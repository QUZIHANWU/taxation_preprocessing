# %% [markdown]
# ## 2018_Preprocessing

# %%
# import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read 2010_data

CSMAR = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2018/CSMAR.xlsx')

WIND = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2018/WIND.xlsx')

MASTER = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2018/MASTER.xlsx')
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CSMAR.dtypes
# Out:
# code                    object
# short_name              object
# FS_Comins-Accper        object
# FS_Comins-Typrep        object
# FS_Comins-B002100000    object
# BF_EXPAY-EndDate        object
# BF_EXPAY-Same           object
# CG_Capchg-Reptdt        object
# CG_Capchg-Nshrsms       object
# CG_Capchg-Nshrttl       object
# dtype: object

# %%
WIND.dtypes
# Out:
# 证券代码                                                   object
# 证券简称                                                   object
# 递延所得税负债增加\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元          float64
# 递延所得税资产减少\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元          float64
# 高管人数\n[交易日期] 2018-12-31                               float64
# 支付给职工以及为职工支付的现金\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元    float64
# 营业收入(同比增长率)\n[报告期] 2018年报\n[单位] %                     float64
# 所属申万行业名称\n[行业级别] 一级行业                                  object
# 资产总计\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元               float64
# 独立董事人数\n[交易日期] 2018-12-31                             float64
# 非独立董事人数\n[交易日期] 2018-12-31                            float64
# 董事会人数\n[交易日期] 2018-12-31                              float64
# 管理层年度薪酬总额\n[年度] 2018\n[单位] 元                          float64
# 员工总数\n[交易日期] 2018-12-31                               float64
# 资产负债率\n[报告期] 2018年报\n[单位] %                           float64
# 公司属性\n[交易日期] 2018-12-31                                object
# 大股东持股比例\n[日期] 2018-12-31\n[排名] 第1名\n[单位] %            float64
# 公司监事(历任)\n[交易日期] 2018-12-31                            object
# 净利润\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元                float64
# 年末所得税率\n[年度] 2018                                     float64
# 经营活动产生的现金流量净额\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元      float64
# dtype: object

# %%
MASTER.dtypes
# Out:
# Symbol                object
# Enddate               object
# StatisticalCaliber    object
# UnpaidNumber          object
# dtype: object

# %% [markdown]
# ### CSMAR_Preprocessing

# %%
CSMAR.head(5)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0      代码         简称             会计期间             报表类型                所得税费用
# 1    沒有单位       沒有单位             没有单位             没有单位                    元
# 2  000001       平安银行       2018-12-31                A         7413000000.0
# 3  000002        万科A       2018-12-31                A   18187906856.369999
# 4  000004       国华网安       2018-12-31                A          -4487257.14
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0             截止日期  董事长与总经理是否同一人           统计截止日期         其中：监管层持股数
# 1             没有单位          没有单位             没有单位                 股
# 2       2018-12-31             N       2018-12-31            8448.0
# 3       2018-12-31             N       2018-12-31         9026490.0
# 4       2018-12-31             Y       2018-12-31          993075.0
#
#   CG_Capchg-Nshrttl
# 0               总股数
# 1                 股
# 2     17170411366.0
# 3     11039152001.0
# 4        83976684.0

# %%
CSMAR = CSMAR.drop([0])
CSMAR = CSMAR.drop([1])
CSMAR = CSMAR.reset_index(drop= True)
# CSMAR = CSMAR.drop(["TRD_Capchg-Shrchgdt", "TRD_Capchg-Nshrttl"], axis=1)
CSMAR.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2018-12-31                A         7413000000.0
# 1  000002        万科A       2018-12-31                A   18187906856.369999
# 2  000004       国华网安       2018-12-31                A          -4487257.14
# 3  000005      ST 星源       2018-12-31                A          15674499.93
# 4  000006       深振业A       2018-12-31                A         145859201.89
# 5  000007     *ST 全新       2018-12-31                A          -4942893.55
# 6  000008       神州高铁       2018-12-31                A          93170938.47
# 7  000009       中国宝安       2018-12-31                A         369815986.75
# 8  000010       美丽生态       2018-12-31                A           2263762.79
# 9  000011       深物业A       2018-12-31                A         184813373.69
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2018-12-31             N       2018-12-31            8448.0
# 1       2018-12-31             N       2018-12-31         9026490.0
# 2       2018-12-31             Y       2018-12-31          993075.0
# 3       2018-12-31             N       2018-12-31               0.0
# 4       2018-12-31             N       2018-12-31         2208868.0
# 5       2018-12-31             N       2018-12-31        37500000.0
# 6       2018-12-31             N       2018-12-31       165198331.0
# 7       2018-12-31             Y       2018-12-31         5749557.0
# 8       2018-12-31             N       2018-12-31            1150.0
# 9       2018-12-31             N       2018-12-31               0.0
#
#   CG_Capchg-Nshrttl
# 0     17170411366.0
# 1     11039152001.0
# 2        83976684.0
# 3      1058536842.0
# 4      1349995046.0
# 5       346448044.0
# 6      2818329809.0
# 7      2149344971.0
# 8       819854713.0
# 9       595979092.0

# %%
CSMAR.isnull().sum()
# Out:
# code                      0
# short_name                0
# FS_Comins-Accper          0
# FS_Comins-Typrep          0
# FS_Comins-B002100000     33
# BF_EXPAY-EndDate        173
# BF_EXPAY-Same           240
# CG_Capchg-Reptdt        173
# CG_Capchg-Nshrsms       173
# CG_Capchg-Nshrttl       173
# dtype: int64

# %%
CSMAR.shape
# Out:
# (3780, 10)

# %% [markdown]
# ### WIND_Preprocessing

# %%
WIND.head(5)
# Out:
#         证券代码  证券简称  递延所得税负债增加\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元  \
# 0  000001.SZ  平安银行                                           NaN
# 1  000002.SZ   万科A                                 -5.118245e+08
# 2  000004.SZ  国华网安                                 -3.463150e+06
# 3  000005.SZ  ST星源                                 -3.420000e+05
# 4  000006.SZ  深振业A                                 -6.166034e+05
#
#    递延所得税资产减少\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元  高管人数\n[交易日期] 2018-12-31  \
# 0                                 -3.259000e+09                     11.0
# 1                                 -5.846639e+09                      6.0
# 2                                 -1.365039e+06                      3.0
# 3                                 -6.655746e+06                      6.0
# 4                                 -4.212405e+07                      7.0
#
#    支付给职工以及为职工支付的现金\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元  \
# 0                                       1.619400e+10
# 1                                       1.411837e+10
# 2                                       2.082353e+07
# 3                                       8.055738e+07
# 4                                       1.500485e+08
#
#    营业收入(同比增长率)\n[报告期] 2018年报\n[单位] % 所属申万行业名称\n[行业级别] 一级行业  \
# 0                            10.3322                    银行
# 1                            22.5537                   房地产
# 2                           164.6850                   计算机
# 3                            -8.4271                  公用事业
# 4                           -15.1246                   房地产
#
#    资产总计\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元  独立董事人数\n[交易日期] 2018-12-31  ...  \
# 0                             3.418592e+12                        5.0  ...
# 1                             1.528579e+12                        4.0  ...
# 2                             3.511775e+08                        3.0  ...
# 3                             3.121423e+09                        5.0  ...
# 4                             1.353673e+10                        3.0  ...
#
#    董事会人数\n[交易日期] 2018-12-31  管理层年度薪酬总额\n[年度] 2018\n[单位] 元  \
# 0                      14.0                    62868700.0
# 1                      11.0                    76994000.0
# 2                       9.0                     1678800.0
# 3                      14.0                     5388000.0
# 4                       7.0                    11341600.0
#
#    员工总数\n[交易日期] 2018-12-31  资产负债率\n[报告期] 2018年报\n[单位] %  \
# 0                  33708.0                      92.9783
# 1                 104300.0                      84.5856
# 2                    210.0                      47.7966
# 3                    745.0                      49.4040
# 4                    377.0                      52.8236
#
#    公司属性\n[交易日期] 2018-12-31 大股东持股比例\n[日期] 2018-12-31\n[排名] 第1名\n[单位] %  \
# 0                     公众企业                                  49.560001
# 1                     公众企业                                  29.379999
# 2                     民营企业                                  28.430000
# 3                     民营企业                                  17.410000
# 4                   地方国有企业                                  21.930000
#
#    公司监事(历任)\n[交易日期] 2018-12-31 净利润\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元  \
# 0    邱伟,车国宝,周建国,骆向东,王群,储一昀,孙永桢                           2.481800e+10
# 1                    周清平,解冻,郑英                           4.927229e+10
# 2                  唐银萍,林绮霞,阮旭里                          -2.161268e+07
# 3              刘丽萍,熊金芳,刘敏儿,吕卫东                           1.567486e+08
# 4                    陈强,谢向荣,张磊                           9.231274e+08
#
#    年末所得税率\n[年度] 2018  经营活动产生的现金流量净额\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元
# 0               25.0                                     -5.732300e+10
# 1               25.0                                      3.361818e+10
# 2               25.0                                     -5.331025e+07
# 3               25.0                                     -9.479481e+07
# 4               25.0                                      1.606682e+09
#
# [5 rows x 21 columns]

# %%
WIND.columns
# Out:
# Index(['证券代码', '证券简称', '递延所得税负债增加\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元',
#        '递延所得税资产减少\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元',
#        '高管人数\n[交易日期] 2018-12-31',
#        '支付给职工以及为职工支付的现金\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元',
#        '营业收入(同比增长率)\n[报告期] 2018年报\n[单位] %', '所属申万行业名称\n[行业级别] 一级行业',
#        '资产总计\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元', '独立董事人数\n[交易日期] 2018-12-31',
#        '非独立董事人数\n[交易日期] 2018-12-31', '董事会人数\n[交易日期] 2018-12-31',
#        '管理层年度薪酬总额\n[年度] 2018\n[单位] 元', '员工总数\n[交易日期] 2018-12-31',
#        '资产负债率\n[报告期] 2018年报\n[单位] %', '公司属性\n[交易日期] 2018-12-31',
#        '大股东持股比例\n[日期] 2018-12-31\n[排名] 第1名\n[单位] %',
#        '公司监事(历任)\n[交易日期] 2018-12-31', '净利润\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元',
#        '年末所得税率\n[年度] 2018',
#        '经营活动产生的现金流量净额\n[报告期] 2018年报\n[报表类型] 合并报表\n[单位] 元'],
#       dtype='object')

# %%
WIND.columns = [col.replace('\n', '') for col in WIND.columns]
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2018年报[报表类型] 合并报表[单位] 元  \
# 0     000001.SZ  平安银行                                     NaN
# 1     000002.SZ   万科A                           -5.118245e+08
# 2     000004.SZ  国华网安                           -3.463150e+06
# 3     000005.SZ  ST星源                           -3.420000e+05
# 4     000006.SZ  深振业A                           -6.166034e+05
# ...         ...   ...                                     ...
# 4769  871857.BJ  泓禧科技                            7.995401e+05
# 4770  871981.BJ  晶赛科技                            2.762168e+06
# 4771  872925.BJ  锦好医疗                                     NaN
# 4772        NaN   NaN                                     NaN
# 4773  数据来源：Wind   NaN                                     NaN
#
#       递延所得税资产减少[报告期] 2018年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2018-12-31  \
# 0                              -3.259000e+09                   11.0
# 1                              -5.846639e+09                    6.0
# 2                              -1.365039e+06                    3.0
# 3                              -6.655746e+06                    6.0
# 4                              -4.212405e+07                    7.0
# ...                                      ...                    ...
# 4769                            6.009300e+02                    5.0
# 4770                           -9.938775e+04                    2.0
# 4771                           -1.119529e+05                    5.0
# 4772                                     NaN                    NaN
# 4773                                     NaN                    NaN
#
#       支付给职工以及为职工支付的现金[报告期] 2018年报[报表类型] 合并报表[单位] 元  \
# 0                                     1.619400e+10
# 1                                     1.411837e+10
# 2                                     2.082353e+07
# 3                                     8.055738e+07
# 4                                     1.500485e+08
# ...                                            ...
# 4769                                  3.062487e+07
# 4770                                  3.132378e+07
# 4771                                  1.505579e+07
# 4772                                           NaN
# 4773                                           NaN
#
#       营业收入(同比增长率)[报告期] 2018年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           10.3322                  银行
# 1                           22.5537                 房地产
# 2                          164.6850                 计算机
# 3                           -8.4271                公用事业
# 4                          -15.1246                 房地产
# ...                             ...                 ...
# 4769                         3.6633                 NaN
# 4770                        26.0610                 NaN
# 4771                        79.5619                 NaN
# 4772                            NaN                 NaN
# 4773                            NaN                 NaN
#
#       资产总计[报告期] 2018年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2018-12-31  ...  \
# 0                          3.418592e+12                      5.0  ...
# 1                          1.528579e+12                      4.0  ...
# 2                          3.511775e+08                      3.0  ...
# 3                          3.121423e+09                      5.0  ...
# 4                          1.353673e+10                      3.0  ...
# ...                                 ...                      ...  ...
# 4769                       2.084120e+08                      0.0  ...
# 4770                       2.824191e+08                      0.0  ...
# 4771                       8.039090e+07                      0.0  ...
# 4772                                NaN                      NaN  ...
# 4773                                NaN                      NaN  ...
#
#       董事会人数[交易日期] 2018-12-31  管理层年度薪酬总额[年度] 2018[单位] 元  员工总数[交易日期] 2018-12-31  \
# 0                       14.0                62868700.0                33708.0
# 1                       11.0                76994000.0               104300.0
# 2                        9.0                 1678800.0                  210.0
# 3                       14.0                 5388000.0                  745.0
# 4                        7.0                11341600.0                  377.0
# ...                      ...                       ...                    ...
# 4769                     5.0                       NaN                  664.0
# 4770                     5.0                       NaN                  403.0
# 4771                     5.0                       NaN                  189.0
# 4772                     NaN                       NaN                    NaN
# 4773                     NaN                       NaN                    NaN
#
#       资产负债率[报告期] 2018年报[单位] %  公司属性[交易日期] 2018-12-31  \
# 0                     92.9783                   公众企业
# 1                     84.5856                   公众企业
# 2                     47.7966                   民营企业
# 3                     49.4040                   民营企业
# 4                     52.8236                 地方国有企业
# ...                       ...                    ...
# 4769                  59.3443                   民营企业
# 4770                  51.5200                   民营企业
# 4771                  25.0991                   民营企业
# 4772                      NaN                    NaN
# 4773                      NaN                    NaN
#
#      大股东持股比例[日期] 2018-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2018-12-31  \
# 0                               49.560001  邱伟,车国宝,周建国,骆向东,王群,储一昀,孙永桢
# 1                               29.379999                  周清平,解冻,郑英
# 2                               28.430000                唐银萍,林绮霞,阮旭里
# 3                               17.410000            刘丽萍,熊金芳,刘敏儿,吕卫东
# 4                               21.930000                  陈强,谢向荣,张磊
# ...                                   ...                        ...
# 4769                            66.559998                  董清波,许岩,文燕
# 4770                            54.049999                陈维彦,孙龙凤,王立平
# 4771                            40.612499                 钟梅,刘雪映,谈海霞
# 4772                                  NaN                        NaN
# 4773                                  NaN                        NaN
#
#      净利润[报告期] 2018年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2018  \
# 0                        2.481800e+10             25.0
# 1                        4.927229e+10             25.0
# 2                       -2.161268e+07             25.0
# 3                        1.567486e+08             25.0
# 4                        9.231274e+08             25.0
# ...                               ...              ...
# 4769                     1.110295e+07             15.0
# 4770                     1.975094e+07             15.0
# 4771                     1.992406e+07             15.0
# 4772                              NaN              NaN
# 4773                              NaN              NaN
#
#       经营活动产生的现金流量净额[报告期] 2018年报[报表类型] 合并报表[单位] 元
# 0                                  -5.732300e+10
# 1                                   3.361818e+10
# 2                                  -5.331025e+07
# 3                                  -9.479481e+07
# 4                                   1.606682e+09
# ...                                          ...
# 4769                               -9.654995e+06
# 4770                                1.978704e+07
# 4771                                1.639453e+07
# 4772                                         NaN
# 4773                                         NaN
#
# [4774 rows x 21 columns]

# %%
WIND = WIND.drop([4772])
WIND = WIND.drop([4773])
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2018年报[报表类型] 合并报表[单位] 元  \
# 0     000001.SZ  平安银行                                     NaN
# 1     000002.SZ   万科A                           -5.118245e+08
# 2     000004.SZ  国华网安                           -3.463150e+06
# 3     000005.SZ  ST星源                           -3.420000e+05
# 4     000006.SZ  深振业A                           -6.166034e+05
# ...         ...   ...                                     ...
# 4767  871553.BJ  凯腾精工                                     NaN
# 4768  871642.BJ  通易航天                                     NaN
# 4769  871857.BJ  泓禧科技                            7.995401e+05
# 4770  871981.BJ  晶赛科技                            2.762168e+06
# 4771  872925.BJ  锦好医疗                                     NaN
#
#       递延所得税资产减少[报告期] 2018年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2018-12-31  \
# 0                              -3.259000e+09                   11.0
# 1                              -5.846639e+09                    6.0
# 2                              -1.365039e+06                    3.0
# 3                              -6.655746e+06                    6.0
# 4                              -4.212405e+07                    7.0
# ...                                      ...                    ...
# 4767                            1.716215e+05                    8.0
# 4768                           -2.754014e+06                    5.0
# 4769                            6.009300e+02                    5.0
# 4770                           -9.938775e+04                    2.0
# 4771                           -1.119529e+05                    5.0
#
#       支付给职工以及为职工支付的现金[报告期] 2018年报[报表类型] 合并报表[单位] 元  \
# 0                                     1.619400e+10
# 1                                     1.411837e+10
# 2                                     2.082353e+07
# 3                                     8.055738e+07
# 4                                     1.500485e+08
# ...                                            ...
# 4767                                  1.112090e+08
# 4768                                  8.812262e+06
# 4769                                  3.062487e+07
# 4770                                  3.132378e+07
# 4771                                  1.505579e+07
#
#       营业收入(同比增长率)[报告期] 2018年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           10.3322                  银行
# 1                           22.5537                 房地产
# 2                          164.6850                 计算机
# 3                           -8.4271                公用事业
# 4                          -15.1246                 房地产
# ...                             ...                 ...
# 4767                         1.9286                 NaN
# 4768                         6.0629                 NaN
# 4769                         3.6633                 NaN
# 4770                        26.0610                 NaN
# 4771                        79.5619                 NaN
#
#       资产总计[报告期] 2018年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2018-12-31  ...  \
# 0                          3.418592e+12                      5.0  ...
# 1                          1.528579e+12                      4.0  ...
# 2                          3.511775e+08                      3.0  ...
# 3                          3.121423e+09                      5.0  ...
# 4                          1.353673e+10                      3.0  ...
# ...                                 ...                      ...  ...
# 4767                       3.291484e+08                      0.0  ...
# 4768                       1.301877e+08                      0.0  ...
# 4769                       2.084120e+08                      0.0  ...
# 4770                       2.824191e+08                      0.0  ...
# 4771                       8.039090e+07                      0.0  ...
#
#       董事会人数[交易日期] 2018-12-31  管理层年度薪酬总额[年度] 2018[单位] 元  员工总数[交易日期] 2018-12-31  \
# 0                       14.0                62868700.0                33708.0
# 1                       11.0                76994000.0               104300.0
# 2                        9.0                 1678800.0                  210.0
# 3                       14.0                 5388000.0                  745.0
# 4                        7.0                11341600.0                  377.0
# ...                      ...                       ...                    ...
# 4767                     5.0                       NaN                 1063.0
# 4768                     5.0                 1432600.0                   97.0
# 4769                     5.0                       NaN                  664.0
# 4770                     5.0                       NaN                  403.0
# 4771                     5.0                       NaN                  189.0
#
#       资产负债率[报告期] 2018年报[单位] %  公司属性[交易日期] 2018-12-31  \
# 0                     92.9783                   公众企业
# 1                     84.5856                   公众企业
# 2                     47.7966                   民营企业
# 3                     49.4040                   民营企业
# 4                     52.8236                 地方国有企业
# ...                       ...                    ...
# 4767                  28.7305                   民营企业
# 4768                  37.1024                   民营企业
# 4769                  59.3443                   民营企业
# 4770                  51.5200                   民营企业
# 4771                  25.0991                   民营企业
#
#      大股东持股比例[日期] 2018-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2018-12-31  \
# 0                               49.560001  邱伟,车国宝,周建国,骆向东,王群,储一昀,孙永桢
# 1                               29.379999                  周清平,解冻,郑英
# 2                               28.430000                唐银萍,林绮霞,阮旭里
# 3                               17.410000            刘丽萍,熊金芳,刘敏儿,吕卫东
# 4                               21.930000                  陈强,谢向荣,张磊
# ...                                   ...                        ...
# 4767                            54.400002                肖国栋,高国昌,呼桂香
# 4768                            53.389999                 陈永彦,朱炜炜,张凯
# 4769                            66.559998                  董清波,许岩,文燕
# 4770                            54.049999                陈维彦,孙龙凤,王立平
# 4771                            40.612499                 钟梅,刘雪映,谈海霞
#
#      净利润[报告期] 2018年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2018  \
# 0                        2.481800e+10             25.0
# 1                        4.927229e+10             25.0
# 2                       -2.161268e+07             25.0
# 3                        1.567486e+08             25.0
# 4                        9.231274e+08             25.0
# ...                               ...              ...
# 4767                     3.237668e+07             25.0
# 4768                     2.213920e+07             15.0
# 4769                     1.110295e+07             15.0
# 4770                     1.975094e+07             15.0
# 4771                     1.992406e+07             15.0
#
#       经营活动产生的现金流量净额[报告期] 2018年报[报表类型] 合并报表[单位] 元
# 0                                  -5.732300e+10
# 1                                   3.361818e+10
# 2                                  -5.331025e+07
# 3                                  -9.479481e+07
# 4                                   1.606682e+09
# ...                                          ...
# 4767                                5.225626e+07
# 4768                                4.168048e+06
# 4769                               -9.654995e+06
# 4770                                1.978704e+07
# 4771                                1.639453e+07
#
# [4772 rows x 21 columns]

# %%
WIND['证券代码'] = WIND['证券代码'].str[0:6]
WIND
# Out:
#         证券代码  证券简称  递延所得税负债增加[报告期] 2018年报[报表类型] 合并报表[单位] 元  \
# 0     000001  平安银行                                     NaN
# 1     000002   万科A                           -5.118245e+08
# 2     000004  国华网安                           -3.463150e+06
# 3     000005  ST星源                           -3.420000e+05
# 4     000006  深振业A                           -6.166034e+05
# ...      ...   ...                                     ...
# 4767  871553  凯腾精工                                     NaN
# 4768  871642  通易航天                                     NaN
# 4769  871857  泓禧科技                            7.995401e+05
# 4770  871981  晶赛科技                            2.762168e+06
# 4771  872925  锦好医疗                                     NaN
#
#       递延所得税资产减少[报告期] 2018年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2018-12-31  \
# 0                              -3.259000e+09                   11.0
# 1                              -5.846639e+09                    6.0
# 2                              -1.365039e+06                    3.0
# 3                              -6.655746e+06                    6.0
# 4                              -4.212405e+07                    7.0
# ...                                      ...                    ...
# 4767                            1.716215e+05                    8.0
# 4768                           -2.754014e+06                    5.0
# 4769                            6.009300e+02                    5.0
# 4770                           -9.938775e+04                    2.0
# 4771                           -1.119529e+05                    5.0
#
#       支付给职工以及为职工支付的现金[报告期] 2018年报[报表类型] 合并报表[单位] 元  \
# 0                                     1.619400e+10
# 1                                     1.411837e+10
# 2                                     2.082353e+07
# 3                                     8.055738e+07
# 4                                     1.500485e+08
# ...                                            ...
# 4767                                  1.112090e+08
# 4768                                  8.812262e+06
# 4769                                  3.062487e+07
# 4770                                  3.132378e+07
# 4771                                  1.505579e+07
#
#       营业收入(同比增长率)[报告期] 2018年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           10.3322                  银行
# 1                           22.5537                 房地产
# 2                          164.6850                 计算机
# 3                           -8.4271                公用事业
# 4                          -15.1246                 房地产
# ...                             ...                 ...
# 4767                         1.9286                 NaN
# 4768                         6.0629                 NaN
# 4769                         3.6633                 NaN
# 4770                        26.0610                 NaN
# 4771                        79.5619                 NaN
#
#       资产总计[报告期] 2018年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2018-12-31  ...  \
# 0                          3.418592e+12                      5.0  ...
# 1                          1.528579e+12                      4.0  ...
# 2                          3.511775e+08                      3.0  ...
# 3                          3.121423e+09                      5.0  ...
# 4                          1.353673e+10                      3.0  ...
# ...                                 ...                      ...  ...
# 4767                       3.291484e+08                      0.0  ...
# 4768                       1.301877e+08                      0.0  ...
# 4769                       2.084120e+08                      0.0  ...
# 4770                       2.824191e+08                      0.0  ...
# 4771                       8.039090e+07                      0.0  ...
#
#       董事会人数[交易日期] 2018-12-31  管理层年度薪酬总额[年度] 2018[单位] 元  员工总数[交易日期] 2018-12-31  \
# 0                       14.0                62868700.0                33708.0
# 1                       11.0                76994000.0               104300.0
# 2                        9.0                 1678800.0                  210.0
# 3                       14.0                 5388000.0                  745.0
# 4                        7.0                11341600.0                  377.0
# ...                      ...                       ...                    ...
# 4767                     5.0                       NaN                 1063.0
# 4768                     5.0                 1432600.0                   97.0
# 4769                     5.0                       NaN                  664.0
# 4770                     5.0                       NaN                  403.0
# 4771                     5.0                       NaN                  189.0
#
#       资产负债率[报告期] 2018年报[单位] %  公司属性[交易日期] 2018-12-31  \
# 0                     92.9783                   公众企业
# 1                     84.5856                   公众企业
# 2                     47.7966                   民营企业
# 3                     49.4040                   民营企业
# 4                     52.8236                 地方国有企业
# ...                       ...                    ...
# 4767                  28.7305                   民营企业
# 4768                  37.1024                   民营企业
# 4769                  59.3443                   民营企业
# 4770                  51.5200                   民营企业
# 4771                  25.0991                   民营企业
#
#      大股东持股比例[日期] 2018-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2018-12-31  \
# 0                               49.560001  邱伟,车国宝,周建国,骆向东,王群,储一昀,孙永桢
# 1                               29.379999                  周清平,解冻,郑英
# 2                               28.430000                唐银萍,林绮霞,阮旭里
# 3                               17.410000            刘丽萍,熊金芳,刘敏儿,吕卫东
# 4                               21.930000                  陈强,谢向荣,张磊
# ...                                   ...                        ...
# 4767                            54.400002                肖国栋,高国昌,呼桂香
# 4768                            53.389999                 陈永彦,朱炜炜,张凯
# 4769                            66.559998                  董清波,许岩,文燕
# 4770                            54.049999                陈维彦,孙龙凤,王立平
# 4771                            40.612499                 钟梅,刘雪映,谈海霞
#
#      净利润[报告期] 2018年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2018  \
# 0                        2.481800e+10             25.0
# 1                        4.927229e+10             25.0
# 2                       -2.161268e+07             25.0
# 3                        1.567486e+08             25.0
# 4                        9.231274e+08             25.0
# ...                               ...              ...
# 4767                     3.237668e+07             25.0
# 4768                     2.213920e+07             15.0
# 4769                     1.110295e+07             15.0
# 4770                     1.975094e+07             15.0
# 4771                     1.992406e+07             15.0
#
#       经营活动产生的现金流量净额[报告期] 2018年报[报表类型] 合并报表[单位] 元
# 0                                  -5.732300e+10
# 1                                   3.361818e+10
# 2                                  -5.331025e+07
# 3                                  -9.479481e+07
# 4                                   1.606682e+09
# ...                                          ...
# 4767                                5.225626e+07
# 4768                                4.168048e+06
# 4769                               -9.654995e+06
# 4770                                1.978704e+07
# 4771                                1.639453e+07
#
# [4772 rows x 21 columns]

# %%
WIND.isnull().sum()
# Out:
# 证券代码                                               0
# 证券简称                                               0
# 递延所得税负债增加[报告期] 2018年报[报表类型] 合并报表[单位] 元          2090
# 递延所得税资产减少[报告期] 2018年报[报表类型] 合并报表[单位] 元           159
# 高管人数[交易日期] 2018-12-31                              0
# 支付给职工以及为职工支付的现金[报告期] 2018年报[报表类型] 合并报表[单位] 元       1
# 营业收入(同比增长率)[报告期] 2018年报[单位] %                     37
# 所属申万行业名称[行业级别] 一级行业                              163
# 资产总计[报告期] 2018年报[报表类型] 合并报表[单位] 元                  1
# 独立董事人数[交易日期] 2018-12-31                            0
# 非独立董事人数[交易日期] 2018-12-31                           0
# 董事会人数[交易日期] 2018-12-31                             0
# 管理层年度薪酬总额[年度] 2018[单位] 元                         920
# 员工总数[交易日期] 2018-12-31                              2
# 资产负债率[报告期] 2018年报[单位] %                            1
# 公司属性[交易日期] 2018-12-31                            792
# 大股东持股比例[日期] 2018-12-31[排名] 第1名[单位] %             556
# 公司监事(历任)[交易日期] 2018-12-31                        386
# 净利润[报告期] 2018年报[报表类型] 合并报表[单位] 元                   1
# 年末所得税率[年度] 2018                                   13
# 经营活动产生的现金流量净额[报告期] 2018年报[报表类型] 合并报表[单位] 元         1
# dtype: int64

# %% [markdown]
# ### MASTER_Preprocessing

# %%
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0       证券代码      统计截止日期               统计口径   未领取薪酬监管层人数
# 1        NaN         NaN                NaN            人
# 2     000001  2018-12-31                  1          4.0
# 3     000001  2018-12-31                  2          4.0
# 4     000002  2018-12-31                  2          0.0
# ...      ...         ...                ...          ...
# 7211  900953  2018-12-31                  1          7.0
# 7212  900956  2018-12-31                  2          8.0
# 7213  900956  2018-12-31                  1          4.0
# 7214  900957  2018-12-31                  1          0.0
# 7215  900957  2018-12-31                  2          0.0
#
# [7216 rows x 4 columns]

# %%
MASTER = MASTER.drop([0])
MASTER = MASTER.drop([1])
MASTER = MASTER.reset_index(drop =True)
MASTER = MASTER[(MASTER['StatisticalCaliber'] != '2')]
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0     000001  2018-12-31                  1          4.0
# 3     000002  2018-12-31                  1          0.0
# 4     000004  2018-12-31                  1          3.0
# 6     000005  2018-12-31                  1          0.0
# 8     000006  2018-12-31                  1          0.0
# ...      ...         ...                ...          ...
# 7205  900948  2018-12-31                  1          0.0
# 7206  900951  2018-12-31                  1          5.0
# 7209  900953  2018-12-31                  1          7.0
# 7211  900956  2018-12-31                  1          4.0
# 7212  900957  2018-12-31                  1          0.0
#
# [3607 rows x 4 columns]

# %%
MASTER.shape
# Out:
# (3607, 4)

# %% [markdown]
# ### Merge CSMAR_and_WIND_and_MASTER

# %%
merge_data = pd.merge(CSMAR, WIND, left_on='code', right_on='证券代码')
merge_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2018-12-31                A         7413000000.0
# 1  000002        万科A       2018-12-31                A   18187906856.369999
# 2  000004       国华网安       2018-12-31                A          -4487257.14
# 3  000005      ST 星源       2018-12-31                A          15674499.93
# 4  000006       深振业A       2018-12-31                A         145859201.89
# 5  000007     *ST 全新       2018-12-31                A          -4942893.55
# 6  000008       神州高铁       2018-12-31                A          93170938.47
# 7  000009       中国宝安       2018-12-31                A         369815986.75
# 8  000010       美丽生态       2018-12-31                A           2263762.79
# 9  000011       深物业A       2018-12-31                A         184813373.69
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2018-12-31             N       2018-12-31            8448.0
# 1       2018-12-31             N       2018-12-31         9026490.0
# 2       2018-12-31             Y       2018-12-31          993075.0
# 3       2018-12-31             N       2018-12-31               0.0
# 4       2018-12-31             N       2018-12-31         2208868.0
# 5       2018-12-31             N       2018-12-31        37500000.0
# 6       2018-12-31             N       2018-12-31       165198331.0
# 7       2018-12-31             Y       2018-12-31         5749557.0
# 8       2018-12-31             N       2018-12-31            1150.0
# 9       2018-12-31             N       2018-12-31               0.0
#
#   CG_Capchg-Nshrttl  ... 董事会人数[交易日期] 2018-12-31 管理层年度薪酬总额[年度] 2018[单位] 元  \
# 0     17170411366.0  ...                   14.0               62868700.0
# 1     11039152001.0  ...                   11.0               76994000.0
# 2        83976684.0  ...                    9.0                1678800.0
# 3      1058536842.0  ...                   14.0                5388000.0
# 4      1349995046.0  ...                    7.0               11341600.0
# 5       346448044.0  ...                    9.0                3689400.0
# 6      2818329809.0  ...                    9.0               16853200.0
# 7      2149344971.0  ...                    9.0               19405700.0
# 8       819854713.0  ...                   10.0                7021600.0
# 9       595979092.0  ...                    9.0                9977800.0
#
#    员工总数[交易日期] 2018-12-31  资产负债率[报告期] 2018年报[单位] %  公司属性[交易日期] 2018-12-31  \
# 0                33708.0                  92.9783                   公众企业
# 1               104300.0                  84.5856                   公众企业
# 2                  210.0                  47.7966                   民营企业
# 3                  745.0                  49.4040                   民营企业
# 4                  377.0                  52.8236                 地方国有企业
# 5                   84.0                  49.6443                   民营企业
# 6                 2631.0                  29.2510                 中央国有企业
# 7                13620.0                  64.9896                   公众企业
# 8                  545.0                  81.9505                   民营企业
# 9                 5504.0                  42.5931                 地方国有企业
#
#    大股东持股比例[日期] 2018-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2018-12-31  \
# 0                             49.560001  邱伟,车国宝,周建国,骆向东,王群,储一昀,孙永桢
# 1                             29.379999                  周清平,解冻,郑英
# 2                             28.430000                唐银萍,林绮霞,阮旭里
# 3                             17.410000            刘丽萍,熊金芳,刘敏儿,吕卫东
# 4                             21.930000                  陈强,谢向荣,张磊
# 5                             21.650000                  孙华,李代宏,马斌
# 6                             20.000000                  高辉,柳杨,萨殊利
# 7                             11.910000                骆文明,曾丽桃,李新祥
# 8                             13.510000                  翟禹,郭勋,邓丽丹
# 9                             63.820000        戴先华,王秋平,张满华,顾伟敏,李清华
#
#   净利润[报告期] 2018年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2018  \
# 0                     2.481800e+10             25.0
# 1                     4.927229e+10             25.0
# 2                    -2.161268e+07             25.0
# 3                     1.567486e+08             25.0
# 4                     9.231274e+08             25.0
# 5                    -1.962002e+08             25.0
# 6                     3.418897e+08             25.0
# 7                     6.650705e+08             25.0
# 8                    -7.265126e+08             25.0
# 9                     5.926618e+08             25.0
#
#    经营活动产生的现金流量净额[报告期] 2018年报[报表类型] 合并报表[单位] 元
# 0                               -5.732300e+10
# 1                                3.361818e+10
# 2                               -5.331025e+07
# 3                               -9.479481e+07
# 4                                1.606682e+09
# 5                               -6.874171e+06
# 6                               -5.905694e+08
# 7                                2.722842e+09
# 8                               -2.384320e+08
# 9                                1.123595e+09
#
# [10 rows x 31 columns]

# %%
full_data = pd.merge(merge_data, MASTER, left_on='code', right_on='Symbol')
full_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2018-12-31                A         7413000000.0
# 1  000002        万科A       2018-12-31                A   18187906856.369999
# 2  000004       国华网安       2018-12-31                A          -4487257.14
# 3  000005      ST 星源       2018-12-31                A          15674499.93
# 4  000006       深振业A       2018-12-31                A         145859201.89
# 5  000007     *ST 全新       2018-12-31                A          -4942893.55
# 6  000008       神州高铁       2018-12-31                A          93170938.47
# 7  000009       中国宝安       2018-12-31                A         369815986.75
# 8  000010       美丽生态       2018-12-31                A           2263762.79
# 9  000011       深物业A       2018-12-31                A         184813373.69
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2018-12-31             N       2018-12-31            8448.0
# 1       2018-12-31             N       2018-12-31         9026490.0
# 2       2018-12-31             Y       2018-12-31          993075.0
# 3       2018-12-31             N       2018-12-31               0.0
# 4       2018-12-31             N       2018-12-31         2208868.0
# 5       2018-12-31             N       2018-12-31        37500000.0
# 6       2018-12-31             N       2018-12-31       165198331.0
# 7       2018-12-31             Y       2018-12-31         5749557.0
# 8       2018-12-31             N       2018-12-31            1150.0
# 9       2018-12-31             N       2018-12-31               0.0
#
#   CG_Capchg-Nshrttl  ... 公司属性[交易日期] 2018-12-31  \
# 0     17170411366.0  ...                  公众企业
# 1     11039152001.0  ...                  公众企业
# 2        83976684.0  ...                  民营企业
# 3      1058536842.0  ...                  民营企业
# 4      1349995046.0  ...                地方国有企业
# 5       346448044.0  ...                  民营企业
# 6      2818329809.0  ...                中央国有企业
# 7      2149344971.0  ...                  公众企业
# 8       819854713.0  ...                  民营企业
# 9       595979092.0  ...                地方国有企业
#
#   大股东持股比例[日期] 2018-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2018-12-31  \
# 0                            49.560001  邱伟,车国宝,周建国,骆向东,王群,储一昀,孙永桢
# 1                            29.379999                  周清平,解冻,郑英
# 2                            28.430000                唐银萍,林绮霞,阮旭里
# 3                            17.410000            刘丽萍,熊金芳,刘敏儿,吕卫东
# 4                            21.930000                  陈强,谢向荣,张磊
# 5                            21.650000                  孙华,李代宏,马斌
# 6                            20.000000                  高辉,柳杨,萨殊利
# 7                            11.910000                骆文明,曾丽桃,李新祥
# 8                            13.510000                  翟禹,郭勋,邓丽丹
# 9                            63.820000        戴先华,王秋平,张满华,顾伟敏,李清华
#
#    净利润[报告期] 2018年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2018  \
# 0                      2.481800e+10             25.0
# 1                      4.927229e+10             25.0
# 2                     -2.161268e+07             25.0
# 3                      1.567486e+08             25.0
# 4                      9.231274e+08             25.0
# 5                     -1.962002e+08             25.0
# 6                      3.418897e+08             25.0
# 7                      6.650705e+08             25.0
# 8                     -7.265126e+08             25.0
# 9                      5.926618e+08             25.0
#
#    经营活动产生的现金流量净额[报告期] 2018年报[报表类型] 合并报表[单位] 元  Symbol     Enddate  \
# 0                               -5.732300e+10  000001  2018-12-31
# 1                                3.361818e+10  000002  2018-12-31
# 2                               -5.331025e+07  000004  2018-12-31
# 3                               -9.479481e+07  000005  2018-12-31
# 4                                1.606682e+09  000006  2018-12-31
# 5                               -6.874171e+06  000007  2018-12-31
# 6                               -5.905694e+08  000008  2018-12-31
# 7                                2.722842e+09  000009  2018-12-31
# 8                               -2.384320e+08  000010  2018-12-31
# 9                                1.123595e+09  000011  2018-12-31
#
#    StatisticalCaliber  UnpaidNumber
# 0                   1           4.0
# 1                   1           0.0
# 2                   1           3.0
# 3                   1           0.0
# 4                   1           0.0
# 5                   1           0.0
# 6                   1           4.0
# 7                   1           0.0
# 8                   1           0.0
# 9                   1           4.0
#
# [10 rows x 35 columns]

# %%
full_data.shape
# Out:
# (3544, 35)

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2018/full_data.xlsx')

# %% [markdown]
# ### 1：剔除金融保险类、ST、* ST类上市公司

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加[报告期] 2018年报[报表类型] 合并报表[单位] 元',
#        '递延所得税资产减少[报告期] 2018年报[报表类型] 合并报表[单位] 元', '高管人数[交易日期] 2018-12-31',
#        '支付给职工以及为职工支付的现金[报告期] 2018年报[报表类型] 合并报表[单位] 元',
#        '营业收入(同比增长率)[报告期] 2018年报[单位] %', '所属申万行业名称[行业级别] 一级行业',
#        '资产总计[报告期] 2018年报[报表类型] 合并报表[单位] 元', '独立董事人数[交易日期] 2018-12-31',
#        '非独立董事人数[交易日期] 2018-12-31', '董事会人数[交易日期] 2018-12-31',
#        '管理层年度薪酬总额[年度] 2018[单位] 元', '员工总数[交易日期] 2018-12-31',
#        '资产负债率[报告期] 2018年报[单位] %', '公司属性[交易日期] 2018-12-31',
#        '大股东持股比例[日期] 2018-12-31[排名] 第1名[单位] %', '公司监事(历任)[交易日期] 2018-12-31',
#        '净利润[报告期] 2018年报[报表类型] 合并报表[单位] 元', '年末所得税率[年度] 2018',
#        '经营活动产生的现金流量净额[报告期] 2018年报[报表类型] 合并报表[单位] 元', 'Symbol', 'Enddate',
#        'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.columns = ['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
       'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
       'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
       '证券简称', '递延所得税负债增加',
       '递延所得税资产减少', '高管人数',
       '支付给职工以及为职工支付的现金',
       '营业收入', '所属申万行业名称',
       '资产总计', '独立董事人数',
       '非独立董事人数', '董事会人数',
       '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性',
       '大股东持股比例', '公司监事',
       '净利润', '年末所得税率',
       '经营活动产生的现金流量净额', 'Symbol', 'Enddate',
       'StatisticalCaliber', 'UnpaidNumber']
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.shape
# Out:
# (3544, 35)

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '银行')]
full_data = full_data[(full_data['所属申万行业名称'] != '非银金融')]

full_data['check_ST'] = full_data['short_name'].str[0:2]
full_data['check_*ST'] = full_data['short_name'].str[0:3]
full_data = full_data[(full_data['check_ST'] != 'ST')]
full_data = full_data[(full_data['check_*ST'] != '*ST')]

# %%
full_data.shape
# Out:
# (3263, 37)

# %% [markdown]
# ### 2：剔除员工数量不足 100人的公司,这部分公司可能存在经营异常或者数据披露错误

# %%
full_data = full_data[(full_data['员工总数'] > 100)]

# %%
full_data.shape
# Out:
# (3244, 37)

# %% [markdown]
# ### 3：剔除管理层平均工资比普通员工平均工资低的公司,因为这类公司披露的高管薪酬可能仅是津贴,或者数据错误：

# %% [markdown]
# - 管理层平均工资 = 管理层年度薪酬总数/（非独立董事人数+公司监事+高管人数-UnpaidNumber）
# - 普通员工平均工资 = （支付给职工以及为职工支付的现金-管理层年度薪酬总数）/ （员工总数-（非独立董事+公司监事+高管人数））

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST'],
#       dtype='object')

# %%
full_data['人数']=full_data['公司监事'].apply(lambda x: len(x.split(',')))

# %%
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2018-12-31                A   18187906856.369999
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2018-12-31             N       2018-12-31         9026490.0
#
#   CG_Capchg-Nshrttl  ...           净利润 年末所得税率  经营活动产生的现金流量净额  Symbol  \
# 1     11039152001.0  ...  4.927229e+10   25.0   3.361818e+10  000002
#
#       Enddate  StatisticalCaliber  UnpaidNumber check_ST  check_*ST  人数
# 1  2018-12-31                   1           0.0       万科        万科A   3
#
# [1 rows x 38 columns]

# %%
full_data.isnull().sum()
# Out:
# code                       0
# short_name                 0
# FS_Comins-Accper           0
# FS_Comins-Typrep           0
# FS_Comins-B002100000      15
# BF_EXPAY-EndDate           0
# BF_EXPAY-Same             53
# CG_Capchg-Reptdt           0
# CG_Capchg-Nshrsms          0
# CG_Capchg-Nshrttl          0
# 证券代码                       0
# 证券简称                       0
# 递延所得税负债增加               1167
# 递延所得税资产减少                 60
# 高管人数                       0
# 支付给职工以及为职工支付的现金            0
# 营业收入                       0
# 所属申万行业名称                   0
# 资产总计                       0
# 独立董事人数                     0
# 非独立董事人数                    0
# 董事会人数                      0
# 管理层年度薪酬总额                  4
# 员工总数                       0
# 资产负债率                      0
# 公司属性                       9
# 大股东持股比例                    0
# 公司监事                       0
# 净利润                        0
# 年末所得税率                     5
# 经营活动产生的现金流量净额              0
# Symbol                     0
# Enddate                    0
# StatisticalCaliber         0
# UnpaidNumber               0
# check_ST                   0
# check_*ST                  0
# 人数                         0
# dtype: int64

# %%
full_data['管理层平均工资'] = full_data['管理层年度薪酬总额'] / (
   full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数'] 
      - full_data['UnpaidNumber']
)
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2018-12-31                A   18187906856.369999
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2018-12-31             N       2018-12-31         9026490.0
#
#   CG_Capchg-Nshrttl  ... 年末所得税率 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11039152001.0  ...   25.0  3.361818e+10  000002  2018-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST check_*ST  人数    管理层平均工资
# 1                   1           0.0        万科       万科A   3  4812125.0
#
# [1 rows x 39 columns]

# %%
full_data['普通员工平均工资'] = (full_data ['支付给职工以及为职工支付的现金'] 
   - full_data['管理层年度薪酬总额']) / (
      full_data['员工总数'] - (
         full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数']
      )
)
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2018-12-31                A   18187906856.369999
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2018-12-31             N       2018-12-31         9026490.0
#
#   CG_Capchg-Nshrttl  ... 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11039152001.0  ...  3.361818e+10  000002  2018-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST  check_*ST 人数    管理层平均工资  \
# 1                   1           0.0        万科        万科A  3  4812125.0
#
#         普通员工平均工资
# 1  134645.592663
#
# [1 rows x 40 columns]

# %%
full_data = full_data[(full_data["管理层平均工资"] > full_data["普通员工平均工资"])]

# %%
full_data.shape
# Out:
# (3196, 40)

# %% [markdown]
# ### 4：剔除企业实际所得税率小于0和大于1的样本

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data = full_data[(full_data['年末所得税率'] <100) &
   (full_data['年末所得税率'] >0)]

# %%
full_data.shape
# Out:
# (3161, 40)

# %% [markdown]
# ### 5：由于2015 年新增了轻工、纺织、机械和汽车四大行业作为加速折旧政策试点,如果将这部分个业作为2014年加速折旧政策的控制组可能对结果产生偏差,为此还剔除了享受2015年加速折旧政策的公司样本

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '轻工制造')]
full_data = full_data[(full_data['所属申万行业名称'] != '纺织服装')]
full_data = full_data[(full_data['所属申万行业名称'] != '机械设备')]
full_data = full_data[(full_data['所属申万行业名称'] != '汽车')]

# %%
full_data.shape
# Out:
# (2506, 40)

# %% [markdown]
# ### 6：剔除关键变量缺失的样本

# %%
miss_data = pd.DataFrame(full_data.isnull().sum(), columns=['Missing Data Count'])
miss_data
# Out:
#                       Missing Data Count
# code                                   0
# short_name                             0
# FS_Comins-Accper                       0
# FS_Comins-Typrep                       0
# FS_Comins-B002100000                  11
# BF_EXPAY-EndDate                       0
# BF_EXPAY-Same                         39
# CG_Capchg-Reptdt                       0
# CG_Capchg-Nshrsms                      0
# CG_Capchg-Nshrttl                      0
# 证券代码                                   0
# 证券简称                                   0
# 递延所得税负债增加                            875
# 递延所得税资产减少                             43
# 高管人数                                   0
# 支付给职工以及为职工支付的现金                        0
# 营业收入                                   0
# 所属申万行业名称                               0
# 资产总计                                   0
# 独立董事人数                                 0
# 非独立董事人数                                0
# 董事会人数                                  0
# 管理层年度薪酬总额                              0
# 员工总数                                   0
# 资产负债率                                  0
# 公司属性                                   7
# 大股东持股比例                                0
# 公司监事                                   0
# 净利润                                    0
# 年末所得税率                                 0
# 经营活动产生的现金流量净额                          0
# Symbol                                 0
# Enddate                                0
# StatisticalCaliber                     0
# UnpaidNumber                           0
# check_ST                               0
# check_*ST                              0
# 人数                                     0
# 管理层平均工资                                0
# 普通员工平均工资                               0

# %%
miss_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2018/miss_data.xlsx')

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2018/full_data2.xlsx')

# %%
full_data.dropna(axis=0,inplace=True)

# %%
full_data.shape
# Out:
# (1589, 40)

# %% [markdown]
# ### 8：final

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.columns = ['代码', '简称', '会计期间', '报表类型',
       '所得税费用', '截止日期', '董事长和总经理是否同一人',
       '统计截止日期', '监管层持股数', '总股数', '证券代码',
       '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
       '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
       'Symbol', 'Enddate', 'StatisticalCaliber', '未领取薪酬监管层人数', 'check_ST',
       'check_*ST', '人数', '管理层平均工资', '普通员工平均工资']
full_data.columns
# Out:
# Index(['代码', '简称', '会计期间', '报表类型', '所得税费用', '截止日期', '董事长和总经理是否同一人', '统计截止日期',
#        '监管层持股数', '总股数', '证券代码', '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数',
#        '支付给职工以及为职工支付的现金', '营业收入', '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数',
#        '董事会人数', '管理层年度薪酬总额', '员工总数', '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润',
#        '年末所得税率', '经营活动产生的现金流量净额', 'Symbol', 'Enddate', 'StatisticalCaliber',
#        '未领取薪酬监管层人数', 'check_ST', 'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2018/2018_final_1.xlsx')

# %% [markdown]
# ### .to_table

# %%
import math

def get_log(full_data):
   result_log = []
   list_log = full_data.values
   for i in list_log:
      result_log_n = math.log(i)
      result_log.append(result_log_n)
   return result_log

list_result = get_log(full_data['管理层平均工资'])
full_data['lnAMW'] = list_result

list_result = get_log(full_data['普通员工平均工资'])
full_data['lnAEW'] = list_result

full_data['收入不平等'] = full_data['管理层平均工资'] / full_data['普通员工平均工资']
list_result = get_log(full_data['收入不平等'])
full_data['lnWFI'] = list_result

full_data['ETR'] = full_data['所得税费用'] / (
   (
      full_data['所得税费用'] + full_data['净利润'] - (
         full_data['递延所得税负债增加'] + full_data['递延所得税资产减少']
      )/ full_data['年末所得税率']
   )
)

list_result = get_log(full_data['资产总计'])
full_data['lnSize'] = list_result

full_data['OCF'] = full_data['经营活动产生的现金流量净额'] / full_data['资产总计']

full_data['Lev'] = full_data['资产负债率']/100

full_data['Growth'] = full_data['营业收入']/100

full_data['Top1'] = full_data['大股东持股比例']

full_data['indepent'] = (full_data['独立董事人数'] / full_data['董事会人数'])*100

full_data['MH'] = (full_data['监管层持股数'] / full_data['总股数'])*100

full_data["Dual"] = np.where(full_data["董事长和总经理是否同一人"] =='Y', "1", "0")

full_data['国有判断'] = full_data['公司属性'].str[2:4]
full_data['SOE'] = np.where(full_data['国有判断'] =='国有', "1", "0")

# %%
full_data.head(1)
# Out:
#        代码   简称        会计期间 报表类型               所得税费用        截止日期 董事长和总经理是否同一人  \
# 1  000002  万科A  2018-12-31    A  18187906856.369999  2018-12-31            N
#
#        统计截止日期     监管层持股数            总股数  ...    lnSize       OCF       Lev  \
# 1  2018-12-31  9026490.0  11039152001.0  ...  28.05536  0.021993  0.845856
#
#      Growth       Top1   indepent        MH Dual  国有判断  SOE
# 1  0.225537  29.379999  36.363636  0.081768    0    企业    0
#
# [1 rows x 55 columns]

# %%
full_data.shape
# Out:
# (1589, 55)

# %% [markdown]
# ### 对所有连续变量在上下1%水平上进行缩尾处理

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/processed/2018_final_data.xlsx')

# %%
full_data['lnWFI'].describe()
# Out:
# count    1589.000000
# mean        1.381155
# std         0.620878
# min         0.032658
# 25%         0.952630
# 50%         1.313235
# 75%         1.716724
# max         3.977959
# Name: lnWFI, dtype: float64
