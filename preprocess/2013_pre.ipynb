# %% [markdown]
# ## 2013_Preprocessing

# %%
# import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read 2010_data

CSMAR = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2013/CSMAR.xlsx')

WIND = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2013/WIND.xlsx')

MASTER = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2013/MASTER.xlsx')
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CSMAR.dtypes
# Out:
# code                    object
# short_name              object
# FS_Comins-Accper        object
# FS_Comins-Typrep        object
# FS_Comins-B002100000    object
# BF_EXPAY-EndDate        object
# BF_EXPAY-Same           object
# CG_Capchg-Reptdt        object
# CG_Capchg-Nshrsms       object
# CG_Capchg-Nshrttl       object
# dtype: object

# %%
WIND.dtypes
# Out:
# 证券代码                                                   object
# 证券简称                                                   object
# 递延所得税负债增加\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元          float64
# 递延所得税资产减少\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元          float64
# 高管人数\n[交易日期] 2013-12-31                               float64
# 支付给职工以及为职工支付的现金\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元    float64
# 营业收入(同比增长率)\n[报告期] 2013年报\n[单位] %                     float64
# 所属申万行业名称\n[行业级别] 一级行业                                  object
# 资产总计\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元               float64
# 独立董事人数\n[交易日期] 2013-12-31                             float64
# 非独立董事人数\n[交易日期] 2013-12-31                            float64
# 董事会人数\n[交易日期] 2013-12-31                              float64
# 管理层年度薪酬总额\n[年度] 2013\n[单位] 元                          float64
# 员工总数\n[交易日期] 2013-12-31                               float64
# 资产负债率\n[报告期] 2013年报\n[单位] %                           float64
# 公司属性\n[交易日期] 2013-12-31                                object
# 大股东持股比例\n[日期] 2013-12-31\n[排名] 第1名\n[单位] %            float64
# 公司监事(历任)\n[交易日期] 2013-12-31                            object
# 净利润\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元                float64
# 年末所得税率\n[年度] 2013                                     float64
# 经营活动产生的现金流量净额\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元      float64
# dtype: object

# %%
MASTER.dtypes
# Out:
# Symbol                object
# Enddate               object
# StatisticalCaliber    object
# UnpaidNumber          object
# dtype: object

# %% [markdown]
# ### CSMAR_Preprocessing

# %%
CSMAR.head(5)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0      代码         简称             会计期间             报表类型                所得税费用
# 1    沒有单位       沒有单位             没有单位             没有单位                    元
# 2  000001       平安银行       2013-12-31                A         4809000000.0
# 3  000002        万科A       2013-12-31                A        5993461378.06
# 4  000004       国华网安       2013-12-31                A           5406254.88
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0             截止日期  董事长与总经理是否同一人           统计截止日期         其中：监管层持股数
# 1             没有单位          没有单位             没有单位                 股
# 2       2013-12-31             N       2013-12-31           29782.0
# 3       2013-12-31             N       2013-12-31        23828261.0
# 4       2013-12-31             N       2013-12-31            1725.0
#
#   CG_Capchg-Nshrttl
# 0               总股数
# 1                 股
# 2      8197360665.0
# 3     11014968919.0
# 4        83976684.0

# %%
CSMAR = CSMAR.drop([0])
CSMAR = CSMAR.drop([1])
CSMAR = CSMAR.reset_index(drop= True)
# CSMAR = CSMAR.drop(["TRD_Capchg-Shrchgdt", "TRD_Capchg-Nshrttl"], axis=1)
CSMAR.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2013-12-31                A         4809000000.0
# 1  000002        万科A       2013-12-31                A        5993461378.06
# 2  000004       国华网安       2013-12-31                A           5406254.88
# 3  000005      ST 星源       2013-12-31                A                  0.0
# 4  000006       深振业A       2013-12-31                A         228266054.74
# 5  000007     *ST 全新       2013-12-31                A           3550190.26
# 6  000008       神州高铁       2013-12-31                A           7363135.79
# 7  000009       中国宝安       2013-12-31                A          60114193.04
# 8  000010       美丽生态       2013-12-31                A           5696588.27
# 9  000011       深物业A       2013-12-31                A         122093910.62
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2013-12-31             N       2013-12-31           29782.0
# 1       2013-12-31             N       2013-12-31        23828261.0
# 2       2013-12-31             N       2013-12-31            1725.0
# 3       2013-12-31             N       2013-12-31               0.0
# 4       2013-12-31             N       2013-12-31        11753463.0
# 5       2013-12-31             N       2013-12-31        25152222.0
# 6       2013-12-31             N       2013-12-31             180.0
# 7       2013-12-31             Y       2013-12-31          146402.0
# 8       2013-12-31             N       2013-12-31               0.0
# 9       2013-12-31             N       2013-12-31               0.0
#
#   CG_Capchg-Nshrttl
# 0      8197360665.0
# 1     11014968919.0
# 2        83976684.0
# 3       914333607.0
# 4      1349995046.0
# 5       230965363.0
# 6       303601640.0
# 7      1254363108.0
# 8       588069788.0
# 9       595979092.0

# %%
CSMAR.isnull().sum()
# Out:
# code                      0
# short_name                0
# FS_Comins-Accper          0
# FS_Comins-Typrep          0
# FS_Comins-B002100000      0
# BF_EXPAY-EndDate         88
# BF_EXPAY-Same           108
# CG_Capchg-Reptdt         88
# CG_Capchg-Nshrsms        88
# CG_Capchg-Nshrttl        88
# dtype: int64

# %%
CSMAR.shape
# Out:
# (2624, 10)

# %% [markdown]
# ### WIND_Preprocessing

# %%
WIND.head(5)
# Out:
#         证券代码  证券简称  递延所得税负债增加\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元  \
# 0  000001.SZ  平安银行                                 -1.272000e+09
# 1  000002.SZ   万科A                                 -6.080747e+07
# 2  000004.SZ  国华网安                                           NaN
# 3  000005.SZ  ST星源                                           NaN
# 4  000006.SZ  深振业A                                  9.422067e+06
#
#    递延所得税资产减少\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元  高管人数\n[交易日期] 2013-12-31  \
# 0                                 -3.440000e+08                     15.0
# 1                                 -4.721021e+08                     12.0
# 2                                           NaN                      5.0
# 3                                           NaN                      6.0
# 4                                  1.373554e+08                      9.0
#
#    支付给职工以及为职工支付的现金\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元  \
# 0                                       9.660000e+09
# 1                                       3.472696e+09
# 2                                       1.850977e+07
# 3                                       3.084465e+07
# 4                                       8.350216e+07
#
#    营业收入(同比增长率)\n[报告期] 2013年报\n[单位] % 所属申万行业名称\n[行业级别] 一级行业  \
# 0                            31.2964                    银行
# 1                            31.3263                   房地产
# 2                           -25.2444                   计算机
# 3                           -47.6352                  公用事业
# 4                            49.8858                   房地产
#
#    资产总计\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元  独立董事人数\n[交易日期] 2013-12-31  ...  \
# 0                             1.891741e+12                        8.0  ...
# 1                             4.792053e+11                        4.0  ...
# 2                             2.421521e+08                        3.0  ...
# 3                             1.188654e+09                        5.0  ...
# 4                             9.968160e+09                        3.0  ...
#
#    董事会人数\n[交易日期] 2013-12-31  管理层年度薪酬总额\n[年度] 2013\n[单位] 元  \
# 0                      18.0                    75395400.0
# 1                      11.0                   112210000.0
# 2                       9.0                     1820600.0
# 3                      15.0                     3557000.0
# 4                       9.0                     9480200.0
#
#    员工总数\n[交易日期] 2013-12-31  资产负债率\n[报告期] 2013年报\n[单位] %  \
# 0                  28369.0                      94.0752
# 1                  35330.0                      77.9970
# 2                    243.0                      40.3239
# 3                    376.0                      47.4831
# 4                    296.0                      57.9972
#
#    公司属性\n[交易日期] 2013-12-31 大股东持股比例\n[日期] 2013-12-31\n[排名] 第1名\n[单位] %  \
# 0                     公众企业                                  50.200001
# 1                     公众企业                                  14.700000
# 2                     民营企业                                  26.100000
# 3                     民营企业                                  20.150000
# 4                   地方国有企业                                  20.309999
#
#    公司监事(历任)\n[交易日期] 2013-12-31 净利润\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元  \
# 0     邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚                           1.523100e+10
# 1                   丁福源,周清平,吴丁                           1.829755e+10
# 2                    魏杰,陈少龙,何婷                           5.796750e+06
# 3                  刘丽萍,熊金芳,汪健飞                          -4.234476e+07
# 4                   朱大华,陈强,谢向荣                           6.980091e+08
#
#    年末所得税率\n[年度] 2013  经营活动产生的现金流量净额\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元
# 0               25.0                                      9.167400e+10
# 1               25.0                                      1.923869e+09
# 2               25.0                                     -2.104231e+07
# 3               25.0                                     -1.117181e+08
# 4               25.0                                     -8.902919e+08
#
# [5 rows x 21 columns]

# %%
WIND.columns
# Out:
# Index(['证券代码', '证券简称', '递延所得税负债增加\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元',
#        '递延所得税资产减少\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元',
#        '高管人数\n[交易日期] 2013-12-31',
#        '支付给职工以及为职工支付的现金\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元',
#        '营业收入(同比增长率)\n[报告期] 2013年报\n[单位] %', '所属申万行业名称\n[行业级别] 一级行业',
#        '资产总计\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元', '独立董事人数\n[交易日期] 2013-12-31',
#        '非独立董事人数\n[交易日期] 2013-12-31', '董事会人数\n[交易日期] 2013-12-31',
#        '管理层年度薪酬总额\n[年度] 2013\n[单位] 元', '员工总数\n[交易日期] 2013-12-31',
#        '资产负债率\n[报告期] 2013年报\n[单位] %', '公司属性\n[交易日期] 2013-12-31',
#        '大股东持股比例\n[日期] 2013-12-31\n[排名] 第1名\n[单位] %',
#        '公司监事(历任)\n[交易日期] 2013-12-31', '净利润\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元',
#        '年末所得税率\n[年度] 2013',
#        '经营活动产生的现金流量净额\n[报告期] 2013年报\n[报表类型] 合并报表\n[单位] 元'],
#       dtype='object')

# %%
WIND.columns = [col.replace('\n', '') for col in WIND.columns]
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2013年报[报表类型] 合并报表[单位] 元  \
# 0     000001.SZ  平安银行                           -1.272000e+09
# 1     000002.SZ   万科A                           -6.080747e+07
# 2     000004.SZ  国华网安                                     NaN
# 3     000005.SZ  ST星源                                     NaN
# 4     000006.SZ  深振业A                            9.422067e+06
# ...         ...   ...                                     ...
# 4769  871857.BJ  泓禧科技                                     NaN
# 4770  871981.BJ  晶赛科技                                     NaN
# 4771  872925.BJ  锦好医疗                                     NaN
# 4772        NaN   NaN                                     NaN
# 4773  数据来源：Wind   NaN                                     NaN
#
#       递延所得税资产减少[报告期] 2013年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2013-12-31  \
# 0                              -3.440000e+08                   15.0
# 1                              -4.721021e+08                   12.0
# 2                                        NaN                    5.0
# 3                                        NaN                    6.0
# 4                               1.373554e+08                    9.0
# ...                                      ...                    ...
# 4769                                     NaN                    0.0
# 4770                                     NaN                    0.0
# 4771                                     NaN                    0.0
# 4772                                     NaN                    NaN
# 4773                                     NaN                    NaN
#
#       支付给职工以及为职工支付的现金[报告期] 2013年报[报表类型] 合并报表[单位] 元  \
# 0                                     9.660000e+09
# 1                                     3.472696e+09
# 2                                     1.850977e+07
# 3                                     3.084465e+07
# 4                                     8.350216e+07
# ...                                            ...
# 4769                                           NaN
# 4770                                           NaN
# 4771                                           NaN
# 4772                                           NaN
# 4773                                           NaN
#
#       营业收入(同比增长率)[报告期] 2013年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           31.2964                  银行
# 1                           31.3263                 房地产
# 2                          -25.2444                 计算机
# 3                          -47.6352                公用事业
# 4                           49.8858                 房地产
# ...                             ...                 ...
# 4769                            NaN                 NaN
# 4770                            NaN                 NaN
# 4771                            NaN                 NaN
# 4772                            NaN                 NaN
# 4773                            NaN                 NaN
#
#       资产总计[报告期] 2013年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2013-12-31  ...  \
# 0                          1.891741e+12                      8.0  ...
# 1                          4.792053e+11                      4.0  ...
# 2                          2.421521e+08                      3.0  ...
# 3                          1.188654e+09                      5.0  ...
# 4                          9.968160e+09                      3.0  ...
# ...                                 ...                      ...  ...
# 4769                                NaN                      0.0  ...
# 4770                                NaN                      0.0  ...
# 4771                                NaN                      0.0  ...
# 4772                                NaN                      NaN  ...
# 4773                                NaN                      NaN  ...
#
#       董事会人数[交易日期] 2013-12-31  管理层年度薪酬总额[年度] 2013[单位] 元  员工总数[交易日期] 2013-12-31  \
# 0                       18.0                75395400.0                28369.0
# 1                       11.0               112210000.0                35330.0
# 2                        9.0                 1820600.0                  243.0
# 3                       15.0                 3557000.0                  376.0
# 4                        9.0                 9480200.0                  296.0
# ...                      ...                       ...                    ...
# 4769                     0.0                       NaN                    NaN
# 4770                     0.0                       NaN                    NaN
# 4771                     0.0                       NaN                    NaN
# 4772                     NaN                       NaN                    NaN
# 4773                     NaN                       NaN                    NaN
#
#       资产负债率[报告期] 2013年报[单位] %  公司属性[交易日期] 2013-12-31  \
# 0                     94.0752                   公众企业
# 1                     77.9970                   公众企业
# 2                     40.3239                   民营企业
# 3                     47.4831                   民营企业
# 4                     57.9972                 地方国有企业
# ...                       ...                    ...
# 4769                      NaN                    NaN
# 4770                      NaN                    NaN
# 4771                      NaN                    NaN
# 4772                      NaN                    NaN
# 4773                      NaN                    NaN
#
#      大股东持股比例[日期] 2013-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2013-12-31  \
# 0                               50.200001   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                               14.700000                 丁福源,周清平,吴丁
# 2                               26.100000                  魏杰,陈少龙,何婷
# 3                               20.150000                刘丽萍,熊金芳,汪健飞
# 4                               20.309999                 朱大华,陈强,谢向荣
# ...                                   ...                        ...
# 4769                                  NaN                        NaN
# 4770                            98.750000                        NaN
# 4771                                  NaN                        NaN
# 4772                                  NaN                        NaN
# 4773                                  NaN                        NaN
#
#      净利润[报告期] 2013年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2013  \
# 0                        1.523100e+10             25.0
# 1                        1.829755e+10             25.0
# 2                        5.796750e+06             25.0
# 3                       -4.234476e+07             25.0
# 4                        6.980091e+08             25.0
# ...                               ...              ...
# 4769                              NaN              NaN
# 4770                              NaN              NaN
# 4771                              NaN              NaN
# 4772                              NaN              NaN
# 4773                              NaN              NaN
#
#       经营活动产生的现金流量净额[报告期] 2013年报[报表类型] 合并报表[单位] 元
# 0                                   9.167400e+10
# 1                                   1.923869e+09
# 2                                  -2.104231e+07
# 3                                  -1.117181e+08
# 4                                  -8.902919e+08
# ...                                          ...
# 4769                                         NaN
# 4770                                         NaN
# 4771                                         NaN
# 4772                                         NaN
# 4773                                         NaN
#
# [4774 rows x 21 columns]

# %%
WIND = WIND.drop([4772])
WIND = WIND.drop([4773])
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2013年报[报表类型] 合并报表[单位] 元  \
# 0     000001.SZ  平安银行                           -1.272000e+09
# 1     000002.SZ   万科A                           -6.080747e+07
# 2     000004.SZ  国华网安                                     NaN
# 3     000005.SZ  ST星源                                     NaN
# 4     000006.SZ  深振业A                            9.422067e+06
# ...         ...   ...                                     ...
# 4767  871553.BJ  凯腾精工                                     NaN
# 4768  871642.BJ  通易航天                                     NaN
# 4769  871857.BJ  泓禧科技                                     NaN
# 4770  871981.BJ  晶赛科技                                     NaN
# 4771  872925.BJ  锦好医疗                                     NaN
#
#       递延所得税资产减少[报告期] 2013年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2013-12-31  \
# 0                              -3.440000e+08                   15.0
# 1                              -4.721021e+08                   12.0
# 2                                        NaN                    5.0
# 3                                        NaN                    6.0
# 4                               1.373554e+08                    9.0
# ...                                      ...                    ...
# 4767                                     NaN                    0.0
# 4768                                     NaN                    0.0
# 4769                                     NaN                    0.0
# 4770                                     NaN                    0.0
# 4771                                     NaN                    0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2013年报[报表类型] 合并报表[单位] 元  \
# 0                                     9.660000e+09
# 1                                     3.472696e+09
# 2                                     1.850977e+07
# 3                                     3.084465e+07
# 4                                     8.350216e+07
# ...                                            ...
# 4767                                           NaN
# 4768                                           NaN
# 4769                                           NaN
# 4770                                           NaN
# 4771                                           NaN
#
#       营业收入(同比增长率)[报告期] 2013年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           31.2964                  银行
# 1                           31.3263                 房地产
# 2                          -25.2444                 计算机
# 3                          -47.6352                公用事业
# 4                           49.8858                 房地产
# ...                             ...                 ...
# 4767                            NaN                 NaN
# 4768                            NaN                 NaN
# 4769                            NaN                 NaN
# 4770                            NaN                 NaN
# 4771                            NaN                 NaN
#
#       资产总计[报告期] 2013年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2013-12-31  ...  \
# 0                          1.891741e+12                      8.0  ...
# 1                          4.792053e+11                      4.0  ...
# 2                          2.421521e+08                      3.0  ...
# 3                          1.188654e+09                      5.0  ...
# 4                          9.968160e+09                      3.0  ...
# ...                                 ...                      ...  ...
# 4767                                NaN                      0.0  ...
# 4768                                NaN                      0.0  ...
# 4769                                NaN                      0.0  ...
# 4770                                NaN                      0.0  ...
# 4771                                NaN                      0.0  ...
#
#       董事会人数[交易日期] 2013-12-31  管理层年度薪酬总额[年度] 2013[单位] 元  员工总数[交易日期] 2013-12-31  \
# 0                       18.0                75395400.0                28369.0
# 1                       11.0               112210000.0                35330.0
# 2                        9.0                 1820600.0                  243.0
# 3                       15.0                 3557000.0                  376.0
# 4                        9.0                 9480200.0                  296.0
# ...                      ...                       ...                    ...
# 4767                     0.0                       NaN                    NaN
# 4768                     0.0                       NaN                    NaN
# 4769                     0.0                       NaN                    NaN
# 4770                     0.0                       NaN                    NaN
# 4771                     0.0                       NaN                    NaN
#
#       资产负债率[报告期] 2013年报[单位] %  公司属性[交易日期] 2013-12-31  \
# 0                     94.0752                   公众企业
# 1                     77.9970                   公众企业
# 2                     40.3239                   民营企业
# 3                     47.4831                   民营企业
# 4                     57.9972                 地方国有企业
# ...                       ...                    ...
# 4767                      NaN                    NaN
# 4768                      NaN                    NaN
# 4769                      NaN                    NaN
# 4770                      NaN                    NaN
# 4771                      NaN                    NaN
#
#      大股东持股比例[日期] 2013-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2013-12-31  \
# 0                               50.200001   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                               14.700000                 丁福源,周清平,吴丁
# 2                               26.100000                  魏杰,陈少龙,何婷
# 3                               20.150000                刘丽萍,熊金芳,汪健飞
# 4                               20.309999                 朱大华,陈强,谢向荣
# ...                                   ...                        ...
# 4767                                  NaN                        NaN
# 4768                                  NaN                        NaN
# 4769                                  NaN                        NaN
# 4770                            98.750000                        NaN
# 4771                                  NaN                        NaN
#
#      净利润[报告期] 2013年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2013  \
# 0                        1.523100e+10             25.0
# 1                        1.829755e+10             25.0
# 2                        5.796750e+06             25.0
# 3                       -4.234476e+07             25.0
# 4                        6.980091e+08             25.0
# ...                               ...              ...
# 4767                              NaN              NaN
# 4768                              NaN              NaN
# 4769                              NaN              NaN
# 4770                              NaN              NaN
# 4771                              NaN              NaN
#
#       经营活动产生的现金流量净额[报告期] 2013年报[报表类型] 合并报表[单位] 元
# 0                                   9.167400e+10
# 1                                   1.923869e+09
# 2                                  -2.104231e+07
# 3                                  -1.117181e+08
# 4                                  -8.902919e+08
# ...                                          ...
# 4767                                         NaN
# 4768                                         NaN
# 4769                                         NaN
# 4770                                         NaN
# 4771                                         NaN
#
# [4772 rows x 21 columns]

# %%
WIND['证券代码'] = WIND['证券代码'].str[0:6]
WIND
# Out:
#         证券代码  证券简称  递延所得税负债增加[报告期] 2013年报[报表类型] 合并报表[单位] 元  \
# 0     000001  平安银行                           -1.272000e+09
# 1     000002   万科A                           -6.080747e+07
# 2     000004  国华网安                                     NaN
# 3     000005  ST星源                                     NaN
# 4     000006  深振业A                            9.422067e+06
# ...      ...   ...                                     ...
# 4767  871553  凯腾精工                                     NaN
# 4768  871642  通易航天                                     NaN
# 4769  871857  泓禧科技                                     NaN
# 4770  871981  晶赛科技                                     NaN
# 4771  872925  锦好医疗                                     NaN
#
#       递延所得税资产减少[报告期] 2013年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2013-12-31  \
# 0                              -3.440000e+08                   15.0
# 1                              -4.721021e+08                   12.0
# 2                                        NaN                    5.0
# 3                                        NaN                    6.0
# 4                               1.373554e+08                    9.0
# ...                                      ...                    ...
# 4767                                     NaN                    0.0
# 4768                                     NaN                    0.0
# 4769                                     NaN                    0.0
# 4770                                     NaN                    0.0
# 4771                                     NaN                    0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2013年报[报表类型] 合并报表[单位] 元  \
# 0                                     9.660000e+09
# 1                                     3.472696e+09
# 2                                     1.850977e+07
# 3                                     3.084465e+07
# 4                                     8.350216e+07
# ...                                            ...
# 4767                                           NaN
# 4768                                           NaN
# 4769                                           NaN
# 4770                                           NaN
# 4771                                           NaN
#
#       营业收入(同比增长率)[报告期] 2013年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           31.2964                  银行
# 1                           31.3263                 房地产
# 2                          -25.2444                 计算机
# 3                          -47.6352                公用事业
# 4                           49.8858                 房地产
# ...                             ...                 ...
# 4767                            NaN                 NaN
# 4768                            NaN                 NaN
# 4769                            NaN                 NaN
# 4770                            NaN                 NaN
# 4771                            NaN                 NaN
#
#       资产总计[报告期] 2013年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2013-12-31  ...  \
# 0                          1.891741e+12                      8.0  ...
# 1                          4.792053e+11                      4.0  ...
# 2                          2.421521e+08                      3.0  ...
# 3                          1.188654e+09                      5.0  ...
# 4                          9.968160e+09                      3.0  ...
# ...                                 ...                      ...  ...
# 4767                                NaN                      0.0  ...
# 4768                                NaN                      0.0  ...
# 4769                                NaN                      0.0  ...
# 4770                                NaN                      0.0  ...
# 4771                                NaN                      0.0  ...
#
#       董事会人数[交易日期] 2013-12-31  管理层年度薪酬总额[年度] 2013[单位] 元  员工总数[交易日期] 2013-12-31  \
# 0                       18.0                75395400.0                28369.0
# 1                       11.0               112210000.0                35330.0
# 2                        9.0                 1820600.0                  243.0
# 3                       15.0                 3557000.0                  376.0
# 4                        9.0                 9480200.0                  296.0
# ...                      ...                       ...                    ...
# 4767                     0.0                       NaN                    NaN
# 4768                     0.0                       NaN                    NaN
# 4769                     0.0                       NaN                    NaN
# 4770                     0.0                       NaN                    NaN
# 4771                     0.0                       NaN                    NaN
#
#       资产负债率[报告期] 2013年报[单位] %  公司属性[交易日期] 2013-12-31  \
# 0                     94.0752                   公众企业
# 1                     77.9970                   公众企业
# 2                     40.3239                   民营企业
# 3                     47.4831                   民营企业
# 4                     57.9972                 地方国有企业
# ...                       ...                    ...
# 4767                      NaN                    NaN
# 4768                      NaN                    NaN
# 4769                      NaN                    NaN
# 4770                      NaN                    NaN
# 4771                      NaN                    NaN
#
#      大股东持股比例[日期] 2013-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2013-12-31  \
# 0                               50.200001   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                               14.700000                 丁福源,周清平,吴丁
# 2                               26.100000                  魏杰,陈少龙,何婷
# 3                               20.150000                刘丽萍,熊金芳,汪健飞
# 4                               20.309999                 朱大华,陈强,谢向荣
# ...                                   ...                        ...
# 4767                                  NaN                        NaN
# 4768                                  NaN                        NaN
# 4769                                  NaN                        NaN
# 4770                            98.750000                        NaN
# 4771                                  NaN                        NaN
#
#      净利润[报告期] 2013年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2013  \
# 0                        1.523100e+10             25.0
# 1                        1.829755e+10             25.0
# 2                        5.796750e+06             25.0
# 3                       -4.234476e+07             25.0
# 4                        6.980091e+08             25.0
# ...                               ...              ...
# 4767                              NaN              NaN
# 4768                              NaN              NaN
# 4769                              NaN              NaN
# 4770                              NaN              NaN
# 4771                              NaN              NaN
#
#       经营活动产生的现金流量净额[报告期] 2013年报[报表类型] 合并报表[单位] 元
# 0                                   9.167400e+10
# 1                                   1.923869e+09
# 2                                  -2.104231e+07
# 3                                  -1.117181e+08
# 4                                  -8.902919e+08
# ...                                          ...
# 4767                                         NaN
# 4768                                         NaN
# 4769                                         NaN
# 4770                                         NaN
# 4771                                         NaN
#
# [4772 rows x 21 columns]

# %%
WIND.isnull().sum()
# Out:
# 证券代码                                               0
# 证券简称                                               0
# 递延所得税负债增加[报告期] 2013年报[报表类型] 合并报表[单位] 元          3608
# 递延所得税资产减少[报告期] 2013年报[报表类型] 合并报表[单位] 元          1327
# 高管人数[交易日期] 2013-12-31                              0
# 支付给职工以及为职工支付的现金[报告期] 2013年报[报表类型] 合并报表[单位] 元     844
# 营业收入(同比增长率)[报告期] 2013年报[单位] %                   1178
# 所属申万行业名称[行业级别] 一级行业                              163
# 资产总计[报告期] 2013年报[报表类型] 合并报表[单位] 元                789
# 独立董事人数[交易日期] 2013-12-31                            0
# 非独立董事人数[交易日期] 2013-12-31                           0
# 董事会人数[交易日期] 2013-12-31                             0
# 管理层年度薪酬总额[年度] 2013[单位] 元                        2279
# 员工总数[交易日期] 2013-12-31                           1232
# 资产负债率[报告期] 2013年报[单位] %                          842
# 公司属性[交易日期] 2013-12-31                           2284
# 大股东持股比例[日期] 2013-12-31[排名] 第1名[单位] %            2014
# 公司监事(历任)[交易日期] 2013-12-31                       2013
# 净利润[报告期] 2013年报[报表类型] 合并报表[单位] 元                 832
# 年末所得税率[年度] 2013                                 1539
# 经营活动产生的现金流量净额[报告期] 2013年报[报表类型] 合并报表[单位] 元       840
# dtype: int64

# %% [markdown]
# ### MASTER_Preprocessing

# %%
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0       证券代码      统计截止日期               统计口径   未领取薪酬监管层人数
# 1        NaN         NaN                NaN            人
# 2     000001  2013-12-31                  2          5.0
# 3     000001  2013-12-31                  1          5.0
# 4     000002  2013-12-31                  1          0.0
# ...      ...         ...                ...          ...
# 5069  900953  2013-12-31                  2          7.0
# 5070  900956  2013-12-31                  2          5.0
# 5071  900956  2013-12-31                  1          5.0
# 5072  900957  2013-12-31                  1          0.0
# 5073  900957  2013-12-31                  2          0.0
#
# [5074 rows x 4 columns]

# %%
MASTER = MASTER.drop([0])
MASTER = MASTER.drop([1])
MASTER = MASTER.reset_index(drop =True)
MASTER = MASTER[(MASTER['StatisticalCaliber'] != '2')]
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 1     000001  2013-12-31                  1          5.0
# 2     000002  2013-12-31                  1          0.0
# 5     000004  2013-12-31                  1          5.0
# 7     000005  2013-12-31                  1          3.0
# 8     000006  2013-12-31                  1          3.0
# ...      ...         ...                ...          ...
# 5062  900950  2013-12-31                  1          3.0
# 5064  900951  2013-12-31                  1          8.0
# 5066  900953  2013-12-31                  1          6.0
# 5069  900956  2013-12-31                  1          5.0
# 5070  900957  2013-12-31                  1          0.0
#
# [2536 rows x 4 columns]

# %%
MASTER.shape
# Out:
# (2536, 4)

# %% [markdown]
# ### Merge CSMAR_and_WIND_and_MASTER

# %%
merge_data = pd.merge(CSMAR, WIND, left_on='code', right_on='证券代码')
merge_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2013-12-31                A         4809000000.0
# 1  000002        万科A       2013-12-31                A        5993461378.06
# 2  000004       国华网安       2013-12-31                A           5406254.88
# 3  000005      ST 星源       2013-12-31                A                  0.0
# 4  000006       深振业A       2013-12-31                A         228266054.74
# 5  000007     *ST 全新       2013-12-31                A           3550190.26
# 6  000008       神州高铁       2013-12-31                A           7363135.79
# 7  000009       中国宝安       2013-12-31                A          60114193.04
# 8  000010       美丽生态       2013-12-31                A           5696588.27
# 9  000011       深物业A       2013-12-31                A         122093910.62
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2013-12-31             N       2013-12-31           29782.0
# 1       2013-12-31             N       2013-12-31        23828261.0
# 2       2013-12-31             N       2013-12-31            1725.0
# 3       2013-12-31             N       2013-12-31               0.0
# 4       2013-12-31             N       2013-12-31        11753463.0
# 5       2013-12-31             N       2013-12-31        25152222.0
# 6       2013-12-31             N       2013-12-31             180.0
# 7       2013-12-31             Y       2013-12-31          146402.0
# 8       2013-12-31             N       2013-12-31               0.0
# 9       2013-12-31             N       2013-12-31               0.0
#
#   CG_Capchg-Nshrttl  ... 董事会人数[交易日期] 2013-12-31 管理层年度薪酬总额[年度] 2013[单位] 元  \
# 0      8197360665.0  ...                   18.0               75395400.0
# 1     11014968919.0  ...                   11.0              112210000.0
# 2        83976684.0  ...                    9.0                1820600.0
# 3       914333607.0  ...                   15.0                3557000.0
# 4      1349995046.0  ...                    9.0                9480200.0
# 5       230965363.0  ...                    8.0                2767000.0
# 6       303601640.0  ...                    7.0                2309800.0
# 7      1254363108.0  ...                    8.0               10826900.0
# 8       588069788.0  ...                   11.0                2710000.0
# 9       595979092.0  ...                    9.0                6778500.0
#
#    员工总数[交易日期] 2013-12-31  资产负债率[报告期] 2013年报[单位] %  公司属性[交易日期] 2013-12-31  \
# 0                28369.0                  94.0752                   公众企业
# 1                35330.0                  77.9970                   公众企业
# 2                  243.0                  40.3239                   民营企业
# 3                  376.0                  47.4831                   民营企业
# 4                  296.0                  57.9972                 地方国有企业
# 5                  674.0                  46.2754                   民营企业
# 6                 1622.0                  10.0605                   民营企业
# 7                 7358.0                  62.8798                   公众企业
# 8                  596.0                  35.8152                   民营企业
# 9                 3110.0                  53.4334                 地方国有企业
#
#    大股东持股比例[日期] 2013-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2013-12-31  \
# 0                             50.200001   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                             14.700000                 丁福源,周清平,吴丁
# 2                             26.100000                  魏杰,陈少龙,何婷
# 3                             20.150000                刘丽萍,熊金芳,汪健飞
# 4                             20.309999                 朱大华,陈强,谢向荣
# 5                             17.410000                  王岱,韩军,冯幼红
# 6                             62.709999                  杨建,祁萌,袁淦明
# 7                             12.340000                 龚明,贺国奇,马小虎
# 8                             29.990000                 张晓鹏,孙永平,翟禹
# 9                             54.330002        戴先华,王秋平,王秀颜,张戈坚,张世磊
#
#   净利润[报告期] 2013年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2013  \
# 0                     1.523100e+10             25.0
# 1                     1.829755e+10             25.0
# 2                     5.796750e+06             25.0
# 3                    -4.234476e+07             25.0
# 4                     6.980091e+08             25.0
# 5                     1.883060e+07             25.0
# 6                     2.275795e+07             25.0
# 7                     4.441512e+08             25.0
# 8                     3.810760e+06             25.0
# 9                     3.008406e+08             25.0
#
#    经营活动产生的现金流量净额[报告期] 2013年报[报表类型] 合并报表[单位] 元
# 0                                9.167400e+10
# 1                                1.923869e+09
# 2                               -2.104231e+07
# 3                               -1.117181e+08
# 4                               -8.902919e+08
# 5                                1.928610e+08
# 6                                6.677981e+07
# 7                                8.041946e+07
# 8                                4.239215e+06
# 9                                1.104243e+08
#
# [10 rows x 31 columns]

# %%
full_data = pd.merge(merge_data, MASTER, left_on='code', right_on='Symbol')
full_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2013-12-31                A         4809000000.0
# 1  000002        万科A       2013-12-31                A        5993461378.06
# 2  000004       国华网安       2013-12-31                A           5406254.88
# 3  000005      ST 星源       2013-12-31                A                  0.0
# 4  000006       深振业A       2013-12-31                A         228266054.74
# 5  000007     *ST 全新       2013-12-31                A           3550190.26
# 6  000008       神州高铁       2013-12-31                A           7363135.79
# 7  000009       中国宝安       2013-12-31                A          60114193.04
# 8  000010       美丽生态       2013-12-31                A           5696588.27
# 9  000011       深物业A       2013-12-31                A         122093910.62
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2013-12-31             N       2013-12-31           29782.0
# 1       2013-12-31             N       2013-12-31        23828261.0
# 2       2013-12-31             N       2013-12-31            1725.0
# 3       2013-12-31             N       2013-12-31               0.0
# 4       2013-12-31             N       2013-12-31        11753463.0
# 5       2013-12-31             N       2013-12-31        25152222.0
# 6       2013-12-31             N       2013-12-31             180.0
# 7       2013-12-31             Y       2013-12-31          146402.0
# 8       2013-12-31             N       2013-12-31               0.0
# 9       2013-12-31             N       2013-12-31               0.0
#
#   CG_Capchg-Nshrttl  ... 公司属性[交易日期] 2013-12-31  \
# 0      8197360665.0  ...                  公众企业
# 1     11014968919.0  ...                  公众企业
# 2        83976684.0  ...                  民营企业
# 3       914333607.0  ...                  民营企业
# 4      1349995046.0  ...                地方国有企业
# 5       230965363.0  ...                  民营企业
# 6       303601640.0  ...                  民营企业
# 7      1254363108.0  ...                  公众企业
# 8       588069788.0  ...                  民营企业
# 9       595979092.0  ...                地方国有企业
#
#   大股东持股比例[日期] 2013-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2013-12-31  \
# 0                            50.200001   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                            14.700000                 丁福源,周清平,吴丁
# 2                            26.100000                  魏杰,陈少龙,何婷
# 3                            20.150000                刘丽萍,熊金芳,汪健飞
# 4                            20.309999                 朱大华,陈强,谢向荣
# 5                            17.410000                  王岱,韩军,冯幼红
# 6                            62.709999                  杨建,祁萌,袁淦明
# 7                            12.340000                 龚明,贺国奇,马小虎
# 8                            29.990000                 张晓鹏,孙永平,翟禹
# 9                            54.330002        戴先华,王秋平,王秀颜,张戈坚,张世磊
#
#    净利润[报告期] 2013年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2013  \
# 0                      1.523100e+10             25.0
# 1                      1.829755e+10             25.0
# 2                      5.796750e+06             25.0
# 3                     -4.234476e+07             25.0
# 4                      6.980091e+08             25.0
# 5                      1.883060e+07             25.0
# 6                      2.275795e+07             25.0
# 7                      4.441512e+08             25.0
# 8                      3.810760e+06             25.0
# 9                      3.008406e+08             25.0
#
#    经营活动产生的现金流量净额[报告期] 2013年报[报表类型] 合并报表[单位] 元  Symbol     Enddate  \
# 0                                9.167400e+10  000001  2013-12-31
# 1                                1.923869e+09  000002  2013-12-31
# 2                               -2.104231e+07  000004  2013-12-31
# 3                               -1.117181e+08  000005  2013-12-31
# 4                               -8.902919e+08  000006  2013-12-31
# 5                                1.928610e+08  000007  2013-12-31
# 6                                6.677981e+07  000008  2013-12-31
# 7                                8.041946e+07  000009  2013-12-31
# 8                                4.239215e+06  000010  2013-12-31
# 9                                1.104243e+08  000011  2013-12-31
#
#    StatisticalCaliber  UnpaidNumber
# 0                   1           5.0
# 1                   1           0.0
# 2                   1           5.0
# 3                   1           3.0
# 4                   1           3.0
# 5                   1           0.0
# 6                   1           0.0
# 7                   1           0.0
# 8                   1           0.0
# 9                   1           4.0
#
# [10 rows x 35 columns]

# %%
full_data.shape
# Out:
# (2447, 35)

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2013/full_data.xlsx')

# %% [markdown]
# ### 1：剔除金融保险类、ST、* ST类上市公司

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加[报告期] 2013年报[报表类型] 合并报表[单位] 元',
#        '递延所得税资产减少[报告期] 2013年报[报表类型] 合并报表[单位] 元', '高管人数[交易日期] 2013-12-31',
#        '支付给职工以及为职工支付的现金[报告期] 2013年报[报表类型] 合并报表[单位] 元',
#        '营业收入(同比增长率)[报告期] 2013年报[单位] %', '所属申万行业名称[行业级别] 一级行业',
#        '资产总计[报告期] 2013年报[报表类型] 合并报表[单位] 元', '独立董事人数[交易日期] 2013-12-31',
#        '非独立董事人数[交易日期] 2013-12-31', '董事会人数[交易日期] 2013-12-31',
#        '管理层年度薪酬总额[年度] 2013[单位] 元', '员工总数[交易日期] 2013-12-31',
#        '资产负债率[报告期] 2013年报[单位] %', '公司属性[交易日期] 2013-12-31',
#        '大股东持股比例[日期] 2013-12-31[排名] 第1名[单位] %', '公司监事(历任)[交易日期] 2013-12-31',
#        '净利润[报告期] 2013年报[报表类型] 合并报表[单位] 元', '年末所得税率[年度] 2013',
#        '经营活动产生的现金流量净额[报告期] 2013年报[报表类型] 合并报表[单位] 元', 'Symbol', 'Enddate',
#        'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.columns = ['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
       'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
       'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
       '证券简称', '递延所得税负债增加',
       '递延所得税资产减少', '高管人数',
       '支付给职工以及为职工支付的现金',
       '营业收入', '所属申万行业名称',
       '资产总计', '独立董事人数',
       '非独立董事人数', '董事会人数',
       '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性',
       '大股东持股比例', '公司监事',
       '净利润', '年末所得税率',
       '经营活动产生的现金流量净额', 'Symbol', 'Enddate',
       'StatisticalCaliber', 'UnpaidNumber']
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.shape
# Out:
# (2447, 35)

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '银行')]
full_data = full_data[(full_data['所属申万行业名称'] != '非银金融')]

full_data['check_ST'] = full_data['short_name'].str[0:2]
full_data['check_*ST'] = full_data['short_name'].str[0:3]
full_data = full_data[(full_data['check_ST'] != 'ST')]
full_data = full_data[(full_data['check_*ST'] != '*ST')]

# %%
full_data.shape
# Out:
# (2216, 37)

# %% [markdown]
# ### 2：剔除员工数量不足 100人的公司,这部分公司可能存在经营异常或者数据披露错误

# %%
full_data = full_data[(full_data['员工总数'] > 100)]

# %%
full_data.shape
# Out:
# (2188, 37)

# %% [markdown]
# ### 3：剔除管理层平均工资比普通员工平均工资低的公司,因为这类公司披露的高管薪酬可能仅是津贴,或者数据错误：

# %% [markdown]
# - 管理层平均工资 = 管理层年度薪酬总数/（非独立董事人数+公司监事+高管人数-UnpaidNumber）
# - 普通员工平均工资 = （支付给职工以及为职工支付的现金-管理层年度薪酬总数）/ （员工总数-（非独立董事+公司监事+高管人数））

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST'],
#       dtype='object')

# %%
full_data['人数']=full_data['公司监事'].apply(lambda x: len(x.split(',')))

# %%
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2013-12-31                A        5993461378.06
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2013-12-31             N       2013-12-31        23828261.0
#
#   CG_Capchg-Nshrttl  ...           净利润 年末所得税率  经营活动产生的现金流量净额  Symbol  \
# 1     11014968919.0  ...  1.829755e+10   25.0   1.923869e+09  000002
#
#       Enddate  StatisticalCaliber  UnpaidNumber check_ST  check_*ST  人数
# 1  2013-12-31                   1           0.0       万科        万科A   3
#
# [1 rows x 38 columns]

# %%
full_data['管理层平均工资'] = full_data['管理层年度薪酬总额'] / (
   full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数'] 
      - full_data['UnpaidNumber']
)
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2013-12-31                A        5993461378.06
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2013-12-31             N       2013-12-31        23828261.0
#
#   CG_Capchg-Nshrttl  ... 年末所得税率 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11014968919.0  ...   25.0  1.923869e+09  000002  2013-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST check_*ST  人数         管理层平均工资
# 1                   1           0.0        万科       万科A   3  5100454.545455
#
# [1 rows x 39 columns]

# %%
full_data['普通员工平均工资'] = (full_data ['支付给职工以及为职工支付的现金'] 
   - full_data['管理层年度薪酬总额']) / (
      full_data['员工总数'] - (
         full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数']
      )
)
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2013-12-31                A        5993461378.06
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2013-12-31             N       2013-12-31        23828261.0
#
#   CG_Capchg-Nshrttl  ... 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11014968919.0  ...  1.923869e+09  000002  2013-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST  check_*ST 人数         管理层平均工资  \
# 1                   1           0.0        万科        万科A  3  5100454.545455
#
#        普通员工平均工资
# 1  95176.325642
#
# [1 rows x 40 columns]

# %%
full_data = full_data[(full_data["管理层平均工资"] > full_data["普通员工平均工资"])]

# %%
full_data.shape
# Out:
# (2146, 40)

# %% [markdown]
# ### 4：剔除企业实际所得税率小于0和大于1的样本

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data = full_data[(full_data['年末所得税率'] <100) &
   (full_data['年末所得税率'] >0)]

# %%
full_data.shape
# Out:
# (2099, 40)

# %% [markdown]
# ### 5：由于2015 年新增了轻工、纺织、机械和汽车四大行业作为加速折旧政策试点,如果将这部分个业作为2014年加速折旧政策的控制组可能对结果产生偏差,为此还剔除了享受2015年加速折旧政策的公司样本

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '轻工制造')]
full_data = full_data[(full_data['所属申万行业名称'] != '纺织服装')]
full_data = full_data[(full_data['所属申万行业名称'] != '机械设备')]
full_data = full_data[(full_data['所属申万行业名称'] != '汽车')]

# %%
full_data.shape
# Out:
# (1732, 40)

# %% [markdown]
# ### 6：剔除关键变量缺失的样本

# %%
miss_data = pd.DataFrame(full_data.isnull().sum(), columns=['Missing Data Count'])
miss_data
# Out:
#                       Missing Data Count
# code                                   0
# short_name                             0
# FS_Comins-Accper                       0
# FS_Comins-Typrep                       0
# FS_Comins-B002100000                   0
# BF_EXPAY-EndDate                       0
# BF_EXPAY-Same                          9
# CG_Capchg-Reptdt                       0
# CG_Capchg-Nshrsms                      0
# CG_Capchg-Nshrttl                      0
# 证券代码                                   0
# 证券简称                                   0
# 递延所得税负债增加                           1045
# 递延所得税资产减少                             60
# 高管人数                                   0
# 支付给职工以及为职工支付的现金                        0
# 营业收入                                   0
# 所属申万行业名称                               0
# 资产总计                                   0
# 独立董事人数                                 0
# 非独立董事人数                                0
# 董事会人数                                  0
# 管理层年度薪酬总额                              0
# 员工总数                                   0
# 资产负债率                                  0
# 公司属性                                  22
# 大股东持股比例                                0
# 公司监事                                   0
# 净利润                                    0
# 年末所得税率                                 0
# 经营活动产生的现金流量净额                          0
# Symbol                                 0
# Enddate                                0
# StatisticalCaliber                     0
# UnpaidNumber                           0
# check_ST                               0
# check_*ST                              0
# 人数                                     0
# 管理层平均工资                                0
# 普通员工平均工资                               0

# %%
miss_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2013/miss_data.xlsx')

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2013/full_data2.xlsx')

# %%
full_data.dropna(axis=0,inplace=True)

# %%
full_data.shape
# Out:
# (664, 40)

# %% [markdown]
# ### 8：final

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.columns = ['代码', '简称', '会计期间', '报表类型',
       '所得税费用', '截止日期', '董事长和总经理是否同一人',
       '统计截止日期', '监管层持股数', '总股数', '证券代码',
       '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
       '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
       'Symbol', 'Enddate', 'StatisticalCaliber', '未领取薪酬监管层人数', 'check_ST',
       'check_*ST', '人数', '管理层平均工资', '普通员工平均工资']
full_data.columns
# Out:
# Index(['代码', '简称', '会计期间', '报表类型', '所得税费用', '截止日期', '董事长和总经理是否同一人', '统计截止日期',
#        '监管层持股数', '总股数', '证券代码', '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数',
#        '支付给职工以及为职工支付的现金', '营业收入', '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数',
#        '董事会人数', '管理层年度薪酬总额', '员工总数', '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润',
#        '年末所得税率', '经营活动产生的现金流量净额', 'Symbol', 'Enddate', 'StatisticalCaliber',
#        '未领取薪酬监管层人数', 'check_ST', 'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2013/2013_final_1.xlsx')

# %% [markdown]
# ### .to_table

# %%
import math

def get_log(full_data):
   result_log = []
   list_log = full_data.values
   for i in list_log:
      result_log_n = math.log(i)
      result_log.append(result_log_n)
   return result_log

list_result = get_log(full_data['管理层平均工资'])
full_data['lnAMW'] = list_result

list_result = get_log(full_data['普通员工平均工资'])
full_data['lnAEW'] = list_result

full_data['收入不平等'] = full_data['管理层平均工资'] / full_data['普通员工平均工资']
list_result = get_log(full_data['收入不平等'])
full_data['lnWFI'] = list_result

full_data['ETR'] = full_data['所得税费用'] / (
   (
      full_data['所得税费用'] + full_data['净利润'] - (
         full_data['递延所得税负债增加'] + full_data['递延所得税资产减少']
      )/ full_data['年末所得税率']
   )
)

list_result = get_log(full_data['资产总计'])
full_data['lnSize'] = list_result

full_data['OCF'] = full_data['经营活动产生的现金流量净额'] / full_data['资产总计']

full_data['Lev'] = full_data['资产负债率']/100

full_data['Growth'] = full_data['营业收入']/100

full_data['Top1'] = full_data['大股东持股比例']

full_data['indepent'] = (full_data['独立董事人数'] / full_data['董事会人数'])*100

full_data['MH'] = (full_data['监管层持股数'] / full_data['总股数'])*100

full_data["Dual"] = np.where(full_data["董事长和总经理是否同一人"] =='Y', "1", "0")

full_data['国有判断'] = full_data['公司属性'].str[2:4]
full_data['SOE'] = np.where(full_data['国有判断'] =='国有', "1", "0")

# %%
full_data.head(1)
# Out:
#        代码   简称        会计期间 报表类型          所得税费用        截止日期 董事长和总经理是否同一人  \
# 1  000002  万科A  2013-12-31    A  5993461378.06  2013-12-31            N
#
#        统计截止日期      监管层持股数            总股数  ...     lnSize       OCF      Lev  \
# 1  2013-12-31  23828261.0  11014968919.0  ...  26.895395  0.004015  0.77997
#
#      Growth  Top1   indepent        MH Dual  国有判断  SOE
# 1  0.313263  14.7  36.363636  0.216326    0    企业    0
#
# [1 rows x 55 columns]

# %%
full_data.shape
# Out:
# (664, 55)

# %% [markdown]
# ### 对所有连续变量在上下1%水平上进行缩尾处理

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/processed/2013_final_data.xlsx')

# %%
full_data['lnWFI'].describe()
# Out:
# count    664.000000
# mean       1.423582
# std        0.598883
# min        0.024707
# 25%        1.031535
# 50%        1.361330
# 75%        1.794587
# max        3.981354
# Name: lnWFI, dtype: float64
