# %% [markdown]
# ## 2017_Preprocessing

# %%
# import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read 2010_data

CSMAR = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2017/CSMAR.xlsx')

WIND = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2017/WIND.xlsx')

MASTER = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2017/MASTER.xlsx')
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CSMAR.dtypes
# Out:
# code                    object
# short_name              object
# FS_Comins-Accper        object
# FS_Comins-Typrep        object
# FS_Comins-B002100000    object
# BF_EXPAY-EndDate        object
# BF_EXPAY-Same           object
# CG_Capchg-Reptdt        object
# CG_Capchg-Nshrsms       object
# CG_Capchg-Nshrttl       object
# dtype: object

# %%
WIND.dtypes
# Out:
# 证券代码                                                    object
# 证券简称                                                    object
# 递延所得税负债增加\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元          float64
# 递延所得税资产减少\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元          float64
# 高管人数\n[交易日期] 2017-12-31\n[单位] 1                        float64
# 支付给职工以及为职工支付的现金\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元    float64
# 营业收入(同比增长率)\n[报告期] 2017年报\n[单位] 1%                     float64
# 所属申万行业名称\n[行业级别] 一级行业\n[单位] 1                           object
# 资产总计\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元               float64
# 独立董事人数\n[交易日期] 2017-12-31\n[单位] 1                      float64
# 非独立董事人数\n[交易日期] 2017-12-31\n[单位] 1                     float64
# 董事会人数\n[交易日期] 2017-12-31\n[单位] 1                       float64
# 管理层年度薪酬总额\n[年度] 2017\n[单位] 1元                          float64
# 员工总数\n[交易日期] 2017-12-31\n[单位] 1                        float64
# 资产负债率\n[报告期] 2017年报\n[单位] 1%                           float64
# 公司属性\n[交易日期] 2017-12-31\n[单位] 1                         object
# 大股东持股比例\n[日期] 2017-12-31\n[排名] 第1名\n[单位] 1%            float64
# 公司监事(历任)\n[交易日期] 2017-12-31\n[单位] 1                     object
# 净利润\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元                float64
# 年末所得税率\n[年度] 2017\n[单位] 1                              float64
# 经营活动产生的现金流量净额\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元      float64
# dtype: object

# %%
MASTER.dtypes
# Out:
# Symbol                object
# Enddate               object
# StatisticalCaliber    object
# UnpaidNumber          object
# dtype: object

# %% [markdown]
# ### CSMAR_Preprocessing

# %%
CSMAR.head(5)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0      代码         简称             会计期间             报表类型                所得税费用
# 1    沒有单位       沒有单位             没有单位             没有单位                    元
# 2  000001       平安银行       2017-12-31                A         6968000000.0
# 3  000002        万科A       2017-12-31                A       13933565335.34
# 4  000004       国华网安       2017-12-31                A            3824189.8
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0             截止日期  董事长与总经理是否同一人           统计截止日期         其中：监管层持股数
# 1             没有单位          没有单位             没有单位                 股
# 2       2017-12-31             N       2017-12-31           23866.0
# 3       2017-12-31             Y       2017-12-31         9026490.0
# 4       2017-12-31             Y       2017-12-31          913500.0
#
#   CG_Capchg-Nshrttl
# 0               总股数
# 1                 股
# 2     17170411366.0
# 3     11039152001.0
# 4        83976684.0

# %%
CSMAR = CSMAR.drop([0])
CSMAR = CSMAR.drop([1])
CSMAR = CSMAR.reset_index(drop= True)
# CSMAR = CSMAR.drop(["TRD_Capchg-Shrchgdt", "TRD_Capchg-Nshrttl"], axis=1)
CSMAR.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2017-12-31                A         6968000000.0
# 1  000002        万科A       2017-12-31                A       13933565335.34
# 2  000004       国华网安       2017-12-31                A            3824189.8
# 3  000005      ST 星源       2017-12-31                A          35022615.46
# 4  000006       深振业A       2017-12-31                A         139744237.42
# 5  000007     *ST 全新       2017-12-31                A           1026801.56
# 6  000008       神州高铁       2017-12-31                A         129481987.68
# 7  000009       中国宝安       2017-12-31                A          56227086.59
# 8  000010       美丽生态       2017-12-31                A           -2729050.4
# 9  000011       深物业A       2017-12-31                A          203784886.4
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2017-12-31             N       2017-12-31           23866.0
# 1       2017-12-31             Y       2017-12-31         9026490.0
# 2       2017-12-31             Y       2017-12-31          913500.0
# 3       2017-12-31             N       2017-12-31               0.0
# 4       2017-12-31             N       2017-12-31         1727639.0
# 5       2017-12-31             N       2017-12-31        37500000.0
# 6       2017-12-31             N       2017-12-31       172828165.0
# 7       2017-12-31             Y       2017-12-31         5674555.0
# 8       2017-12-31             N       2017-12-31               0.0
# 9       2017-12-31             N       2017-12-31               0.0
#
#   CG_Capchg-Nshrttl
# 0     17170411366.0
# 1     11039152001.0
# 2        83976684.0
# 3      1058536842.0
# 4      1349995046.0
# 5       346448044.0
# 6      2818329809.0
# 7      2149344971.0
# 8       819854713.0
# 9       595979092.0

# %%
CSMAR.isnull().sum()
# Out:
# code                      0
# short_name                0
# FS_Comins-Accper          0
# FS_Comins-Typrep          0
# FS_Comins-B002100000     35
# BF_EXPAY-EndDate        171
# BF_EXPAY-Same           222
# CG_Capchg-Reptdt        171
# CG_Capchg-Nshrsms       171
# CG_Capchg-Nshrttl       171
# dtype: int64

# %%
CSMAR.shape
# Out:
# (3684, 10)

# %% [markdown]
# ### WIND_Preprocessing

# %%
WIND.head(5)
# Out:
#         证券代码  证券简称  递延所得税负债增加\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元  \
# 0  000001.SZ  平安银行                                            NaN
# 1  000002.SZ   万科A                                  -1.109681e+08
# 2  000004.SZ  国华网安                                   3.463150e+06
# 3  000005.SZ  ST星源                                  -3.420000e+05
# 4  000006.SZ  深振业A                                   6.765542e+05
#
#    递延所得税资产减少\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元  \
# 0                                  -7.252000e+09
# 1                                  -2.443367e+09
# 2                                  -7.676307e+05
# 3                                  -7.187767e+06
# 4                                  -4.431963e+07
#
#    高管人数\n[交易日期] 2017-12-31\n[单位] 1  \
# 0                              9.0
# 1                              5.0
# 2                              3.0
# 3                              6.0
# 4                              7.0
#
#    支付给职工以及为职工支付的现金\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元  \
# 0                                       1.434500e+10
# 1                                       9.243603e+09
# 2                                       1.273144e+07
# 3                                       7.395553e+07
# 4                                       1.120988e+08
#
#    营业收入(同比增长率)\n[报告期] 2017年报\n[单位] 1% 所属申万行业名称\n[行业级别] 一级行业\n[单位] 1  \
# 0                             -1.7908                            银行
# 1                              1.0063                           房地产
# 2                            -51.8178                           计算机
# 3                             10.1811                          公用事业
# 4                            -11.8903                           房地产
#
#    资产总计\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元  \
# 0                              3.248474e+12
# 1                              1.165347e+12
# 2                              2.688443e+08
# 3                              2.912100e+09
# 4                              1.313993e+10
#
#    独立董事人数\n[交易日期] 2017-12-31\n[单位] 1  ...  董事会人数\n[交易日期] 2017-12-31\n[单位] 1  \
# 0                                5.0  ...                              14.0
# 1                                4.0  ...                              11.0
# 2                                3.0  ...                               9.0
# 3                                5.0  ...                              15.0
# 4                                3.0  ...                               7.0
#
#    管理层年度薪酬总额\n[年度] 2017\n[单位] 1元  员工总数\n[交易日期] 2017-12-31\n[单位] 1  \
# 0                     51522800.0                          31168.0
# 1                     64100000.0                          77708.0
# 2                      1583400.0                            172.0
# 3                      5341000.0                            705.0
# 4                      9593300.0                            370.0
#
#    资产负债率\n[报告期] 2017年报\n[单位] 1%  公司属性\n[交易日期] 2017-12-31\n[单位] 1  \
# 0                       93.1644                             公众企业
# 1                       83.9813                             公众企业
# 2                       31.5247                             民营企业
# 3                       51.7747                             民营企业
# 4                       56.5648                           地方国有企业
#
#   大股东持股比例\n[日期] 2017-12-31\n[排名] 第1名\n[单位] 1%  \
# 0                                   49.560001
# 1                                   29.379999
# 2                                   28.430000
# 3                                   17.410000
# 4                                   21.930000
#
#    公司监事(历任)\n[交易日期] 2017-12-31\n[单位] 1  \
# 0             邱伟,车国宝,周建国,骆向东,甘煜,王群,储一昀
# 1                            周清平,解冻,郑英
# 2                          唐银萍,林绮霞,阮旭里
# 3                  刘丽萍,熊金芳,汪健飞,刘敏儿,吕卫东
# 4                            陈强,谢向荣,张磊
#
#   净利润\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元  年末所得税率\n[年度] 2017\n[单位] 1  \
# 0                            2.318900e+10                       25.0
# 1                            3.720839e+10                       25.0
# 2                            5.892241e+06                       25.0
# 3                            2.293599e+07                       25.0
# 4                            8.204825e+08                       25.0
#
#    经营活动产生的现金流量净额\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元
# 0                                      -1.187800e+11
# 1                                       8.232283e+10
# 2                                       1.443948e+07
# 3                                      -2.433035e+08
# 4                                       7.068813e+08
#
# [5 rows x 21 columns]

# %%
WIND.columns
# Out:
# Index(['证券代码', '证券简称', '递延所得税负债增加\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元',
#        '递延所得税资产减少\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元',
#        '高管人数\n[交易日期] 2017-12-31\n[单位] 1',
#        '支付给职工以及为职工支付的现金\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元',
#        '营业收入(同比增长率)\n[报告期] 2017年报\n[单位] 1%', '所属申万行业名称\n[行业级别] 一级行业\n[单位] 1',
#        '资产总计\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元',
#        '独立董事人数\n[交易日期] 2017-12-31\n[单位] 1',
#        '非独立董事人数\n[交易日期] 2017-12-31\n[单位] 1',
#        '董事会人数\n[交易日期] 2017-12-31\n[单位] 1', '管理层年度薪酬总额\n[年度] 2017\n[单位] 1元',
#        '员工总数\n[交易日期] 2017-12-31\n[单位] 1', '资产负债率\n[报告期] 2017年报\n[单位] 1%',
#        '公司属性\n[交易日期] 2017-12-31\n[单位] 1',
#        '大股东持股比例\n[日期] 2017-12-31\n[排名] 第1名\n[单位] 1%',
#        '公司监事(历任)\n[交易日期] 2017-12-31\n[单位] 1',
#        '净利润\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元', '年末所得税率\n[年度] 2017\n[单位] 1',
#        '经营活动产生的现金流量净额\n[报告期] 2017年报\n[报表类型] 合并报表\n[单位] 1元'],
#       dtype='object')

# %%
WIND.columns = [col.replace('\n', '') for col in WIND.columns]
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2017年报[报表类型] 合并报表[单位] 1元  \
# 0     000001.SZ  平安银行                                      NaN
# 1     000002.SZ   万科A                            -1.109681e+08
# 2     000004.SZ  国华网安                             3.463150e+06
# 3     000005.SZ  ST星源                            -3.420000e+05
# 4     000006.SZ  深振业A                             6.765542e+05
# ...         ...   ...                                      ...
# 4769  871857.BJ  泓禧科技                            -3.577606e+04
# 4770  871981.BJ  晶赛科技                             5.222401e+05
# 4771  872925.BJ  锦好医疗                                      NaN
# 4772        NaN   NaN                                      NaN
# 4773  数据来源：Wind   NaN                                      NaN
#
#       递延所得税资产减少[报告期] 2017年报[报表类型] 合并报表[单位] 1元  高管人数[交易日期] 2017-12-31[单位] 1  \
# 0                               -7.252000e+09                          9.0
# 1                               -2.443367e+09                          5.0
# 2                               -7.676307e+05                          3.0
# 3                               -7.187767e+06                          6.0
# 4                               -4.431963e+07                          7.0
# ...                                       ...                          ...
# 4769                             4.329600e+03                          5.0
# 4770                             7.733243e+05                          3.0
# 4771                             3.674002e+04                          4.0
# 4772                                      NaN                          NaN
# 4773                                      NaN                          NaN
#
#       支付给职工以及为职工支付的现金[报告期] 2017年报[报表类型] 合并报表[单位] 1元  \
# 0                                      1.434500e+10
# 1                                      9.243603e+09
# 2                                      1.273144e+07
# 3                                      7.395553e+07
# 4                                      1.120988e+08
# ...                                             ...
# 4769                                   2.538995e+07
# 4770                                   2.399889e+07
# 4771                                   9.188857e+06
# 4772                                            NaN
# 4773                                            NaN
#
#       营业收入(同比增长率)[报告期] 2017年报[单位] 1% 所属申万行业名称[行业级别] 一级行业[单位] 1  \
# 0                            -1.7908                        银行
# 1                             1.0063                       房地产
# 2                           -51.8178                       计算机
# 3                            10.1811                      公用事业
# 4                           -11.8903                       房地产
# ...                              ...                       ...
# 4769                         26.9636                       NaN
# 4770                          9.4637                       NaN
# 4771                         26.0015                       NaN
# 4772                             NaN                       NaN
# 4773                             NaN                       NaN
#
#       资产总计[报告期] 2017年报[报表类型] 合并报表[单位] 1元  独立董事人数[交易日期] 2017-12-31[单位] 1  ...  \
# 0                           3.248474e+12                            5.0  ...
# 1                           1.165347e+12                            4.0  ...
# 2                           2.688443e+08                            3.0  ...
# 3                           2.912100e+09                            5.0  ...
# 4                           1.313993e+10                            3.0  ...
# ...                                  ...                            ...  ...
# 4769                        1.631685e+08                            0.0  ...
# 4770                        2.467649e+08                            0.0  ...
# 4771                        4.013729e+07                            0.0  ...
# 4772                                 NaN                            NaN  ...
# 4773                                 NaN                            NaN  ...
#
#       董事会人数[交易日期] 2017-12-31[单位] 1  管理层年度薪酬总额[年度] 2017[单位] 1元  \
# 0                             14.0                 51522800.0
# 1                             11.0                 64100000.0
# 2                              9.0                  1583400.0
# 3                             15.0                  5341000.0
# 4                              7.0                  9593300.0
# ...                            ...                        ...
# 4769                           5.0                        NaN
# 4770                           5.0                        NaN
# 4771                           5.0                        NaN
# 4772                           NaN                        NaN
# 4773                           NaN                        NaN
#
#       员工总数[交易日期] 2017-12-31[单位] 1  资产负债率[报告期] 2017年报[单位] 1%  \
# 0                         31168.0                   93.1644
# 1                         77708.0                   83.9813
# 2                           172.0                   31.5247
# 3                           705.0                   51.7747
# 4                           370.0                   56.5648
# ...                           ...                       ...
# 4769                        619.0                   54.8759
# 4770                        362.0                   40.7809
# 4771                        114.0                   25.3015
# 4772                          NaN                       NaN
# 4773                          NaN                       NaN
#
#       公司属性[交易日期] 2017-12-31[单位] 1 大股东持股比例[日期] 2017-12-31[排名] 第1名[单位] 1%  \
# 0                            公众企业                             49.560001
# 1                            公众企业                             29.379999
# 2                            民营企业                             28.430000
# 3                            民营企业                             17.410000
# 4                          地方国有企业                             21.930000
# ...                           ...                                   ...
# 4769                         民营企业                             66.559998
# 4770                         民营企业                             54.049999
# 4771                          NaN                                   NaN
# 4772                          NaN                                   NaN
# 4773                          NaN                                   NaN
#
#       公司监事(历任)[交易日期] 2017-12-31[单位] 1 净利润[报告期] 2017年报[报表类型] 合并报表[单位] 1元  \
# 0            邱伟,车国宝,周建国,骆向东,甘煜,王群,储一昀                      2.318900e+10
# 1                           周清平,解冻,郑英                      3.720839e+10
# 2                         唐银萍,林绮霞,阮旭里                      5.892241e+06
# 3                 刘丽萍,熊金芳,汪健飞,刘敏儿,吕卫东                      2.293599e+07
# 4                           陈强,谢向荣,张磊                      8.204825e+08
# ...                               ...                               ...
# 4769                        董清波,许岩,文燕                      1.145378e+07
# 4770                      陈维彦,孙龙凤,王立平                      1.875294e+07
# 4771                       钟梅,刘雪映,谈海霞                      8.025816e+06
# 4772                              NaN                               NaN
# 4773                              NaN                               NaN
#
#       年末所得税率[年度] 2017[单位] 1  经营活动产生的现金流量净额[报告期] 2017年报[报表类型] 合并报表[单位] 1元
# 0                      25.0                                -1.187800e+11
# 1                      25.0                                 8.232283e+10
# 2                      25.0                                 1.443948e+07
# 3                      25.0                                -2.433035e+08
# 4                      25.0                                 7.068813e+08
# ...                     ...                                          ...
# 4769                   15.0                                 3.705832e+07
# 4770                   15.0                                 2.762378e+07
# 4771                   15.0                                 6.367584e+06
# 4772                    NaN                                          NaN
# 4773                    NaN                                          NaN
#
# [4774 rows x 21 columns]

# %%
WIND = WIND.drop([4772])
WIND = WIND.drop([4773])
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2017年报[报表类型] 合并报表[单位] 1元  \
# 0     000001.SZ  平安银行                                      NaN
# 1     000002.SZ   万科A                            -1.109681e+08
# 2     000004.SZ  国华网安                             3.463150e+06
# 3     000005.SZ  ST星源                            -3.420000e+05
# 4     000006.SZ  深振业A                             6.765542e+05
# ...         ...   ...                                      ...
# 4767  871553.BJ  凯腾精工                                      NaN
# 4768  871642.BJ  通易航天                                      NaN
# 4769  871857.BJ  泓禧科技                            -3.577606e+04
# 4770  871981.BJ  晶赛科技                             5.222401e+05
# 4771  872925.BJ  锦好医疗                                      NaN
#
#       递延所得税资产减少[报告期] 2017年报[报表类型] 合并报表[单位] 1元  高管人数[交易日期] 2017-12-31[单位] 1  \
# 0                               -7.252000e+09                          9.0
# 1                               -2.443367e+09                          5.0
# 2                               -7.676307e+05                          3.0
# 3                               -7.187767e+06                          6.0
# 4                               -4.431963e+07                          7.0
# ...                                       ...                          ...
# 4767                            -7.025064e+04                          6.0
# 4768                             9.429279e+05                          6.0
# 4769                             4.329600e+03                          5.0
# 4770                             7.733243e+05                          3.0
# 4771                             3.674002e+04                          4.0
#
#       支付给职工以及为职工支付的现金[报告期] 2017年报[报表类型] 合并报表[单位] 1元  \
# 0                                      1.434500e+10
# 1                                      9.243603e+09
# 2                                      1.273144e+07
# 3                                      7.395553e+07
# 4                                      1.120988e+08
# ...                                             ...
# 4767                                   1.106055e+08
# 4768                                   7.124956e+06
# 4769                                   2.538995e+07
# 4770                                   2.399889e+07
# 4771                                   9.188857e+06
#
#       营业收入(同比增长率)[报告期] 2017年报[单位] 1% 所属申万行业名称[行业级别] 一级行业[单位] 1  \
# 0                            -1.7908                        银行
# 1                             1.0063                       房地产
# 2                           -51.8178                       计算机
# 3                            10.1811                      公用事业
# 4                           -11.8903                       房地产
# ...                              ...                       ...
# 4767                          7.6952                       NaN
# 4768                         76.8962                       NaN
# 4769                         26.9636                       NaN
# 4770                          9.4637                       NaN
# 4771                         26.0015                       NaN
#
#       资产总计[报告期] 2017年报[报表类型] 合并报表[单位] 1元  独立董事人数[交易日期] 2017-12-31[单位] 1  ...  \
# 0                           3.248474e+12                            5.0  ...
# 1                           1.165347e+12                            4.0  ...
# 2                           2.688443e+08                            3.0  ...
# 3                           2.912100e+09                            5.0  ...
# 4                           1.313993e+10                            3.0  ...
# ...                                  ...                            ...  ...
WIND['证券代码'] = WIND['证券代码'].str[0:6]
WIND
# Out:
#         证券代码  证券简称  递延所得税负债增加[报告期] 2017年报[报表类型] 合并报表[单位] 1元  \
# 0     000001  平安银行                                      NaN
# 1     000002   万科A                            -1.109681e+08
# 2     000004  国华网安                             3.463150e+06
# 3     000005  ST星源                            -3.420000e+05
# 4     000006  深振业A                             6.765542e+05
# ...      ...   ...                                      ...
# 4767  871553  凯腾精工                                      NaN
# 4768  871642  通易航天                                      NaN
# 4769  871857  泓禧科技                            -3.577606e+04
# 4770  871981  晶赛科技                             5.222401e+05
# 4771  872925  锦好医疗                                      NaN
#
#       递延所得税资产减少[报告期] 2017年报[报表类型] 合并报表[单位] 1元  高管人数[交易日期] 2017-12-31[单位] 1  \
# 0                               -7.252000e+09                          9.0
# 1                               -2.443367e+09                          5.0
# 2                               -7.676307e+05                          3.0
# 3                               -7.187767e+06                          6.0
# 4                               -4.431963e+07                          7.0
# ...                                       ...                          ...
# 4767                            -7.025064e+04                          6.0
# 4768                             9.429279e+05                          6.0
# 4769                             4.329600e+03                          5.0
# 4770                             7.733243e+05                          3.0
# 4771                             3.674002e+04                          4.0
#
#       支付给职工以及为职工支付的现金[报告期] 2017年报[报表类型] 合并报表[单位] 1元  \
# 0                                      1.434500e+10
# 1                                      9.243603e+09
# 2                                      1.273144e+07
# 3                                      7.395553e+07
# 4                                      1.120988e+08
# ...                                             ...
# 4767                                   1.106055e+08
# 4768                                   7.124956e+06
# 4769                                   2.538995e+07
# 4770                                   2.399889e+07
# 4771                                   9.188857e+06
#
#       营业收入(同比增长率)[报告期] 2017年报[单位] 1% 所属申万行业名称[行业级别] 一级行业[单位] 1  \
# 0                            -1.7908                        银行
# 1                             1.0063                       房地产
# 2                           -51.8178                       计算机
# 3                            10.1811                      公用事业
# 4                           -11.8903                       房地产
# ...                              ...                       ...
# 4767                          7.6952                       NaN
# 4768                         76.8962                       NaN
# 4769                         26.9636                       NaN
# 4770                          9.4637                       NaN
# 4771                         26.0015                       NaN
#
#       资产总计[报告期] 2017年报[报表类型] 合并报表[单位] 1元  独立董事人数[交易日期] 2017-12-31[单位] 1  ...  \
# 0                           3.248474e+12                            5.0  ...
# 1                           1.165347e+12                            4.0  ...
# 2                           2.688443e+08                            3.0  ...
# 3                           2.912100e+09                            5.0  ...
# 4                           1.313993e+10                            3.0  ...
# ...                                  ...                            ...  ...
# 4767                        3.280615e+08                            0.0  ...
# 4768                        1.153359e+08                            0.0  ...
# 4769                        1.631685e+08                            0.0  ...
# 4770                        2.467649e+08                            0.0  ...
# 4771                        4.013729e+07                            0.0  ...
#
#       董事会人数[交易日期] 2017-12-31[单位] 1  管理层年度薪酬总额[年度] 2017[单位] 1元  \
# 0                             14.0                 51522800.0
# 1                             11.0                 64100000.0
# 2                              9.0                  1583400.0
# 3                             15.0                  5341000.0
# 4                              7.0                  9593300.0
# ...                            ...                        ...
# 4767                           5.0                        NaN
# 4768                           5.0                        NaN
# 4769                           5.0                        NaN
# 独立董事人数[交易日期] 2017-12-31[单位] 1                       0
# 非独立董事人数[交易日期] 2017-12-31[单位] 1                      0
# 董事会人数[交易日期] 2017-12-31[单位] 1                        0
# 管理层年度薪酬总额[年度] 2017[单位] 1元                        1182
# 员工总数[交易日期] 2017-12-31[单位] 1                        31
# 资产负债率[报告期] 2017年报[单位] 1%                           33
# 公司属性[交易日期] 2017-12-31[单位] 1                       874
# 大股东持股比例[日期] 2017-12-31[排名] 第1名[单位] 1%             665
# 公司监事(历任)[交易日期] 2017-12-31[单位] 1                   604
# 净利润[报告期] 2017年报[报表类型] 合并报表[单位] 1元                  33
# 年末所得税率[年度] 2017[单位] 1                             345
# 经营活动产生的现金流量净额[报告期] 2017年报[报表类型] 合并报表[单位] 1元        33
# dtype: int64

# %% [markdown]
# ### MASTER_Preprocessing

# %%
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0       证券代码      统计截止日期               统计口径   未领取薪酬监管层人数
# 1        NaN         NaN                NaN            人
# 2     000001  2017-12-31                  2          4.0
# 3     000001  2017-12-31                  1          4.0
# 4     000002  2017-12-31                  1          5.0
# ...      ...         ...                ...          ...
# 7023  900953  2017-12-31                  2          7.0
# 7024  900956  2017-12-31                  1          4.0
# 7025  900956  2017-12-31                  2          4.0
# 7026  900957  2017-12-31                  2          0.0
# 7027  900957  2017-12-31                  1          0.0
#
# [7028 rows x 4 columns]

# %%
MASTER = MASTER.drop([0])
MASTER = MASTER.drop([1])
MASTER = MASTER.reset_index(drop =True)
MASTER = MASTER[(MASTER['StatisticalCaliber'] != '2')]
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 1     000001  2017-12-31                  1          4.0
# 2     000002  2017-12-31                  1          5.0
# 4     000004  2017-12-31                  1          3.0
# 6     000005  2017-12-31                  1          2.0
# 8     000006  2017-12-31                  1          0.0
# ...      ...         ...                ...          ...
# 7017  900948  2017-12-31                  1          0.0
# 7018  900951  2017-12-31                  1          5.0
# 7020  900953  2017-12-31                  1          7.0
# 7022  900956  2017-12-31                  1          4.0
# 7025  900957  2017-12-31                  1          0.0
#
# [3513 rows x 4 columns]

# %%
MASTER.shape
# Out:
# (3513, 4)

# %% [markdown]
# ### Merge CSMAR_and_WIND_and_MASTER

# %%
merge_data = pd.merge(CSMAR, WIND, left_on='code', right_on='证券代码')
merge_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2017-12-31                A         6968000000.0
# 1  000002        万科A       2017-12-31                A       13933565335.34
# 2  000004       国华网安       2017-12-31                A            3824189.8
# 3  000005      ST 星源       2017-12-31                A          35022615.46
# 4  000006       深振业A       2017-12-31                A         139744237.42
# 5  000007     *ST 全新       2017-12-31                A           1026801.56
# 6  000008       神州高铁       2017-12-31                A         129481987.68
# 7  000009       中国宝安       2017-12-31                A          56227086.59
# 8  000010       美丽生态       2017-12-31                A           -2729050.4
# 9  000011       深物业A       2017-12-31                A          203784886.4
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 
# 3                       2.293599e+07                   25.0
# 4                       8.204825e+08                   25.0
# 5                       7.950554e+05                   25.0
# 6                       8.896099e+08                   25.0
# 7                       3.232474e+08                   25.0
# 8                      -1.050006e+09                   25.0
# 9                       6.229627e+08                   25.0
#
#    经营活动产生的现金流量净额[报告期] 2017年报[报表类型] 合并报表[单位] 1元  Symbol     Enddate  \
# 0                                -1.187800e+11  000001  2017-12-31
# 1                                 8.232283e+10  000002  2017-12-31
# 2                                 1.443948e+07  000004  2017-12-31
# 3                                -2.433035e+08  000005  2017-12-31
# 4                                 7.068813e+08  000006  2017-12-31
# 5                                 2.266985e+06  000007  2017-12-31
# 6                                -5.295902e+07  000008  2017-12-31
# 7                                 3.909072e+08  000009  2017-12-31
# 8                                 5.641627e+08  000010  2017-12-31
# 9                                -3.462698e+08  000011  2017-12-31
#
#    StatisticalCaliber  UnpaidNumber
# 0                   1           4.0
# 1                   1           5.0
# 2                   1           3.0
# 3                   1           2.0
# 4                   1           0.0
# 5                   1           0.0
# 6                   1           0.0
# 7                   1           0.0
# 8                   1           3.0
# 9                   1           4.0
#
# [10 rows x 35 columns]

# %%
full_data.shape
# Out:
# (3440, 35)

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2017/full_data.xlsx')

# %% [markdown]
# ### 1：剔除金融保险类、ST、* ST类上市公司

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加[报告期] 2017年报[报表类型] 合并报表[单位] 1元',
#        '递延所得税资产减少[报告期] 2017年报[报表类型] 合并报表[单位] 1元',
#        '高管人数[交易日期] 2017-12-31[单位] 1',
#        '支付给职工以及为职工支付的现金[报告期] 2017年报[报表类型] 合并报表[单位] 1元',
#        '营业收入(同比增长率)[报告期] 2017年报[单位] 1%', '所属申万行业名称[行业级别] 一级行业[单位] 1',
#        '资产总计[报告期] 2017年报[报表类型] 合并报表[单位] 1元', '独立董事人数[交易日期] 2017-12-31[单位] 1',
#        '非独立董事人数[交易日期] 2017-12-31[单位] 1', '董事会人数[交易日期] 2017-12-31[单位] 1',
#        '管理层年度薪酬总额[年度] 2017[单位] 1元', '员工总数[交易日期] 2017-12-31[单位] 1',
#        '资产负债率[报告期] 2017年报[单位] 1%', '公司属性[交易日期] 2017-12-31[单位] 1',
#        '大股东持股比例[日期] 2017-12-31[排名] 第1名[单位] 1%',
#        '公司监事(历任)[交易日期] 2017-12-31[单位] 1', '净利润[报告期] 2017年报[报表类型] 合并报表[单位] 1元',
#        '年末所得税率[年度] 2017[单位] 1', '经营活动产生的现金流量净额[报告期] 2017年报[报表类型] 合并报表[单位] 1元',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.columns = ['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
       'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
       'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
       '证券简称', '递延所得税负债增加',
       '递延所得税资产减少', '高管人数',
       '支付给职工以及为职工支付的现金',
       '营业收入', '所属申万行业名称',
       '资产总计', '独立董事人数',
       '非独立董事人数', '董事会人数',
       '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性',
       '大股东持股比例', '公司监事',
       '净利润', '年末所得税率',
       '经营活动产生的现金流量净额', 'Symbol', 'Enddate',
       'StatisticalCaliber', 'UnpaidNumber']
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.shape
# Out:
# (3440, 35)

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '银行')]
full_data = full_data[(full_data['所属申万行业名称'] != '非银金融')]

full_data['check_ST'] = full_data['short_name'].str[0:2]
full_data['check_*ST'] = full_data['short_name'].str[0:3]
full_data = full_data[(full_data['check_ST'] != 'ST')]
full_data = full_data[(full_data['check_*ST'] != '*ST')]

# %%
full_data.shape
# Out:
# (3171, 37)

# %% [markdown]
# ### 2：剔除员工数量不足 100人的公司,这部分公司可能存在经营异常或者数据披露错误

# %%
full_data = full_data[(full_data['员工总数'] > 100)]

# %%
full_data.shape
# Out:
# (3152, 37)

# %% [markdown]
# ### 3：剔除管理层平均工资比普通员工平均工资低的公司,因为这类公司披露的高管薪酬可能仅是津贴,或者数据错误：

# %% [markdown]
# - 管理层平均工资 = 管理层年度薪酬总数/（非独立董事人数+公司监事+高管人数-UnpaidNumber）
# - 普通员工平均工资 = （支付给职工以及为职工支付的现金-管理层年度薪酬总数）/ （员工总数-（非独立董事+公司监事+高管人数））

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST'],
#       dtype='object')

# %%
full_data['人数']=full_data['公司监事'].apply(lambda x: len(x.split(',')))

# %%
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2017-12-31                A       13933565335.34
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2017-12-31             Y       2017-12-31         9026490.0
#
#   CG_Capchg-Nshrttl  ...           净利润 年末所得税率  经营活动产生的现金流量净额  Symbol  \
# 1     11039152001.0  ...  3.720839e+10   25.0   8.232283e+10  000002
#
#       Enddate  StatisticalCaliber  UnpaidNumber check_ST  check_*ST  人数
# 1  2017-12-31                   1           5.0       万科        万科A   3
#
# [1 rows x 38 columns]

# %%
full_data['管理层平均工资'] = full_data['管理层年度薪酬总额'] / (
   full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数'] 
      - full_data['UnpaidNumber']
)
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2017-12-31                A       13933565335.34
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2017-12-31             Y       2017-12-31         9026490.0
#
#   CG_Capchg-Nshrttl  ... 年末所得税率 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11039152001.0  ...   25.0  8.232283e+10  000002  2017-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST check_*ST  人数    管理层平均工资
# 1                   1           5.0        万科       万科A   3  6410000.0
#
# [1 rows x 39 columns]

# %%
full_data['普通员工平均工资'] = (full_data ['支付给职工以及为职工支付的现金'] 
   - full_data['管理层年度薪酬总额']) / (
      full_data['员工总数'] - (
         full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数']
      )
)
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2017-12-31                A       13933565335.34
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2017-12-31             Y       2017-12-31         9026490.0
#
#   CG_Capchg-Nshrttl  ... 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11039152001.0  ...  8.232283e+10  000002  2017-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST  check_*ST 人数    管理层平均工资  \
# 1                   1           5.0        万科        万科A  3  6410000.0
#
#         普通员工平均工资
# 1  118150.960372
#
# [1 rows x 40 columns]

# %%
full_data = full_data[(full_data["管理层平均工资"] > full_data["普通员工平均工资"])]

# %%
full_data.shape
# Out:
# (3102, 40)

# %% [markdown]
# ### 4：剔除企业实际所得税率小于0和大于1的样本

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data = full_data[(full_data['年末所得税率'] <100) &
   (full_data['年末所得税率'] >0)]

# %%
full_data.shape
# Out:
# (3059, 40)

# %% [markdown]
# ### 5：由于2015 年新增了轻工、纺织、机械和汽车四大行业作为加速折旧政策试点,如果将这部分个业作为2014年加速折旧政策的控制组可能对结果产生偏差,为此还剔除了享受2015年加速折旧政策的公司样本

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '轻工制造')]
full_data = full_data[(full_data['所属申万行业名称'] != '纺织服装')]
full_data = full_data[(full_data['所属申万行业名称'] != '机械设备')]
full_data = full_data[(full_data['所属申万行业名称'] != '汽车')]

# %%
full_data.shape
# Out:
# (2427, 40)

# %% [markdown]
# ### 6：剔除关键变量缺失的样本

# %%
miss_data = pd.DataFrame(full_data.isnull().sum(), columns=['Missing Data Count'])
miss_data
# Out:
#                       Missing Data Count
# code                                   0
# short_name                             0
# FS_Comins-Accper                       0
# FS_Comins-Typrep                       0
# FS_Comins-B002100000                  13
# BF_EXPAY-EndDate                       0
# BF_EXPAY-Same                         30
# CG_Capchg-Reptdt                       0
# CG_Capchg-Nshrsms                      0
# CG_Capchg-Nshrttl                      0
# 证券代码                                   0
# 证券简称                                   0
# 递延所得税负债增加                           1059
# 递延所得税资产减少                             47
# 高管人数                                   0
# 支付给职工以及为职工支付的现金                        0
# 营业收入                                   0
# 所属申万行业名称                               0
# 资产总计                                   0
# 独立董事人数                                 0
# 非独立董事人数                                0
# 董事会人数                                  0
# 管理层年度薪酬总额                              0
# 员工总数                                   0
# 资产负债率                                  0
# 公司属性                                  11
# 大股东持股比例                                0
# 公司监事                                   0
# 净利润                                    0
# 年末所得税率                                 0
# 经营活动产生的现金流量净额                          0
# Symbol                                 0
# Enddate                                0
# StatisticalCaliber                     0
# UnpaidNumber                           0
# check_ST                               0
# check_*ST                              0
# 人数                                     0
# 管理层平均工资                                0
# 普通员工平均工资                               0

# %%
miss_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2017/miss_data.xlsx')

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2017/full_data2.xlsx')

# %%
full_data.dropna(axis=0,inplace=True)

# %%
full_data.shape
# Out:
# (1336, 40)

# %% [markdown]
# ### 8：final

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.columns = ['代码', '简称', '会计期间', '报表类型',
       '所得税费用', '截止日期', '董事长和总经理是否同一人',
       '统计截止日期', '监管层持股数', '总股数', '证券代码',
       '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
       '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
       'Symbol', 'Enddate', 'StatisticalCaliber', '未领取薪酬监管层人数', 'check_ST',
       'check_*ST', '人数', '管理层平均工资', '普通员工平均工资']
full_data.columns
# Out:
# Index(['代码', '简称', '会计期间', '报表类型', '所得税费用', '截止日期', '董事长和总经理是否同一人', '统计截止日期',
#        '监管层持股数', '总股数', '证券代码', '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数',
#        '支付给职工以及为职工支付的现金', '营业收入', '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数',
#        '董事会人数', '管理层年度薪酬总额', '员工总数', '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润',
#        '年末所得税率', '经营活动产生的现金流量净额', 'Symbol', 'Enddate', 'StatisticalCaliber',
#        '未领取薪酬监管层人数', 'check_ST', 'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2017/2017_final_1.xlsx')

# %% [markdown]
# ### .to_table

# %%
import math

def get_log(full_data):
   result_log = []
   list_log = full_data.values
   for i in list_log:
      result_log_n = math.log(i)
      result_log.append(result_log_n)
   return result_log

list_result = get_log(full_data['管理层平均工资'])
full_data['lnAMW'] = list_result

list_result = get_log(full_data['普通员工平均工资'])
full_data['lnAEW'] = list_result

full_data['收入不平等'] = full_data['管理层平均工资'] / full_data['普通员工平均工资']
list_result = get_log(full_data['收入不平等'])
full_data['lnWFI'] = list_result

full_data['ETR'] = full_data['所得税费用'] / (
   (
      full_data['所得税费用'] + full_data['净利润'] - (
         full_data['递延所得税负债增加'] + full_data['递延所得税资产减少']
      )/ full_data['年末所得税率']
   )
)

list_result = get_log(full_data['资产总计'])
full_data['lnSize'] = list_result

full_data['OCF'] = full_data['经营活动产生的现金流量净额'] / full_data['资产总计']

full_data['Lev'] = full_data['资产负债率']/100

full_data['Growth'] = full_data['营业收入']/100

full_data['Top1'] = full_data['大股东持股比例']

full_data['indepent'] = (full_data['独立董事人数'] / full_data['董事会人数'])*100

full_data['MH'] = (full_data['监管层持股数'] / full_data['总股数'])*100

full_data["Dual"] = np.where(full_data["董事长和总经理是否同一人"] =='Y', "1", "0")

full_data['国有判断'] = full_data['公司属性'].str[2:4]
full_data['SOE'] = np.where(full_data['国有判断'] =='国有', "1", "0")

# %%
full_data.head(1)
# Out:
#        代码   简称        会计期间 报表类型           所得税费用        截止日期 董事长和总经理是否同一人  \
# 1  000002  万科A  2017-12-31    A  13933565335.34  2017-12-31            Y
#
#        统计截止日期     监管层持股数            总股数  ...    lnSize       OCF       Lev  \
# 1  2017-12-31  9026490.0  11039152001.0  ...  27.78404  0.070642  0.839813
#
#      Growth       Top1   indepent        MH Dual  国有判断  SOE
# 1  0.010063  29.379999  36.363636  0.081768    1    企业    0
#
# [1 rows x 55 columns]

# %%
full_data.shape
# Out:
# (1336, 55)

# %% [markdown]
# ### 对所有连续变量在上下1%水平上进行缩尾处理

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/processed/2017_final_data.xlsx')

# %%
full_data['lnWFI'].describe()
# Out:
# count    1336.000000
# mean        1.380624
# std         0.615239
# min         0.003904
# 25%         0.955240
# 50%         1.305071
# 75%         1.738760
# max         5.536340
# Name: lnWFI, dtype: float64
