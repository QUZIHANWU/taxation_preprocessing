# %% [markdown]
# ## 2011_Preprocessing

# %%
# import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read 2010_data

CSMAR = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2011/CSMAR.xlsx')

WIND = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2011/WIND.xlsx')

MASTER = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2011/MASTER.xlsx')
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CSMAR.dtypes
# Out:
# code                    object
# short_name              object
# FS_Comins-Accper        object
# FS_Comins-Typrep        object
# FS_Comins-B002100000    object
# BF_EXPAY-EndDate        object
# BF_EXPAY-Same           object
# CG_Capchg-Reptdt        object
# CG_Capchg-Nshrsms       object
# CG_Capchg-Nshrttl       object
# dtype: object

# %%
WIND.dtypes
# Out:
# 证券代码                                                   object
# 证券简称                                                   object
# 递延所得税负债增加\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元          float64
# 递延所得税资产减少\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元          float64
# 高管人数\n[交易日期] 2011-12-31                               float64
# 支付给职工以及为职工支付的现金\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元    float64
# 营业收入(同比增长率)\n[报告期] 2011年报\n[单位] %                     float64
# 所属申万行业名称\n[行业级别] 一级行业                                  object
# 资产总计\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元               float64
# 独立董事人数\n[交易日期] 2011-12-31                             float64
# 非独立董事人数\n[交易日期] 2011-12-31                            float64
# 董事会人数\n[交易日期] 2011-12-31                              float64
# 管理层年度薪酬总额\n[年度] 2011\n[单位] 万元                         float64
# 员工总数\n[交易日期] 2011-12-31                               float64
# 资产负债率\n[报告期] 2011年报\n[单位] %                           float64
# 公司属性\n[交易日期] 2011-12-31                                object
# 大股东持股比例\n[日期] 2011-12-31\n[排名] 第1名\n[单位] %            float64
# 公司监事(历任)\n[交易日期] 2011-12-31                            object
# 净利润\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元                float64
# 年末所得税率\n[年度] 2011                                     float64
# 经营活动产生的现金流量净额\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元      float64
# dtype: object

# %%
MASTER.dtypes
# Out:
# Symbol                object
# Enddate               object
# StatisticalCaliber    object
# UnpaidNumber          object
# dtype: object

# %% [markdown]
# ### CSMAR_Preprocessing

# %%
CSMAR.head(5)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0      代码         简称             会计期间             报表类型                所得税费用
# 1    沒有单位       沒有单位             没有单位             没有单位                    元
# 2  000001       平安银行       2011-12-31                A           2866998000
# 3  000002        万科A       2011-12-31                A        4206276208.55
# 4  000004       国华网安       2011-12-31                A           3196648.14
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0             截止日期  董事长与总经理是否同一人           统计截止日期         其中：监管层持股数
# 1             没有单位          没有单位             没有单位                 股
# 2       2011-12-31             N       2011-12-31             18614
# 3       2011-12-31             N       2011-12-31          18426384
# 4       2011-12-31             N       2011-12-31              1725
#
#   CG_Capchg-Nshrttl
# 0               总股数
# 1                 股
# 2        5123350416
# 3       10995210218
# 4          83976684

# %%
CSMAR = CSMAR.drop([0])
CSMAR = CSMAR.drop([1])
CSMAR = CSMAR.reset_index(drop= True)
# CSMAR = CSMAR.drop(["TRD_Capchg-Shrchgdt", "TRD_Capchg-Nshrttl"], axis=1)
CSMAR.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2011-12-31                A           2866998000
# 1  000002        万科A       2011-12-31                A        4206276208.55
# 2  000004       国华网安       2011-12-31                A           3196648.14
# 3  000005      ST 星源       2011-12-31                A            283222.53
# 4  000006       深振业A       2011-12-31                A         130138012.03
# 5  000007     *ST 全新       2011-12-31                A           2281437.43
# 6  000008       神州高铁       2011-12-31                A                    0
# 7  000009       中国宝安       2011-12-31                A         139417237.02
# 8  000010       美丽生态       2011-12-31                A           3191978.52
# 9  000011       深物业A       2011-12-31                A          82042327.08
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2011-12-31             N       2011-12-31             18614
# 1       2011-12-31             N       2011-12-31          18426384
# 2       2011-12-31             N       2011-12-31              1725
# 3       2011-12-31             N       2011-12-31                 0
# 4       2011-12-31             N       2011-12-31          16651250
# 5       2011-12-31             N       2011-12-31          25000000
# 6       2011-12-31             N       2011-12-31                90
# 7       2011-12-31             Y       2011-12-31            144875
# 8       2011-12-31             Y       2011-12-31                 0
# 9       2011-12-31             N       2011-12-31                 0
#
#   CG_Capchg-Nshrttl
# 0        5123350416
# 1       10995210218
# 2          83976684
# 3         914333607
# 4         989007360
# 5         230965363
# 6          73653208
# 7        1090750529
# 8         147017448
# 9         595979092

# %%
CSMAR.isnull().sum()
# Out:
# code                      0
# short_name                0
# FS_Comins-Accper          0
# FS_Comins-Typrep          0
# FS_Comins-B002100000      1
# BF_EXPAY-EndDate         89
# BF_EXPAY-Same           115
# CG_Capchg-Reptdt         89
# CG_Capchg-Nshrsms        89
# CG_Capchg-Nshrttl        89
# dtype: int64

# %%
CSMAR.shape
# Out:
# (2452, 10)

# %% [markdown]
# ### WIND_Preprocessing

# %%
WIND.head(5)
# Out:
#         证券代码  证券简称  递延所得税负债增加\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元  \
# 0  000001.SZ  平安银行                                    26299000.0
# 1  000002.SZ   万科A                                    35383126.9
# 2  000004.SZ  国华网安                                           NaN
# 3  000005.SZ  ST星源                                           NaN
# 4  000006.SZ  深振业A                                           NaN
#
#    递延所得税资产减少\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元  高管人数\n[交易日期] 2011-12-31  \
# 0                                 -7.689700e+08                     10.0
# 1                                 -6.754340e+08                     13.0
# 2                                           NaN                      6.0
# 3                                  2.832225e+05                      7.0
# 4                                 -8.439757e+07                      9.0
#
#    支付给职工以及为职工支付的现金\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元  \
# 0                                       5.287265e+09
# 1                                       2.480848e+09
# 2                                       1.497066e+07
# 3                                       3.898805e+07
# 4                                       6.921623e+07
#
#    营业收入(同比增长率)\n[报告期] 2011年报\n[单位] % 所属申万行业名称\n[行业级别] 一级行业  \
# 0                            64.9423                    银行
# 1                            41.5447                   房地产
# 2                           -43.2705                   计算机
# 3                           -53.7034                  公用事业
# 4                            10.7127                   房地产
#
#    资产总计\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元  独立董事人数\n[交易日期] 2011-12-31  ...  \
# 0                             1.258177e+12                        8.0  ...
# 1                             2.962084e+11                        4.0  ...
# 2                             1.963072e+08                        3.0  ...
# 3                             1.260586e+09                        5.0  ...
# 4                             8.321974e+09                        3.0  ...
#
#    董事会人数\n[交易日期] 2011-12-31  管理层年度薪酬总额\n[年度] 2011\n[单位] 万元  \
# 0                      18.0                        4179.00
# 1                      11.0                        6557.00
# 2                       8.0                         166.41
# 3                      15.0                         380.80
# 4                       9.0                         661.08
#
#    员工总数\n[交易日期] 2011-12-31  资产负债率\n[报告期] 2011年报\n[单位] %  \
# 0                  13778.0                      94.0087
# 1                  27951.0                      77.0997
# 2                    322.0                      29.4935
# 3                    501.0                      47.6484
# 4                    283.0                      65.2855
#
#    公司属性\n[交易日期] 2011-12-31 大股东持股比例\n[日期] 2011-12-31\n[排名] 第1名\n[单位] %  \
# 0                     公众企业                                      42.16
# 1                     公众企业                                      14.73
# 2                     民营企业                                      26.10
# 3                     民营企业                                      20.15
# 4                   地方国有企业                                      19.93
#
#    公司监事(历任)\n[交易日期] 2011-12-31 净利润\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元  \
# 0     邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚                           1.039049e+10
# 1                   丁福源,周清平,吴丁                           1.159961e+10
# 2                    魏杰,陈少龙,何婷                           9.193068e+06
# 3                  刘丽萍,熊金芳,王洁萍                           1.141465e+07
# 4                  朱大华,郭其荣,李红光                           4.341170e+08
#
#    年末所得税率\n[年度] 2011  经营活动产生的现金流量净额\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元
# 0               24.0                                     -1.443937e+10
# 1               24.0                                      3.389425e+09
# 2               24.0                                      1.936574e+07
# 3               24.0                                      3.477337e+07
# 4               24.0                                      1.198565e+09
#
# [5 rows x 21 columns]

# %%
WIND.columns
# Out:
# Index(['证券代码', '证券简称', '递延所得税负债增加\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元',
#        '递延所得税资产减少\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元',
#        '高管人数\n[交易日期] 2011-12-31',
#        '支付给职工以及为职工支付的现金\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元',
#        '营业收入(同比增长率)\n[报告期] 2011年报\n[单位] %', '所属申万行业名称\n[行业级别] 一级行业',
#        '资产总计\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元', '独立董事人数\n[交易日期] 2011-12-31',
#        '非独立董事人数\n[交易日期] 2011-12-31', '董事会人数\n[交易日期] 2011-12-31',
#        '管理层年度薪酬总额\n[年度] 2011\n[单位] 万元', '员工总数\n[交易日期] 2011-12-31',
#        '资产负债率\n[报告期] 2011年报\n[单位] %', '公司属性\n[交易日期] 2011-12-31',
#        '大股东持股比例\n[日期] 2011-12-31\n[排名] 第1名\n[单位] %',
#        '公司监事(历任)\n[交易日期] 2011-12-31', '净利润\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元',
#        '年末所得税率\n[年度] 2011',
#        '经营活动产生的现金流量净额\n[报告期] 2011年报\n[报表类型] 合并报表\n[单位] 元'],
#       dtype='object')

# %%
WIND.columns = [col.replace('\n', '') for col in WIND.columns]
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2011年报[报表类型] 合并报表[单位] 元  \
# 0     000001.SZ  平安银行                              26299000.0
# 1     000002.SZ   万科A                              35383126.9
# 2     000004.SZ  国华网安                                     NaN
# 3     000005.SZ  ST星源                                     NaN
# 4     000006.SZ  深振业A                                     NaN
# ...         ...   ...                                     ...
# 4769  871857.BJ  泓禧科技                                     NaN
# 4770  871981.BJ  晶赛科技                                     NaN
# 4771  872925.BJ  锦好医疗                                     NaN
# 4772        NaN   NaN                                     NaN
# 4773  数据来源：Wind   NaN                                     NaN
#
#       递延所得税资产减少[报告期] 2011年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2011-12-31  \
# 0                              -7.689700e+08                   10.0
# 1                              -6.754340e+08                   13.0
# 2                                        NaN                    6.0
# 3                               2.832225e+05                    7.0
# 4                              -8.439757e+07                    9.0
# ...                                      ...                    ...
# 4769                                     NaN                    0.0
# 4770                                     NaN                    0.0
# 4771                                     NaN                    0.0
# 4772                                     NaN                    NaN
# 4773                                     NaN                    NaN
#
#       支付给职工以及为职工支付的现金[报告期] 2011年报[报表类型] 合并报表[单位] 元  \
# 0                                     5.287265e+09
# 1                                     2.480848e+09
# 2                                     1.497066e+07
# 3                                     3.898805e+07
# 4                                     6.921623e+07
# ...                                            ...
# 4769                                           NaN
# 4770                                           NaN
# 4771                                           NaN
# 4772                                           NaN
# 4773                                           NaN
#
#       营业收入(同比增长率)[报告期] 2011年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           64.9423                  银行
# 1                           41.5447                 房地产
# 2                          -43.2705                 计算机
# 3                          -53.7034                公用事业
# 4                           10.7127                 房地产
# ...                             ...                 ...
# 4769                            NaN                 NaN
# 4770                            NaN                 NaN
# 4771                            NaN                 NaN
# 4772                            NaN                 NaN
# 4773                            NaN                 NaN
#
#       资产总计[报告期] 2011年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2011-12-31  ...  \
# 0                          1.258177e+12                      8.0  ...
# 1                          2.962084e+11                      4.0  ...
# 2                          1.963072e+08                      3.0  ...
# 3                          1.260586e+09                      5.0  ...
# 4                          8.321974e+09                      3.0  ...
# ...                                 ...                      ...  ...
# 4769                                NaN                      0.0  ...
# 4770                                NaN                      0.0  ...
# 4771                                NaN                      0.0  ...
# 4772                                NaN                      NaN  ...
# 4773                                NaN                      NaN  ...
#
#       董事会人数[交易日期] 2011-12-31  管理层年度薪酬总额[年度] 2011[单位] 万元  \
# 0                       18.0                    4179.00
# 1                       11.0                    6557.00
# 2                        8.0                     166.41
# 3                       15.0                     380.80
# 4                        9.0                     661.08
# ...                      ...                        ...
# 4769                     0.0                        NaN
# 4770                     0.0                        NaN
# 4771                     0.0                        NaN
# 4772                     NaN                        NaN
# 4773                     NaN                        NaN
#
#       员工总数[交易日期] 2011-12-31  资产负债率[报告期] 2011年报[单位] %  公司属性[交易日期] 2011-12-31  \
# 0                   13778.0                  94.0087                   公众企业
# 1                   27951.0                  77.0997                   公众企业
# 2                     322.0                  29.4935                   民营企业
# 3                     501.0                  47.6484                   民营企业
# 4                     283.0                  65.2855                 地方国有企业
# ...                     ...                      ...                    ...
# 4769                    NaN                      NaN                    NaN
# 4770                    NaN                      NaN                    NaN
# 4771                    NaN                      NaN                    NaN
# 4772                    NaN                      NaN                    NaN
# 4773                    NaN                      NaN                    NaN
#
#      大股东持股比例[日期] 2011-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2011-12-31  \
# 0                                   42.16   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                                   14.73                 丁福源,周清平,吴丁
# 2                                   26.10                  魏杰,陈少龙,何婷
# 3                                   20.15                刘丽萍,熊金芳,王洁萍
# 4                                   19.93                朱大华,郭其荣,李红光
# ...                                   ...                        ...
# 4769                                  NaN                        NaN
# 4770                                  NaN                        NaN
# 4771                                  NaN                        NaN
# 4772                                  NaN                        NaN
# 4773                                  NaN                        NaN
#
#      净利润[报告期] 2011年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2011  \
# 0                        1.039049e+10             24.0
# 1                        1.159961e+10             24.0
# 2                        9.193068e+06             24.0
# 3                        1.141465e+07             24.0
# 4                        4.341170e+08             24.0
# ...                               ...              ...
# 4769                              NaN              NaN
# 4770                              NaN              NaN
# 4771                              NaN              NaN
# 4772                              NaN              NaN
# 4773                              NaN              NaN
#
#       经营活动产生的现金流量净额[报告期] 2011年报[报表类型] 合并报表[单位] 元
# 0                                  -1.443937e+10
# 1                                   3.389425e+09
# 2                                   1.936574e+07
# 3                                   3.477337e+07
# 4                                   1.198565e+09
# ...                                          ...
# 4769                                         NaN
# 4770                                         NaN
# 4771                                         NaN
# 4772                                         NaN
# 4773                                         NaN
#
# [4774 rows x 21 columns]

# %%
WIND = WIND.drop([4772])
WIND = WIND.drop([4773])
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2011年报[报表类型] 合并报表[单位] 元  \
# 0     000001.SZ  平安银行                              26299000.0
# 1     000002.SZ   万科A                              35383126.9
# 2     000004.SZ  国华网安                                     NaN
# 3     000005.SZ  ST星源                                     NaN
# 4     000006.SZ  深振业A                                     NaN
# ...         ...   ...                                     ...
# 4767  871553.BJ  凯腾精工                                     NaN
# 4768  871642.BJ  通易航天                                     NaN
# 4769  871857.BJ  泓禧科技                                     NaN
# 4770  871981.BJ  晶赛科技                                     NaN
# 4771  872925.BJ  锦好医疗                                     NaN
#
#       递延所得税资产减少[报告期] 2011年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2011-12-31  \
# 0                              -7.689700e+08                   10.0
# 1                              -6.754340e+08                   13.0
# 2                                        NaN                    6.0
# 3                               2.832225e+05                    7.0
# 4                              -8.439757e+07                    9.0
# ...                                      ...                    ...
# 4767                                     NaN                    0.0
# 4768                                     NaN                    0.0
# 4769                                     NaN                    0.0
# 4770                                     NaN                    0.0
# 4771                                     NaN                    0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2011年报[报表类型] 合并报表[单位] 元  \
# 0                                     5.287265e+09
# 1                                     2.480848e+09
# 2                                     1.497066e+07
# 3                                     3.898805e+07
# 4                                     6.921623e+07
# ...                                            ...
# 4767                                           NaN
# 4768                                           NaN
# 4769                                           NaN
# 4770                                           NaN
# 4771                                           NaN
#
#       营业收入(同比增长率)[报告期] 2011年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           64.9423                  银行
# 1                           41.5447                 房地产
# 2                          -43.2705                 计算机
# 3                          -53.7034                公用事业
# 4                           10.7127                 房地产
# ...                             ...                 ...
# 4767                            NaN                 NaN
# 4768                            NaN                 NaN
# 4769                            NaN                 NaN
# 4770                            NaN                 NaN
# 4771                            NaN                 NaN
#
#       资产总计[报告期] 2011年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2011-12-31  ...  \
# 0                          1.258177e+12                      8.0  ...
# 1                          2.962084e+11                      4.0  ...
# 2                          1.963072e+08                      3.0  ...
# 3                          1.260586e+09                      5.0  ...
# 4                          8.321974e+09                      3.0  ...
# ...                                 ...                      ...  ...
# 4767                                NaN                      0.0  ...
# 4768                                NaN                      0.0  ...
# 4769                                NaN                      0.0  ...
# 4770                                NaN                      0.0  ...
# 4771                                NaN                      0.0  ...
#
#       董事会人数[交易日期] 2011-12-31  管理层年度薪酬总额[年度] 2011[单位] 万元  \
# 0                       18.0                    4179.00
# 1                       11.0                    6557.00
# 2                        8.0                     166.41
# 3                       15.0                     380.80
# 4                        9.0                     661.08
# ...                      ...                        ...
# 4767                     0.0                        NaN
# 4768                     0.0                        NaN
# 4769                     0.0                        NaN
# 4770                     0.0                        NaN
# 4771                     0.0                        NaN
#
#       员工总数[交易日期] 2011-12-31  资产负债率[报告期] 2011年报[单位] %  公司属性[交易日期] 2011-12-31  \
# 0                   13778.0                  94.0087                   公众企业
# 1                   27951.0                  77.0997                   公众企业
# 2                     322.0                  29.4935                   民营企业
# 3                     501.0                  47.6484                   民营企业
# 4                     283.0                  65.2855                 地方国有企业
# ...                     ...                      ...                    ...
# 4767                    NaN                      NaN                    NaN
# 4768                    NaN                      NaN                    NaN
# 4769                    NaN                      NaN                    NaN
# 4770                    NaN                      NaN                    NaN
# 4771                    NaN                      NaN                    NaN
#
#      大股东持股比例[日期] 2011-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2011-12-31  \
# 0                                   42.16   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                                   14.73                 丁福源,周清平,吴丁
# 2                                   26.10                  魏杰,陈少龙,何婷
# 3                                   20.15                刘丽萍,熊金芳,王洁萍
# 4                                   19.93                朱大华,郭其荣,李红光
# ...                                   ...                        ...
# 4767                                  NaN                        NaN
# 4768                                  NaN                        NaN
# 4769                                  NaN                        NaN
# 4770                                  NaN                        NaN
# 4771                                  NaN                        NaN
#
#      净利润[报告期] 2011年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2011  \
# 0                        1.039049e+10             24.0
# 1                        1.159961e+10             24.0
# 2                        9.193068e+06             24.0
# 3                        1.141465e+07             24.0
# 4                        4.341170e+08             24.0
# ...                               ...              ...
# 4767                              NaN              NaN
# 4768                              NaN              NaN
# 4769                              NaN              NaN
# 4770                              NaN              NaN
# 4771                              NaN              NaN
#
#       经营活动产生的现金流量净额[报告期] 2011年报[报表类型] 合并报表[单位] 元
# 0                                  -1.443937e+10
# 1                                   3.389425e+09
# 2                                   1.936574e+07
# 3                                   3.477337e+07
# 4                                   1.198565e+09
# ...                                          ...
# 4767                                         NaN
# 4768                                         NaN
# 4769                                         NaN
# 4770                                         NaN
# 4771                                         NaN
#
# [4772 rows x 21 columns]

# %%
WIND['证券代码'] = WIND['证券代码'].str[0:6]
WIND
# Out:
#         证券代码  证券简称  递延所得税负债增加[报告期] 2011年报[报表类型] 合并报表[单位] 元  \
# 0     000001  平安银行                              26299000.0
# 1     000002   万科A                              35383126.9
# 2     000004  国华网安                                     NaN
# 3     000005  ST星源                                     NaN
# 4     000006  深振业A                                     NaN
# ...      ...   ...                                     ...
# 4767  871553  凯腾精工                                     NaN
# 4768  871642  通易航天                                     NaN
# 4769  871857  泓禧科技                                     NaN
# 4770  871981  晶赛科技                                     NaN
# 4771  872925  锦好医疗                                     NaN
#
#       递延所得税资产减少[报告期] 2011年报[报表类型] 合并报表[单位] 元  高管人数[交易日期] 2011-12-31  \
# 0                              -7.689700e+08                   10.0
# 1                              -6.754340e+08                   13.0
# 2                                        NaN                    6.0
# 3                               2.832225e+05                    7.0
# 4                              -8.439757e+07                    9.0
# ...                                      ...                    ...
# 4767                                     NaN                    0.0
# 4768                                     NaN                    0.0
# 4769                                     NaN                    0.0
# 4770                                     NaN                    0.0
# 4771                                     NaN                    0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2011年报[报表类型] 合并报表[单位] 元  \
# 0                                     5.287265e+09
# 1                                     2.480848e+09
# 2                                     1.497066e+07
# 3                                     3.898805e+07
# 4                                     6.921623e+07
# ...                                            ...
# 4767                                           NaN
# 4768                                           NaN
# 4769                                           NaN
# 4770                                           NaN
# 4771                                           NaN
#
#       营业收入(同比增长率)[报告期] 2011年报[单位] % 所属申万行业名称[行业级别] 一级行业  \
# 0                           64.9423                  银行
# 1                           41.5447                 房地产
# 2                          -43.2705                 计算机
# 3                          -53.7034                公用事业
# 4                           10.7127                 房地产
# ...                             ...                 ...
# 4767                            NaN                 NaN
# 4768                            NaN                 NaN
# 4769                            NaN                 NaN
# 4770                            NaN                 NaN
# 4771                            NaN                 NaN
#
#       资产总计[报告期] 2011年报[报表类型] 合并报表[单位] 元  独立董事人数[交易日期] 2011-12-31  ...  \
# 0                          1.258177e+12                      8.0  ...
# 1                          2.962084e+11                      4.0  ...
# 2                          1.963072e+08                      3.0  ...
# 3                          1.260586e+09                      5.0  ...
# 4                          8.321974e+09                      3.0  ...
# ...                                 ...                      ...  ...
# 4767                                NaN                      0.0  ...
# 4768                                NaN                      0.0  ...
# 4769                                NaN                      0.0  ...
# 4770                                NaN                      0.0  ...
# 4771                                NaN                      0.0  ...
#
#       董事会人数[交易日期] 2011-12-31  管理层年度薪酬总额[年度] 2011[单位] 万元  \
# 0                       18.0                    4179.00
# 1                       11.0                    6557.00
# 2                        8.0                     166.41
# 3                       15.0                     380.80
# 4                        9.0                     661.08
# ...                      ...                        ...
# 4767                     0.0                        NaN
# 4768                     0.0                        NaN
# 4769                     0.0                        NaN
# 4770                     0.0                        NaN
# 4771                     0.0                        NaN
#
#       员工总数[交易日期] 2011-12-31  资产负债率[报告期] 2011年报[单位] %  公司属性[交易日期] 2011-12-31  \
# 0                   13778.0                  94.0087                   公众企业
# 1                   27951.0                  77.0997                   公众企业
# 2                     322.0                  29.4935                   民营企业
# 3                     501.0                  47.6484                   民营企业
# 4                     283.0                  65.2855                 地方国有企业
# ...                     ...                      ...                    ...
# 4767                    NaN                      NaN                    NaN
# 4768                    NaN                      NaN                    NaN
# 4769                    NaN                      NaN                    NaN
# 4770                    NaN                      NaN                    NaN
# 4771                    NaN                      NaN                    NaN
#
#      大股东持股比例[日期] 2011-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2011-12-31  \
# 0                                   42.16   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                                   14.73                 丁福源,周清平,吴丁
# 2                                   26.10                  魏杰,陈少龙,何婷
# 3                                   20.15                刘丽萍,熊金芳,王洁萍
# 4                                   19.93                朱大华,郭其荣,李红光
# ...                                   ...                        ...
# 4767                                  NaN                        NaN
# 4768                                  NaN                        NaN
# 4769                                  NaN                        NaN
# 4770                                  NaN                        NaN
# 4771                                  NaN                        NaN
#
#      净利润[报告期] 2011年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2011  \
# 0                        1.039049e+10             24.0
# 1                        1.159961e+10             24.0
# 2                        9.193068e+06             24.0
# 3                        1.141465e+07             24.0
# 4                        4.341170e+08             24.0
# ...                               ...              ...
# 4767                              NaN              NaN
# 4768                              NaN              NaN
# 4769                              NaN              NaN
# 4770                              NaN              NaN
# 4771                              NaN              NaN
#
#       经营活动产生的现金流量净额[报告期] 2011年报[报表类型] 合并报表[单位] 元
# 0                                  -1.443937e+10
# 1                                   3.389425e+09
# 2                                   1.936574e+07
# 3                                   3.477337e+07
# 4                                   1.198565e+09
# ...                                          ...
# 4767                                         NaN
# 4768                                         NaN
# 4769                                         NaN
# 4770                                         NaN
# 4771                                         NaN
#
# [4772 rows x 21 columns]

# %%
WIND.isnull().sum()
# Out:
# 证券代码                                               0
# 证券简称                                               0
# 递延所得税负债增加[报告期] 2011年报[报表类型] 合并报表[单位] 元          3825
# 递延所得税资产减少[报告期] 2011年报[报表类型] 合并报表[单位] 元          2085
# 高管人数[交易日期] 2011-12-31                              0
# 支付给职工以及为职工支付的现金[报告期] 2011年报[报表类型] 合并报表[单位] 元    1569
# 营业收入(同比增长率)[报告期] 2011年报[单位] %                   2090
# 所属申万行业名称[行业级别] 一级行业                              163
# 资产总计[报告期] 2011年报[报表类型] 合并报表[单位] 元               1525
# 独立董事人数[交易日期] 2011-12-31                            0
# 非独立董事人数[交易日期] 2011-12-31                           0
# 董事会人数[交易日期] 2011-12-31                             0
# 管理层年度薪酬总额[年度] 2011[单位] 万元                       2471
# 员工总数[交易日期] 2011-12-31                           1721
# 资产负债率[报告期] 2011年报[单位] %                         1564
# 公司属性[交易日期] 2011-12-31                           2466
# 大股东持股比例[日期] 2011-12-31[排名] 第1名[单位] %            2292
# 公司监事(历任)[交易日期] 2011-12-31                       2292
# 净利润[报告期] 2011年报[报表类型] 合并报表[单位] 元                1555
# 年末所得税率[年度] 2011                                 2203
# 经营活动产生的现金流量净额[报告期] 2011年报[报表类型] 合并报表[单位] 元      1567
# dtype: int64

# %% [markdown]
# ### MASTER_Preprocessing

# %%
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0       证券代码      统计截止日期               统计口径   未领取薪酬监管层人数
# 1        NaN         NaN                NaN            人
# 2     000001  2011-12-31                  1          4.0
# 3     000001  2011-12-31                  2          4.0
# 4     000002  2011-12-31                  2          5.0
# ...      ...         ...                ...          ...
# 4723  900953  2011-12-31                  2          6.0
# 4724  900956  2011-12-31                  2          5.0
# 4725  900956  2011-12-31                  1          5.0
# 4726  900957  2011-12-31                  1          2.0
# 4727  900957  2011-12-31                  2          2.0
#
# [4728 rows x 4 columns]

# %%
MASTER = MASTER.drop([0])
MASTER = MASTER.drop([1])
MASTER = MASTER.reset_index(drop =True)
MASTER = MASTER[(MASTER['StatisticalCaliber'] != '2')]
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0     000001  2011-12-31                  1          4.0
# 3     000002  2011-12-31                  1          5.0
# 4     000004  2011-12-31                  1          5.0
# 7     000005  2011-12-31                  1          3.0
# 8     000006  2011-12-31                  1          3.0
# ...      ...         ...                ...          ...
# 4717  900950  2011-12-31                  1          3.0
# 4718  900951  2011-12-31                  1          8.0
# 4720  900953  2011-12-31                  1          6.0
# 4723  900956  2011-12-31                  1          5.0
# 4724  900957  2011-12-31                  1          2.0
#
# [2363 rows x 4 columns]

# %%
MASTER.shape
# Out:
# (2363, 4)

# %% [markdown]
# ### Merge CSMAR_and_WIND_and_MASTER

# %%
merge_data = pd.merge(CSMAR, WIND, left_on='code', right_on='证券代码')
merge_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2011-12-31                A           2866998000
# 1  000002        万科A       2011-12-31                A        4206276208.55
# 2  000004       国华网安       2011-12-31                A           3196648.14
# 3  000005      ST 星源       2011-12-31                A            283222.53
# 4  000006       深振业A       2011-12-31                A         130138012.03
# 5  000007     *ST 全新       2011-12-31                A           2281437.43
# 6  000008       神州高铁       2011-12-31                A                    0
# 7  000009       中国宝安       2011-12-31                A         139417237.02
# 8  000010       美丽生态       2011-12-31                A           3191978.52
# 9  000011       深物业A       2011-12-31                A          82042327.08
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2011-12-31             N       2011-12-31             18614
# 1       2011-12-31             N       2011-12-31          18426384
# 2       2011-12-31             N       2011-12-31              1725
# 3       2011-12-31             N       2011-12-31                 0
# 4       2011-12-31             N       2011-12-31          16651250
# 5       2011-12-31             N       2011-12-31          25000000
# 6       2011-12-31             N       2011-12-31                90
# 7       2011-12-31             Y       2011-12-31            144875
# 8       2011-12-31             Y       2011-12-31                 0
# 9       2011-12-31             N       2011-12-31                 0
#
#   CG_Capchg-Nshrttl  ... 董事会人数[交易日期] 2011-12-31 管理层年度薪酬总额[年度] 2011[单位] 万元  \
# 0        5123350416  ...                   18.0                   4179.00
# 1       10995210218  ...                   11.0                   6557.00
# 2          83976684  ...                    8.0                    166.41
# 3         914333607  ...                   15.0                    380.80
# 4         989007360  ...                    9.0                    661.08
# 5         230965363  ...                    9.0                    273.72
# 6          73653208  ...                    6.0                    119.40
# 7        1090750529  ...                    9.0                   1405.70
# 8         147017448  ...                   11.0                    139.90
# 9         595979092  ...                    9.0                    540.82
#
#    员工总数[交易日期] 2011-12-31  资产负债率[报告期] 2011年报[单位] %  公司属性[交易日期] 2011-12-31  \
# 0                13778.0                  94.0087                   公众企业
# 1                27951.0                  77.0997                   公众企业
# 2                  322.0                  29.4935                   民营企业
# 3                  501.0                  47.6484                   民营企业
# 4                  283.0                  65.2855                 地方国有企业
# 5                  675.0                  19.3420                   民营企业
# 6                   23.0                   4.3705                   民营企业
# 7                 5697.0                  65.0402                   公众企业
# 8                  444.0                  60.6440                   民营企业
# 9                 2723.0                  67.6791                 地方国有企业
#
#    大股东持股比例[日期] 2011-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2011-12-31  \
# 0                             42.160000   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                             14.730000                 丁福源,周清平,吴丁
# 2                             26.100000                  魏杰,陈少龙,何婷
# 3                             20.150000                刘丽萍,熊金芳,王洁萍
# 4                             19.930000                朱大华,郭其荣,李红光
# 5                             17.410000                  王岱,韩军,冯幼红
# 6                             23.150000                 施丽娜,杨建,陈汉伦
# 7                             11.960000                 龚明,贺国奇,张育新
# 8                             24.070000                 周会军,孙永平,单军
# 9                             54.310001        戴先华,王秋平,王秀颜,张戈坚,张世磊
#
#   净利润[报告期] 2011年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2011  \
# 0                     1.039049e+10             24.0
# 1                     1.159961e+10             24.0
# 2                     9.193068e+06             24.0
# 3                     1.141465e+07             24.0
# 4                     4.341170e+08             24.0
# 5                     8.310539e+06             24.0
# 6                    -5.394518e+05             24.0
# 7                     3.804354e+08             24.0
# 8                     8.374495e+06              NaN
# 9                     2.574611e+08             24.0
#
#    经营活动产生的现金流量净额[报告期] 2011年报[报表类型] 合并报表[单位] 元
# 0                               -1.443937e+10
# 1                                3.389425e+09
# 2                                1.936574e+07
# 3                                3.477337e+07
# 4                                1.198565e+09
# 5                               -1.697571e+07
# 6                               -1.030071e+06
# 7                               -8.281620e+08
# 8                                6.516479e+06
# 9                               -3.614676e+08
#
# [10 rows x 31 columns]

# %%
full_data = pd.merge(merge_data, MASTER, left_on='code', right_on='Symbol')
full_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2011-12-31                A           2866998000
# 1  000002        万科A       2011-12-31                A        4206276208.55
# 2  000004       国华网安       2011-12-31                A           3196648.14
# 3  000005      ST 星源       2011-12-31                A            283222.53
# 4  000006       深振业A       2011-12-31                A         130138012.03
# 5  000007     *ST 全新       2011-12-31                A           2281437.43
# 6  000008       神州高铁       2011-12-31                A                    0
# 7  000009       中国宝安       2011-12-31                A         139417237.02
# 8  000010       美丽生态       2011-12-31                A           3191978.52
# 9  000011       深物业A       2011-12-31                A          82042327.08
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2011-12-31             N       2011-12-31             18614
# 1       2011-12-31             N       2011-12-31          18426384
# 2       2011-12-31             N       2011-12-31              1725
# 3       2011-12-31             N       2011-12-31                 0
# 4       2011-12-31             N       2011-12-31          16651250
# 5       2011-12-31             N       2011-12-31          25000000
# 6       2011-12-31             N       2011-12-31                90
# 7       2011-12-31             Y       2011-12-31            144875
# 8       2011-12-31             Y       2011-12-31                 0
# 9       2011-12-31             N       2011-12-31                 0
#
#   CG_Capchg-Nshrttl  ... 公司属性[交易日期] 2011-12-31  \
# 0        5123350416  ...                  公众企业
# 1       10995210218  ...                  公众企业
# 2          83976684  ...                  民营企业
# 3         914333607  ...                  民营企业
# 4         989007360  ...                地方国有企业
# 5         230965363  ...                  民营企业
# 6          73653208  ...                  民营企业
# 7        1090750529  ...                  公众企业
# 8         147017448  ...                  民营企业
# 9         595979092  ...                地方国有企业
#
#   大股东持股比例[日期] 2011-12-31[排名] 第1名[单位] %  公司监事(历任)[交易日期] 2011-12-31  \
# 0                            42.160000   邱伟,车国宝,罗康平,肖立荣,王毅,曹立新,王岚
# 1                            14.730000                 丁福源,周清平,吴丁
# 2                            26.100000                  魏杰,陈少龙,何婷
# 3                            20.150000                刘丽萍,熊金芳,王洁萍
# 4                            19.930000                朱大华,郭其荣,李红光
# 5                            17.410000                  王岱,韩军,冯幼红
# 6                            23.150000                 施丽娜,杨建,陈汉伦
# 7                            11.960000                 龚明,贺国奇,张育新
# 8                            24.070000                 周会军,孙永平,单军
# 9                            54.310001        戴先华,王秋平,王秀颜,张戈坚,张世磊
#
#    净利润[报告期] 2011年报[报表类型] 合并报表[单位] 元  年末所得税率[年度] 2011  \
# 0                      1.039049e+10             24.0
# 1                      1.159961e+10             24.0
# 2                      9.193068e+06             24.0
# 3                      1.141465e+07             24.0
# 4                      4.341170e+08             24.0
# 5                      8.310539e+06             24.0
# 6                     -5.394518e+05             24.0
# 7                      3.804354e+08             24.0
# 8                      8.374495e+06              NaN
# 9                      2.574611e+08             24.0
#
#    经营活动产生的现金流量净额[报告期] 2011年报[报表类型] 合并报表[单位] 元  Symbol     Enddate  \
# 0                               -1.443937e+10  000001  2011-12-31
# 1                                3.389425e+09  000002  2011-12-31
# 2                                1.936574e+07  000004  2011-12-31
# 3                                3.477337e+07  000005  2011-12-31
# 4                                1.198565e+09  000006  2011-12-31
# 5                               -1.697571e+07  000007  2011-12-31
# 6                               -1.030071e+06  000008  2011-12-31
# 7                               -8.281620e+08  000009  2011-12-31
# 8                                6.516479e+06  000010  2011-12-31
# 9                               -3.614676e+08  000011  2011-12-31
#
#    StatisticalCaliber  UnpaidNumber
# 0                   1           4.0
# 1                   1           5.0
# 2                   1           5.0
# 3                   1           3.0
# 4                   1           3.0
# 5                   1           0.0
# 6                   1           0.0
# 7                   1           0.0
# 8                   1           5.0
# 9                   1           4.0
#
# [10 rows x 35 columns]

# %%
full_data.shape
# Out:
# (2271, 35)

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2011/full_data.xlsx')

# %% [markdown]
# ### 1：剔除金融保险类、ST、* ST类上市公司

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加[报告期] 2011年报[报表类型] 合并报表[单位] 元',
#        '递延所得税资产减少[报告期] 2011年报[报表类型] 合并报表[单位] 元', '高管人数[交易日期] 2011-12-31',
#        '支付给职工以及为职工支付的现金[报告期] 2011年报[报表类型] 合并报表[单位] 元',
#        '营业收入(同比增长率)[报告期] 2011年报[单位] %', '所属申万行业名称[行业级别] 一级行业',
#        '资产总计[报告期] 2011年报[报表类型] 合并报表[单位] 元', '独立董事人数[交易日期] 2011-12-31',
#        '非独立董事人数[交易日期] 2011-12-31', '董事会人数[交易日期] 2011-12-31',
#        '管理层年度薪酬总额[年度] 2011[单位] 万元', '员工总数[交易日期] 2011-12-31',
#        '资产负债率[报告期] 2011年报[单位] %', '公司属性[交易日期] 2011-12-31',
#        '大股东持股比例[日期] 2011-12-31[排名] 第1名[单位] %', '公司监事(历任)[交易日期] 2011-12-31',
#        '净利润[报告期] 2011年报[报表类型] 合并报表[单位] 元', '年末所得税率[年度] 2011',
#        '经营活动产生的现金流量净额[报告期] 2011年报[报表类型] 合并报表[单位] 元', 'Symbol', 'Enddate',
#        'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.columns = ['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
       'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
       'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
       '证券简称', '递延所得税负债增加',
       '递延所得税资产减少', '高管人数',
       '支付给职工以及为职工支付的现金',
       '营业收入', '所属申万行业名称',
       '资产总计', '独立董事人数',
       '非独立董事人数', '董事会人数',
       '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性',
       '大股东持股比例', '公司监事',
       '净利润', '年末所得税率',
       '经营活动产生的现金流量净额', 'Symbol', 'Enddate',
       'StatisticalCaliber', 'UnpaidNumber']
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.shape
# Out:
# (2271, 35)

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '银行')]
full_data = full_data[(full_data['所属申万行业名称'] != '非银金融')]

full_data['check_ST'] = full_data['short_name'].str[0:2]
full_data['check_*ST'] = full_data['short_name'].str[0:3]
full_data = full_data[(full_data['check_ST'] != 'ST')]
full_data = full_data[(full_data['check_*ST'] != '*ST')]

# %%
full_data.shape
# Out:
# (2055, 37)

# %% [markdown]
# ### 2：剔除员工数量不足 100人的公司,这部分公司可能存在经营异常或者数据披露错误

# %%
full_data = full_data[(full_data['员工总数'] > 100)]

# %%
full_data.shape
# Out:
# (2000, 37)

# %% [markdown]
# ### 3：剔除管理层平均工资比普通员工平均工资低的公司,因为这类公司披露的高管薪酬可能仅是津贴,或者数据错误：

# %% [markdown]
# - 管理层平均工资 = 管理层年度薪酬总数/（非独立董事人数+公司监事+高管人数-UnpaidNumber）
# - 普通员工平均工资 = （支付给职工以及为职工支付的现金-管理层年度薪酬总数）/ （员工总数-（非独立董事+公司监事+高管人数））

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST'],
#       dtype='object')

# %%
full_data['人数']=full_data['公司监事'].apply(lambda x: len(x.split(',')))

# %%
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2011-12-31                A        4206276208.55
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2011-12-31             N       2011-12-31          18426384
#
#   CG_Capchg-Nshrttl  ...           净利润 年末所得税率  经营活动产生的现金流量净额  Symbol  \
# 1       10995210218  ...  1.159961e+10   24.0   3.389425e+09  000002
#
#       Enddate  StatisticalCaliber  UnpaidNumber check_ST  check_*ST  人数
# 1  2011-12-31                   1           5.0       万科        万科A   3
#
# [1 rows x 38 columns]

# %%
full_data['管理层平均工资'] = full_data['管理层年度薪酬总额'] / (
   full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数'] 
      - full_data['UnpaidNumber']
) * 10000
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2011-12-31                A        4206276208.55
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2011-12-31             N       2011-12-31          18426384
#
#   CG_Capchg-Nshrttl  ... 年末所得税率 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1       10995210218  ...   24.0  3.389425e+09  000002  2011-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST check_*ST  人数         管理层平均工资
# 1                   1           5.0        万科       万科A   3  3642777.777778
#
# [1 rows x 39 columns]

# %%
full_data['普通员工平均工资'] = (full_data ['支付给职工以及为职工支付的现金'] 
   - full_data['管理层年度薪酬总额']) / (
      full_data['员工总数'] - (
         full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数']
      )
)
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2011-12-31                A        4206276208.55
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2011-12-31             N       2011-12-31          18426384
#
#   CG_Capchg-Nshrttl  ... 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1       10995210218  ...  3.389425e+09  000002  2011-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST  check_*ST 人数         管理层平均工资  \
# 1                   1           5.0        万科        万科A  3  3642777.777778
#
#        普通员工平均工资
# 1  88829.900037
#
# [1 rows x 40 columns]

# %%
full_data = full_data[(full_data["管理层平均工资"] > full_data["普通员工平均工资"])]

# %%
full_data.shape
# Out:
# (1929, 40)

# %% [markdown]
# ### 4：剔除企业实际所得税率小于0和大于1的样本

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data = full_data[(full_data['年末所得税率'] <100) &
   (full_data['年末所得税率'] >0)]

# %%
full_data.shape
# Out:
# (1887, 40)

# %% [markdown]
# ### 5：由于2015 年新增了轻工、纺织、机械和汽车四大行业作为加速折旧政策试点,如果将这部分个业作为2014年加速折旧政策的控制组可能对结果产生偏差,为此还剔除了享受2015年加速折旧政策的公司样本

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '轻工制造')]
full_data = full_data[(full_data['所属申万行业名称'] != '纺织服装')]
full_data = full_data[(full_data['所属申万行业名称'] != '机械设备')]
full_data = full_data[(full_data['所属申万行业名称'] != '汽车')]

# %%
full_data.shape
# Out:
# (1564, 40)

# %% [markdown]
# ### 6：剔除关键变量缺失的样本

# %%
miss_data = pd.DataFrame(full_data.isnull().sum(), columns=['Missing Data Count'])
miss_data
# Out:
#                       Missing Data Count
# code                                   0
# short_name                             0
# FS_Comins-Accper                       0
# FS_Comins-Typrep                       0
# FS_Comins-B002100000                   0
# BF_EXPAY-EndDate                       0
# BF_EXPAY-Same                         15
# CG_Capchg-Reptdt                       0
# CG_Capchg-Nshrsms                      0
# CG_Capchg-Nshrttl                      0
# 证券代码                                   0
# 证券简称                                   0
# 递延所得税负债增加                            988
# 递延所得税资产减少                             64
# 高管人数                                   0
# 支付给职工以及为职工支付的现金                        0
# 营业收入                                   0
# 所属申万行业名称                               0
# 资产总计                                   0
# 独立董事人数                                 0
# 非独立董事人数                                0
# 董事会人数                                  0
# 管理层年度薪酬总额                              0
# 员工总数                                   0
# 资产负债率                                  0
# 公司属性                                  16
# 大股东持股比例                                2
# 公司监事                                   0
# 净利润                                    0
# 年末所得税率                                 0
# 经营活动产生的现金流量净额                          0
# Symbol                                 0
# Enddate                                0
# StatisticalCaliber                     0
# UnpaidNumber                           0
# check_ST                               0
# check_*ST                              0
# 人数                                     0
# 管理层平均工资                                0
# 普通员工平均工资                               0

# %%
miss_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2011/miss_data.xlsx')

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2011/full_data2.xlsx')

# %%
full_data.dropna(axis=0,inplace=True)

# %%
full_data.shape
# Out:
# (555, 40)

# %% [markdown]
# ### 8：final

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.columns = ['代码', '简称', '会计期间', '报表类型',
       '所得税费用', '截止日期', '董事长和总经理是否同一人',
       '统计截止日期', '监管层持股数', '总股数', '证券代码',
       '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
       '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
       'Symbol', 'Enddate', 'StatisticalCaliber', '未领取薪酬监管层人数', 'check_ST',
       'check_*ST', '人数', '管理层平均工资', '普通员工平均工资']
full_data.columns
# Out:
# Index(['代码', '简称', '会计期间', '报表类型', '所得税费用', '截止日期', '董事长和总经理是否同一人', '统计截止日期',
#        '监管层持股数', '总股数', '证券代码', '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数',
#        '支付给职工以及为职工支付的现金', '营业收入', '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数',
#        '董事会人数', '管理层年度薪酬总额', '员工总数', '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润',
#        '年末所得税率', '经营活动产生的现金流量净额', 'Symbol', 'Enddate', 'StatisticalCaliber',
#        '未领取薪酬监管层人数', 'check_ST', 'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2011/2010_final_1.xlsx')

# %% [markdown]
# ### .to_table

# %%
import math

def get_log(full_data):
   result_log = []
   list_log = full_data.values
   for i in list_log:
      result_log_n = math.log(i)
      result_log.append(result_log_n)
   return result_log

list_result = get_log(full_data['管理层平均工资'])
full_data['lnAMW'] = list_result

list_result = get_log(full_data['普通员工平均工资'])
full_data['lnAEW'] = list_result

full_data['收入不平等'] = full_data['管理层平均工资'] / full_data['普通员工平均工资']
list_result = get_log(full_data['收入不平等'])
full_data['lnWFI'] = list_result

full_data['ETR'] = full_data['所得税费用'] / (
   (
      full_data['所得税费用'] + full_data['净利润'] - (
         full_data['递延所得税负债增加'] + full_data['递延所得税资产减少']
      )/ full_data['年末所得税率']
   )
)

list_result = get_log(full_data['资产总计'])
full_data['lnSize'] = list_result

full_data['OCF'] = full_data['经营活动产生的现金流量净额'] / full_data['资产总计']

full_data['Lev'] = full_data['资产负债率']/100

full_data['Growth'] = full_data['营业收入']/100

full_data['Top1'] = full_data['大股东持股比例']

full_data['indepent'] = (full_data['独立董事人数'] / full_data['董事会人数'])*100

full_data['MH'] = (full_data['监管层持股数'] / full_data['总股数'])*100

full_data["Dual"] = np.where(full_data["董事长和总经理是否同一人"] =='Y', "1", "0")

full_data['国有判断'] = full_data['公司属性'].str[2:4]
full_data['SOE'] = np.where(full_data['国有判断'] =='国有', "1", "0")

# %%
full_data.head(1)
# Out:
#        代码   简称        会计期间 报表类型          所得税费用        截止日期 董事长和总经理是否同一人  \
# 1  000002  万科A  2011-12-31    A  4206276208.55  2011-12-31            N
#
#        统计截止日期    监管层持股数          总股数  ...     lnSize       OCF       Lev  \
# 1  2011-12-31  18426384  10995210218  ...  26.414329  0.011443  0.770997
#
#      Growth   Top1   indepent        MH Dual  国有判断  SOE
# 1  0.415447  14.73  36.363636  0.167586    0    企业    0
#
# [1 rows x 55 columns]

# %%
full_data.shape
# Out:
# (555, 55)

# %% [markdown]
# ### 对所有连续变量在上下1%水平上进行缩尾处理

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/processed/2011_final_data.xlsx')
