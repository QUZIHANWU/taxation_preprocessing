# %% [markdown]
# ## 2014_Preprocessing

# %%
# import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read 2010_data

CSMAR = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2014/CSMAR.xlsx')

WIND = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2014/WIND.xlsx')

MASTER = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2014/MASTER.xlsx')
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CSMAR.dtypes
# Out:
# code                    object
# short_name              object
# FS_Comins-Accper        object
# FS_Comins-Typrep        object
# FS_Comins-B002100000    object
# BF_EXPAY-EndDate        object
# BF_EXPAY-Same           object
# CG_Capchg-Reptdt        object
# CG_Capchg-Nshrsms       object
# CG_Capchg-Nshrttl       object
# dtype: object

# %%
WIND.dtypes
# Out:
# 证券代码                                                    object
# 证券简称                                                    object
# 递延所得税负债增加\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元          float64
# 递延所得税资产减少\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元          float64
# 高管人数\n[交易日期] 2014-12-31\n[单位] 万                        float64
# 支付给职工以及为职工支付的现金\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元    float64
# 营业收入(同比增长率)\n[报告期] 2014年报\n[单位] 万%                     float64
# 所属申万行业名称\n[行业级别] 一级行业\n[单位] 万                           object
# 资产总计\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元               float64
# 独立董事人数\n[交易日期] 2014-12-31\n[单位] 万                      float64
# 非独立董事人数\n[交易日期] 2014-12-31\n[单位] 万                     float64
# 董事会人数\n[交易日期] 2014-12-31\n[单位] 万                       float64
# 管理层年度薪酬总额\n[年度] 2014\n[单位] 万元                          float64
# 员工总数\n[交易日期] 2014-12-31\n[单位] 万                        float64
# 资产负债率\n[报告期] 2014年报\n[单位] 万%                           float64
# 公司属性\n[交易日期] 2014-12-31\n[单位] 万                         object
# 大股东持股比例\n[日期] 2014-12-31\n[排名] 第1名\n[单位] 万%            float64
# 公司监事(历任)\n[交易日期] 2014-12-31\n[单位] 万                     object
# 净利润\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元                float64
# 年末所得税率\n[年度] 2014\n[单位] 万                              float64
# 经营活动产生的现金流量净额\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元      float64
# dtype: object

# %%
MASTER.dtypes
# Out:
# Symbol                object
# Enddate               object
# StatisticalCaliber    object
# UnpaidNumber          object
# dtype: object

# %% [markdown]
# ### CSMAR_Preprocessing

# %%
CSMAR.head(5)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0      代码         简称             会计期间             报表类型                所得税费用
# 1    沒有单位       沒有单位             没有单位             没有单位                    元
# 2  000001       平安银行       2014-12-31                A         6392000000.0
# 3  000002        万科A       2014-12-31                A        5964839205.41
# 4  000004       国华网安       2014-12-31                A           5040994.08
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0             截止日期  董事长与总经理是否同一人           统计截止日期         其中：监管层持股数
# 1             没有单位          没有单位             没有单位                 股
# 2       2014-12-31             N       2014-12-31           12213.0
# 3       2014-12-31             N       2014-12-31        15874479.0
# 4       2014-12-31             N       2014-12-31            1725.0
#
#   CG_Capchg-Nshrttl
# 0               总股数
# 1                 股
# 2     11424894787.0
# 3     11037507242.0
# 4        83976684.0

# %%
CSMAR = CSMAR.drop([0])
CSMAR = CSMAR.drop([1])
CSMAR = CSMAR.reset_index(drop= True)
# CSMAR = CSMAR.drop(["TRD_Capchg-Shrchgdt", "TRD_Capchg-Nshrttl"], axis=1)
CSMAR.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2014-12-31                A         6392000000.0
# 1  000002        万科A       2014-12-31                A        5964839205.41
# 2  000004       国华网安       2014-12-31                A           5040994.08
# 3  000005      ST 星源       2014-12-31                A          11209069.58
# 4  000006       深振业A       2014-12-31                A         172701030.61
# 5  000007     *ST 全新       2014-12-31                A           1759740.21
# 6  000008       神州高铁       2014-12-31                A          11109571.78
# 7  000009       中国宝安       2014-12-31                A         115934188.91
# 8  000010       美丽生态       2014-12-31                A            -192326.9
# 9  000011       深物业A       2014-12-31                A         136266283.67
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2014-12-31             N       2014-12-31           12213.0
# 1       2014-12-31             N       2014-12-31        15874479.0
# 2       2014-12-31             N       2014-12-31            1725.0
# 3       2014-12-31             N       2014-12-31               0.0
# 4       2014-12-31             N       2014-12-31        11097903.0
# 5       2014-12-31             N       2014-12-31        25078225.0
# 6       2014-12-31             N       2014-12-31             180.0
# 7       2014-12-31             Y       2014-12-31          175682.0
# 8       2014-12-31             N       2014-12-31               0.0
# 9       2014-12-31             N       2014-12-31               0.0
#
#   CG_Capchg-Nshrttl
# 0     11424894787.0
# 1     11037507242.0
# 2        83976684.0
# 3       914333607.0
# 4      1349995046.0
# 5       230965363.0
# 6       303601640.0
# 7      1505235729.0
# 8       588069788.0
# 9       595979092.0

# %%
CSMAR.isnull().sum()
# Out:
# code                      0
# short_name                0
# FS_Comins-Accper          0
# FS_Comins-Typrep          0
# FS_Comins-B002100000      0
# BF_EXPAY-EndDate         88
# BF_EXPAY-Same           119
# CG_Capchg-Reptdt         88
# CG_Capchg-Nshrsms        88
# CG_Capchg-Nshrttl        88
# dtype: int64

# %%
CSMAR.shape
# Out:
# (2740, 10)

# %% [markdown]
# ### WIND_Preprocessing

# %%
WIND.head(5)
# Out:
#         证券代码  证券简称  递延所得税负债增加\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0  000001.SZ  平安银行                                            NaN
# 1  000002.SZ   万科A                                   -8241.636559
# 2  000004.SZ  国华网安                                            NaN
# 3  000005.SZ  ST星源                                            NaN
# 4  000006.SZ  深振业A                                    -871.642623
#
#    递延所得税资产减少\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0                                 -262600.000000
# 1                                  -57859.812374
# 2                                     -11.778238
# 3                                            NaN
# 4                                   -6096.689921
#
#    高管人数\n[交易日期] 2014-12-31\n[单位] 万  \
# 0                             15.0
# 1                              6.0
# 2                              5.0
# 3                              6.0
# 4                              9.0
#
#    支付给职工以及为职工支付的现金\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0                                       1.217500e+06
# 1                                       5.132633e+05
# 2                                       1.607097e+03
# 3                                       2.833883e+03
# 4                                       9.704156e+03
#
#    营业收入(同比增长率)\n[报告期] 2014年报\n[单位] 万% 所属申万行业名称\n[行业级别] 一级行业\n[单位] 万  \
# 0                             40.6561                            银行
# 1                              8.1002                           房地产
# 2                             10.7499                           计算机
# 3                              1.3739                          公用事业
# 4                            -49.4946                           房地产
#
#    资产总计\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0                              2.186459e+08
# 1                              5.084088e+07
# 2                              3.382826e+04
# 3                              1.366664e+05
# 4                              1.175322e+06
#
#    独立董事人数\n[交易日期] 2014-12-31\n[单位] 万  ...  董事会人数\n[交易日期] 2014-12-31\n[单位] 万  \
# 0                                5.0  ...                              15.0
# 1                                4.0  ...                              11.0
# 2                                3.0  ...                               9.0
# 3                                5.0  ...                              15.0
# 4                                3.0  ...                               9.0
#
#    管理层年度薪酬总额\n[年度] 2014\n[单位] 万元  员工总数\n[交易日期] 2014-12-31\n[单位] 万  \
# 0                        8366.74                          29860.0
# 1                        8703.50                          40647.0
# 2                         166.86                            220.0
# 3                         315.10                            421.0
# 4                         882.60                            329.0
#
#    资产负债率\n[报告期] 2014年报\n[单位] 万%  公司属性\n[交易日期] 2014-12-31\n[单位] 万  \
# 0                       94.0109                             公众企业
# 1                       77.2046                             公众企业
# 2                       53.4754                             民营企业
# 3                       50.9964                             民营企业
# 4                       64.1420                           地方国有企业
#
#   大股东持股比例\n[日期] 2014-12-31\n[排名] 第1名\n[单位] 万%  \
# 0                                   50.200001
# 1                                   14.910000
# 2                                   26.100000
# 3                                   20.150000
# 4                                   21.930000
#
#    公司监事(历任)\n[交易日期] 2014-12-31\n[单位] 万  \
# 0             邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东
# 1                           周清平,解冻,廖绮云
# 2                            魏杰,陈少龙,何婷
# 3                          刘丽萍,熊金芳,汪健飞
# 4                           朱大华,陈强,谢向荣
#
#   净利润\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元  年末所得税率\n[年度] 2014\n[单位] 万  \
# 0                            1.980200e+06                       25.0
# 1                            1.928752e+06                       25.0
# 2                            1.562481e+03                       25.0
# 3                            4.316394e+03                       25.0
# 4                            5.124536e+04                       25.0
#
#    经营活动产生的现金流量净额\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元
# 0                                       2.532100e+06
# 1                                       4.172482e+06
# 2                                      -5.534051e+02
# 3                                      -9.177753e+02
# 4                                      -1.097954e+05
#
# [5 rows x 21 columns]

# %%
WIND.columns
# Out:
# Index(['证券代码', '证券简称', '递延所得税负债增加\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元',
#        '递延所得税资产减少\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元',
#        '高管人数\n[交易日期] 2014-12-31\n[单位] 万',
#        '支付给职工以及为职工支付的现金\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元',
#        '营业收入(同比增长率)\n[报告期] 2014年报\n[单位] 万%', '所属申万行业名称\n[行业级别] 一级行业\n[单位] 万',
#        '资产总计\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元',
#        '独立董事人数\n[交易日期] 2014-12-31\n[单位] 万',
#        '非独立董事人数\n[交易日期] 2014-12-31\n[单位] 万',
#        '董事会人数\n[交易日期] 2014-12-31\n[单位] 万', '管理层年度薪酬总额\n[年度] 2014\n[单位] 万元',
#        '员工总数\n[交易日期] 2014-12-31\n[单位] 万', '资产负债率\n[报告期] 2014年报\n[单位] 万%',
#        '公司属性\n[交易日期] 2014-12-31\n[单位] 万',
#        '大股东持股比例\n[日期] 2014-12-31\n[排名] 第1名\n[单位] 万%',
#        '公司监事(历任)\n[交易日期] 2014-12-31\n[单位] 万',
#        '净利润\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元', '年末所得税率\n[年度] 2014\n[单位] 万',
#        '经营活动产生的现金流量净额\n[报告期] 2014年报\n[报表类型] 合并报表\n[单位] 万元'],
#       dtype='object')

# %%
WIND.columns = [col.replace('\n', '') for col in WIND.columns]
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0     000001.SZ  平安银行                                      NaN
# 1     000002.SZ   万科A                             -8241.636559
# 2     000004.SZ  国华网安                                      NaN
# 3     000005.SZ  ST星源                                      NaN
# 4     000006.SZ  深振业A                              -871.642623
# ...         ...   ...                                      ...
# 4769  871857.BJ  泓禧科技                                      NaN
# 4770  871981.BJ  晶赛科技                                      NaN
# 4771  872925.BJ  锦好医疗                                      NaN
# 4772        NaN   NaN                                      NaN
# 4773  数据来源：Wind   NaN                                      NaN
#
#       递延所得税资产减少[报告期] 2014年报[报表类型] 合并报表[单位] 万元  高管人数[交易日期] 2014-12-31[单位] 万  \
# 0                              -262600.000000                         15.0
# 1                               -57859.812374                          6.0
# 2                                  -11.778238                          5.0
# 3                                         NaN                          6.0
# 4                                -6096.689921                          9.0
# ...                                       ...                          ...
# 4769                                      NaN                          0.0
# 4770                                      NaN                          0.0
# 4771                                      NaN                          0.0
# 4772                                      NaN                          NaN
# 4773                                      NaN                          NaN
#
#       支付给职工以及为职工支付的现金[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0                                      1.217500e+06
# 1                                      5.132633e+05
# 2                                      1.607097e+03
# 3                                      2.833883e+03
# 4                                      9.704156e+03
# ...                                             ...
# 4769                                            NaN
# 4770                                            NaN
# 4771                                            NaN
# 4772                                            NaN
# 4773                                            NaN
#
#       营业收入(同比增长率)[报告期] 2014年报[单位] 万% 所属申万行业名称[行业级别] 一级行业[单位] 万  \
# 0                            40.6561                        银行
# 1                             8.1002                       房地产
# 2                            10.7499                       计算机
# 3                             1.3739                      公用事业
# 4                           -49.4946                       房地产
# ...                              ...                       ...
# 4769                             NaN                       NaN
# 4770                             NaN                       NaN
# 4771                             NaN                       NaN
# 4772                             NaN                       NaN
# 4773                             NaN                       NaN
#
#       资产总计[报告期] 2014年报[报表类型] 合并报表[单位] 万元  独立董事人数[交易日期] 2014-12-31[单位] 万  ...  \
# 0                           2.186459e+08                            5.0  ...
# 1                           5.084088e+07                            4.0  ...
# 2                           3.382826e+04                            3.0  ...
# 3                           1.366664e+05                            5.0  ...
# 4                           1.175322e+06                            3.0  ...
# ...                                  ...                            ...  ...
# 4769                                 NaN                            0.0  ...
# 4770                                 NaN                            0.0  ...
# 4771                                 NaN                            0.0  ...
# 4772                                 NaN                            NaN  ...
# 4773                                 NaN                            NaN  ...
#
#       董事会人数[交易日期] 2014-12-31[单位] 万  管理层年度薪酬总额[年度] 2014[单位] 万元  \
# 0                             15.0                    8366.74
# 1                             11.0                    8703.50
# 2                              9.0                     166.86
# 3                             15.0                     315.10
# 4                              9.0                     882.60
# ...                            ...                        ...
# 4769                           0.0                        NaN
# 4770                           0.0                        NaN
# 4771                           0.0                        NaN
# 4772                           NaN                        NaN
# 4773                           NaN                        NaN
#
#       员工总数[交易日期] 2014-12-31[单位] 万  资产负债率[报告期] 2014年报[单位] 万%  \
# 0                         29860.0                   94.0109
# 1                         40647.0                   77.2046
# 2                           220.0                   53.4754
# 3                           421.0                   50.9964
# 4                           329.0                   64.1420
# ...                           ...                       ...
# 4769                          NaN                       NaN
# 4770                          NaN                       NaN
# 4771                          NaN                       NaN
# 4772                          NaN                       NaN
# 4773                          NaN                       NaN
#
#       公司属性[交易日期] 2014-12-31[单位] 万 大股东持股比例[日期] 2014-12-31[排名] 第1名[单位] 万%  \
# 0                            公众企业                             50.200001
# 1                            公众企业                             14.910000
# 2                            民营企业                             26.100000
# 3                            民营企业                             20.150000
# 4                          地方国有企业                             21.930000
# ...                           ...                                   ...
# 4769                          NaN                                   NaN
# 4770                          NaN                             98.750000
# 4771                          NaN                                   NaN
# 4772                          NaN                                   NaN
# 4773                          NaN                                   NaN
#
#       公司监事(历任)[交易日期] 2014-12-31[单位] 万 净利润[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0            邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东                      1.980200e+06
# 1                          周清平,解冻,廖绮云                      1.928752e+06
# 2                           魏杰,陈少龙,何婷                      1.562481e+03
# 3                         刘丽萍,熊金芳,汪健飞                      4.316394e+03
# 4                          朱大华,陈强,谢向荣                      5.124536e+04
# ...                               ...                               ...
# 4769                              NaN                               NaN
# 4770                              NaN                               NaN
# 4771                              NaN                               NaN
# 4772                              NaN                               NaN
# 4773                              NaN                               NaN
#
#       年末所得税率[年度] 2014[单位] 万  经营活动产生的现金流量净额[报告期] 2014年报[报表类型] 合并报表[单位] 万元
# 0                      25.0                                 2.532100e+06
# 1                      25.0                                 4.172482e+06
# 2                      25.0                                -5.534051e+02
# 3                      25.0                                -9.177753e+02
# 4                      25.0                                -1.097954e+05
# ...                     ...                                          ...
# 4769                    NaN                                          NaN
# 4770                    NaN                                          NaN
# 4771                    NaN                                          NaN
# 4772                    NaN                                          NaN
# 4773                    NaN                                          NaN
#
# [4774 rows x 21 columns]

# %%
WIND = WIND.drop([4772])
WIND = WIND.drop([4773])
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0     000001.SZ  平安银行                                      NaN
# 1     000002.SZ   万科A                             -8241.636559
# 2     000004.SZ  国华网安                                      NaN
# 3     000005.SZ  ST星源                                      NaN
# 4     000006.SZ  深振业A                              -871.642623
# ...         ...   ...                                      ...
# 4767  871553.BJ  凯腾精工                                      NaN
# 4768  871642.BJ  通易航天                                      NaN
# 4769  871857.BJ  泓禧科技                                      NaN
# 4770  871981.BJ  晶赛科技                                      NaN
# 4771  872925.BJ  锦好医疗                                      NaN
#
#       递延所得税资产减少[报告期] 2014年报[报表类型] 合并报表[单位] 万元  高管人数[交易日期] 2014-12-31[单位] 万  \
# 0                              -262600.000000                         15.0
# 1                               -57859.812374                          6.0
# 2                                  -11.778238                          5.0
# 3                                         NaN                          6.0
# 4                                -6096.689921                          9.0
# ...                                       ...                          ...
# 4767                               -32.267070                          0.0
# 4768                                39.710639                          0.0
# 4769                                      NaN                          0.0
# 4770                                      NaN                          0.0
# 4771                                      NaN                          0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0                                      1.217500e+06
# 1                                      5.132633e+05
# 2                                      1.607097e+03
# 3                                      2.833883e+03
# 4                                      9.704156e+03
# ...                                             ...
# 4767                                   9.610305e+03
# 4768                                   4.075622e+02
# 4769                                            NaN
# 4770                                            NaN
# 4771                                            NaN
#
#       营业收入(同比增长率)[报告期] 2014年报[单位] 万% 所属申万行业名称[行业级别] 一级行业[单位] 万  \
# 0                            40.6561                        银行
# 1                             8.1002                       房地产
# 2                            10.7499                       计算机
# 3                             1.3739                      公用事业
# 4                           -49.4946                       房地产
# ...                              ...                       ...
# 4767                             NaN                       NaN
# 4768                             NaN                       NaN
# 4769                             NaN                       NaN
# 4770                             NaN                       NaN
# 4771                             NaN                       NaN
#
#       资产总计[报告期] 2014年报[报表类型] 合并报表[单位] 万元  独立董事人数[交易日期] 2014-12-31[单位] 万  ...  \
# 0                           2.186459e+08                            5.0  ...
# 1                           5.084088e+07                            4.0  ...
# 2                           3.382826e+04                            3.0  ...
# 3                           1.366664e+05                            5.0  ...
# 4                           1.175322e+06                            3.0  ...
# ...                                  ...                            ...  ...
# 4767                        3.354464e+04                            0.0  ...
# 4768                        1.102113e+04                            0.0  ...
# 4769                                 NaN                            0.0  ...
# 4770                                 NaN                            0.0  ...
# 4771                                 NaN                            0.0  ...
#
#       董事会人数[交易日期] 2014-12-31[单位] 万  管理层年度薪酬总额[年度] 2014[单位] 万元  \
# 0                             15.0                    8366.74
# 1                             11.0                    8703.50
# 2                              9.0                     166.86
# 3                             15.0                     315.10
# 4                              9.0                     882.60
# ...                            ...                        ...
# 4767                           0.0                        NaN
# 4768                           0.0                        NaN
# 4769                           0.0                        NaN
# 4770                           0.0                        NaN
# 4771                           0.0                        NaN
#
#       员工总数[交易日期] 2014-12-31[单位] 万  资产负债率[报告期] 2014年报[单位] 万%  \
# 0                         29860.0                   94.0109
# 1                         40647.0                   77.2046
# 2                           220.0                   53.4754
# 3                           421.0                   50.9964
# 4                           329.0                   64.1420
# ...                           ...                       ...
# 4767                          NaN                   27.5848
# 4768                          NaN                   85.3659
# 4769                          NaN                       NaN
# 4770                          NaN                       NaN
# 4771                          NaN                       NaN
#
#       公司属性[交易日期] 2014-12-31[单位] 万 大股东持股比例[日期] 2014-12-31[排名] 第1名[单位] 万%  \
# 0                            公众企业                             50.200001
# 1                            公众企业                             14.910000
# 2                            民营企业                             26.100000
# 3                            民营企业                             20.150000
# 4                          地方国有企业                             21.930000
# ...                           ...                                   ...
# 4767                          NaN                                   NaN
# 4768                          NaN                                   NaN
# 4769                          NaN                                   NaN
# 4770                          NaN                             98.750000
# 4771                          NaN                                   NaN
#
#       公司监事(历任)[交易日期] 2014-12-31[单位] 万 净利润[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0            邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东                      1.980200e+06
# 1                          周清平,解冻,廖绮云                      1.928752e+06
# 2                           魏杰,陈少龙,何婷                      1.562481e+03
# 3                         刘丽萍,熊金芳,汪健飞                      4.316394e+03
# 4                          朱大华,陈强,谢向荣                      5.124536e+04
# ...                               ...                               ...
# 4767                              NaN                      1.923452e+03
# 4768                              NaN                      6.107214e+01
# 4769                              NaN                               NaN
# 4770                              NaN                               NaN
# 4771                              NaN                               NaN
#
#       年末所得税率[年度] 2014[单位] 万  经营活动产生的现金流量净额[报告期] 2014年报[报表类型] 合并报表[单位] 万元
# 0                      25.0                                 2.532100e+06
# 1                      25.0                                 4.172482e+06
# 2                      25.0                                -5.534051e+02
# 3                      25.0                                -9.177753e+02
# 4                      25.0                                -1.097954e+05
# ...                     ...                                          ...
# 4767                   25.0                                 2.594134e+03
# 4768                   25.0                                -1.992055e+03
# 4769                    NaN                                          NaN
# 4770                    NaN                                          NaN
# 4771                    NaN                                          NaN
#
# [4772 rows x 21 columns]

# %%
WIND['证券代码'] = WIND['证券代码'].str[0:6]
WIND
# Out:
#         证券代码  证券简称  递延所得税负债增加[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0     000001  平安银行                                      NaN
# 1     000002   万科A                             -8241.636559
# 2     000004  国华网安                                      NaN
# 3     000005  ST星源                                      NaN
# 4     000006  深振业A                              -871.642623
# ...      ...   ...                                      ...
# 4767  871553  凯腾精工                                      NaN
# 4768  871642  通易航天                                      NaN
# 4769  871857  泓禧科技                                      NaN
# 4770  871981  晶赛科技                                      NaN
# 4771  872925  锦好医疗                                      NaN
#
#       递延所得税资产减少[报告期] 2014年报[报表类型] 合并报表[单位] 万元  高管人数[交易日期] 2014-12-31[单位] 万  \
# 0                              -262600.000000                         15.0
# 1                               -57859.812374                          6.0
# 2                                  -11.778238                          5.0
# 3                                         NaN                          6.0
# 4                                -6096.689921                          9.0
# ...                                       ...                          ...
# 4767                               -32.267070                          0.0
# 4768                                39.710639                          0.0
# 4769                                      NaN                          0.0
# 4770                                      NaN                          0.0
# 4771                                      NaN                          0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0                                      1.217500e+06
# 1                                      5.132633e+05
# 2                                      1.607097e+03
# 3                                      2.833883e+03
# 4                                      9.704156e+03
# ...                                             ...
# 4767                                   9.610305e+03
# 4768                                   4.075622e+02
# 4769                                            NaN
# 4770                                            NaN
# 4771                                            NaN
#
#       营业收入(同比增长率)[报告期] 2014年报[单位] 万% 所属申万行业名称[行业级别] 一级行业[单位] 万  \
# 0                            40.6561                        银行
# 1                             8.1002                       房地产
# 2                            10.7499                       计算机
# 3                             1.3739                      公用事业
# 4                           -49.4946                       房地产
# ...                              ...                       ...
# 4767                             NaN                       NaN
# 4768                             NaN                       NaN
# 4769                             NaN                       NaN
# 4770                             NaN                       NaN
# 4771                             NaN                       NaN
#
#       资产总计[报告期] 2014年报[报表类型] 合并报表[单位] 万元  独立董事人数[交易日期] 2014-12-31[单位] 万  ...  \
# 0                           2.186459e+08                            5.0  ...
# 1                           5.084088e+07                            4.0  ...
# 2                           3.382826e+04                            3.0  ...
# 3                           1.366664e+05                            5.0  ...
# 4                           1.175322e+06                            3.0  ...
# ...                                  ...                            ...  ...
# 4767                        3.354464e+04                            0.0  ...
# 4768                        1.102113e+04                            0.0  ...
# 4769                                 NaN                            0.0  ...
# 4770                                 NaN                            0.0  ...
# 4771                                 NaN                            0.0  ...
#
#       董事会人数[交易日期] 2014-12-31[单位] 万  管理层年度薪酬总额[年度] 2014[单位] 万元  \
# 0                             15.0                    8366.74
# 1                             11.0                    8703.50
# 2                              9.0                     166.86
# 3                             15.0                     315.10
# 4                              9.0                     882.60
# ...                            ...                        ...
# 4767                           0.0                        NaN
# 4768                           0.0                        NaN
# 4769                           0.0                        NaN
# 4770                           0.0                        NaN
# 4771                           0.0                        NaN
#
#       员工总数[交易日期] 2014-12-31[单位] 万  资产负债率[报告期] 2014年报[单位] 万%  \
# 0                         29860.0                   94.0109
# 1                         40647.0                   77.2046
# 2                           220.0                   53.4754
# 3                           421.0                   50.9964
# 4                           329.0                   64.1420
# ...                           ...                       ...
# 4767                          NaN                   27.5848
# 4768                          NaN                   85.3659
# 4769                          NaN                       NaN
# 4770                          NaN                       NaN
# 4771                          NaN                       NaN
#
#       公司属性[交易日期] 2014-12-31[单位] 万 大股东持股比例[日期] 2014-12-31[排名] 第1名[单位] 万%  \
# 0                            公众企业                             50.200001
# 1                            公众企业                             14.910000
# 2                            民营企业                             26.100000
# 3                            民营企业                             20.150000
# 4                          地方国有企业                             21.930000
# ...                           ...                                   ...
# 4767                          NaN                                   NaN
# 4768                          NaN                                   NaN
# 4769                          NaN                                   NaN
# 4770                          NaN                             98.750000
# 4771                          NaN                                   NaN
#
#       公司监事(历任)[交易日期] 2014-12-31[单位] 万 净利润[报告期] 2014年报[报表类型] 合并报表[单位] 万元  \
# 0            邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东                      1.980200e+06
# 1                          周清平,解冻,廖绮云                      1.928752e+06
# 2                           魏杰,陈少龙,何婷                      1.562481e+03
# 3                         刘丽萍,熊金芳,汪健飞                      4.316394e+03
# 4                          朱大华,陈强,谢向荣                      5.124536e+04
# ...                               ...                               ...
# 4767                              NaN                      1.923452e+03
# 4768                              NaN                      6.107214e+01
# 4769                              NaN                               NaN
# 4770                              NaN                               NaN
# 4771                              NaN                               NaN
#
#       年末所得税率[年度] 2014[单位] 万  经营活动产生的现金流量净额[报告期] 2014年报[报表类型] 合并报表[单位] 万元
# 0                      25.0                                 2.532100e+06
# 1                      25.0                                 4.172482e+06
# 2                      25.0                                -5.534051e+02
# 3                      25.0                                -9.177753e+02
# 4                      25.0                                -1.097954e+05
# ...                     ...                                          ...
# 4767                   25.0                                 2.594134e+03
# 4768                   25.0                                -1.992055e+03
# 4769                    NaN                                          NaN
# 4770                    NaN                                          NaN
# 4771                    NaN                                          NaN
#
# [4772 rows x 21 columns]

# %%
WIND.isnull().sum()
# Out:
# 证券代码                                                0
# 证券简称                                                0
# 递延所得税负债增加[报告期] 2014年报[报表类型] 合并报表[单位] 万元          3326
# 递延所得税资产减少[报告期] 2014年报[报表类型] 合并报表[单位] 万元          1004
# 高管人数[交易日期] 2014-12-31[单位] 万                         0
# 支付给职工以及为职工支付的现金[报告期] 2014年报[报表类型] 合并报表[单位] 万元     650
# 营业收入(同比增长率)[报告期] 2014年报[单位] 万%                    812
# 所属申万行业名称[行业级别] 一级行业[单位] 万                         163
# 资产总计[报告期] 2014年报[报表类型] 合并报表[单位] 万元                599
# 独立董事人数[交易日期] 2014-12-31[单位] 万                       0
# 非独立董事人数[交易日期] 2014-12-31[单位] 万                      0
# 董事会人数[交易日期] 2014-12-31[单位] 万                        0
# 管理层年度薪酬总额[年度] 2014[单位] 万元                        2163
# 员工总数[交易日期] 2014-12-31[单位] 万                       903
# 资产负债率[报告期] 2014年报[单位] 万%                          649
# 公司属性[交易日期] 2014-12-31[单位] 万                      2071
# 大股东持股比例[日期] 2014-12-31[排名] 第1名[单位] 万%            1738
# 公司监事(历任)[交易日期] 2014-12-31[单位] 万                  1591
# 净利润[报告期] 2014年报[报表类型] 合并报表[单位] 万元                 640
# 年末所得税率[年度] 2014[单位] 万                            1067
# 经营活动产生的现金流量净额[报告期] 2014年报[报表类型] 合并报表[单位] 万元       648
# dtype: int64

# %% [markdown]
# ### MASTER_Preprocessing

# %%
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0       证券代码      统计截止日期               统计口径   未领取薪酬监管层人数
# 1        NaN         NaN                NaN            人
# 2     000001  2014-12-31                  1          5.0
# 3     000001  2014-12-31                  2          9.0
# 4     000002  2014-12-31                  2          0.0
# ...      ...         ...                ...          ...
# 5301  900953  2014-12-31                  1          7.0
# 5302  900956  2014-12-31                  2          5.0
# 5303  900956  2014-12-31                  1          5.0
# 5304  900957  2014-12-31                  1          1.0
# 5305  900957  2014-12-31                  2          1.0
#
# [5306 rows x 4 columns]

# %%
MASTER = MASTER.drop([0])
MASTER = MASTER.drop([1])
MASTER = MASTER.reset_index(drop =True)
MASTER = MASTER[(MASTER['StatisticalCaliber'] != '2')]
MASTER
# Out:
#       Symbol     Enddate StatisticalCaliber UnpaidNumber
# 0     000001  2014-12-31                  1          5.0
# 3     000002  2014-12-31                  1          0.0
# 5     000004  2014-12-31                  1          5.0
# 7     000005  2014-12-31                  1          4.0
# 9     000006  2014-12-31                  1          3.0
# ...      ...         ...                ...          ...
# 5295  900950  2014-12-31                  1          3.0
# 5297  900951  2014-12-31                  1          8.0
# 5299  900953  2014-12-31                  1          7.0
# 5301  900956  2014-12-31                  1          5.0
# 5302  900957  2014-12-31                  1          1.0
#
# [2652 rows x 4 columns]

# %%
MASTER.shape
# Out:
# (2652, 4)

# %% [markdown]
# ### Merge CSMAR_and_WIND_and_MASTER

# %%
merge_data = pd.merge(CSMAR, WIND, left_on='code', right_on='证券代码')
merge_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2014-12-31                A         6392000000.0
# 1  000002        万科A       2014-12-31                A        5964839205.41
# 2  000004       国华网安       2014-12-31                A           5040994.08
# 3  000005      ST 星源       2014-12-31                A          11209069.58
# 4  000006       深振业A       2014-12-31                A         172701030.61
# 5  000007     *ST 全新       2014-12-31                A           1759740.21
# 6  000008       神州高铁       2014-12-31                A          11109571.78
# 7  000009       中国宝安       2014-12-31                A         115934188.91
# 8  000010       美丽生态       2014-12-31                A            -192326.9
# 9  000011       深物业A       2014-12-31                A         136266283.67
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2014-12-31             N       2014-12-31           12213.0
# 1       2014-12-31             N       2014-12-31        15874479.0
# 2       2014-12-31             N       2014-12-31            1725.0
# 3       2014-12-31             N       2014-12-31               0.0
# 4       2014-12-31             N       2014-12-31        11097903.0
# 5       2014-12-31             N       2014-12-31        25078225.0
# 6       2014-12-31             N       2014-12-31             180.0
# 7       2014-12-31             Y       2014-12-31          175682.0
# 8       2014-12-31             N       2014-12-31               0.0
# 9       2014-12-31             N       2014-12-31               0.0
#
#   CG_Capchg-Nshrttl  ... 董事会人数[交易日期] 2014-12-31[单位] 万  \
# 0     11424894787.0  ...                         15.0
# 1     11037507242.0  ...                         11.0
# 2        83976684.0  ...                          9.0
# 3       914333607.0  ...                         15.0
# 4      1349995046.0  ...                          9.0
# 5       230965363.0  ...                          7.0
# 6       303601640.0  ...                          7.0
# 7      1505235729.0  ...                          7.0
# 8       588069788.0  ...                         10.0
# 9       595979092.0  ...                          9.0
#
#   管理层年度薪酬总额[年度] 2014[单位] 万元  员工总数[交易日期] 2014-12-31[单位] 万  \
# 0                   8366.74                      29860.0
# 1                   8703.50                      40647.0
# 2                    166.86                        220.0
# 3                    315.10                        421.0
# 4                    882.60                        329.0
# 5                    325.30                        606.0
# 6                    216.67                       1299.0
# 7                   1823.42                       7457.0
# 8                    395.48                        302.0
# 9                    667.21                       3167.0
#
#    资产负债率[报告期] 2014年报[单位] 万%  公司属性[交易日期] 2014-12-31[单位] 万  \
# 0                   94.0109                         公众企业
# 1                   77.2046                         公众企业
# 2                   53.4754                         民营企业
# 3                   50.9964                         民营企业
# 4                   64.1420                       地方国有企业
# 5                   47.4294                         民营企业
# 6                   11.2276                         民营企业
# 7                   62.8934                         公众企业
# 8                   31.4128                         民营企业
# 9                   46.5632                       地方国有企业
#
#    大股东持股比例[日期] 2014-12-31[排名] 第1名[单位] 万%  公司监事(历任)[交易日期] 2014-12-31[单位] 万  \
# 0                              50.200001         邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东
# 1                              14.910000                       周清平,解冻,廖绮云
# 2                              26.100000                        魏杰,陈少龙,何婷
# 3                              20.150000                      刘丽萍,熊金芳,汪健飞
# 4                              21.930000                       朱大华,陈强,谢向荣
# 5                              13.420000                        孙华,罗旭红,党仑
# 6                              51.480000                        杨建,祁萌,袁淦明
# 7                              12.340000                       龚明,贺国奇,马小虎
# 8                              29.990000                       孙永平,翟禹,徐文慰
# 9                              54.330002              戴先华,王秋平,王秀颜,张戈坚,张满华
#
#   净利润[报告期] 2014年报[报表类型] 合并报表[单位] 万元  年末所得税率[年度] 2014[单位] 万  \
# 0                      1.980200e+06                   25.0
# 1                      1.928752e+06                   25.0
# 2                      1.562481e+03                   25.0
# 3                      4.316394e+03                   25.0
# 4                      5.124536e+04                   25.0
# 5                     -3.338265e+03                   25.0
# 6                      7.766403e+02                   25.0
# 7                      4.725486e+04                   25.0
# 8                     -7.531835e+03                   25.0
# 9                      4.174987e+04                   25.0
#
#    经营活动产生的现金流量净额[报告期] 2014年报[报表类型] 合并报表[单位] 万元
# 0                                 2.532100e+06
# 1                                 4.172482e+06
# 2                                -5.534051e+02
# 3                                -9.177753e+02
# 4                                -1.097954e+05
# 5                                 1.259870e+03
# 6                                 6.869805e+03
# 7                                 4.746348e+04
# 8                                -1.206893e+04
# 9                                -1.462706e+03
#
# [10 rows x 31 columns]

# %%
full_data = pd.merge(merge_data, MASTER, left_on='code', right_on='Symbol')
full_data.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2014-12-31                A         6392000000.0
# 1  000002        万科A       2014-12-31                A        5964839205.41
# 2  000004       国华网安       2014-12-31                A           5040994.08
# 3  000005      ST 星源       2014-12-31                A          11209069.58
# 4  000006       深振业A       2014-12-31                A         172701030.61
# 5  000007     *ST 全新       2014-12-31                A           1759740.21
# 6  000008       神州高铁       2014-12-31                A          11109571.78
# 7  000009       中国宝安       2014-12-31                A         115934188.91
# 8  000010       美丽生态       2014-12-31                A            -192326.9
# 9  000011       深物业A       2014-12-31                A         136266283.67
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2014-12-31             N       2014-12-31           12213.0
# 1       2014-12-31             N       2014-12-31        15874479.0
# 2       2014-12-31             N       2014-12-31            1725.0
# 3       2014-12-31             N       2014-12-31               0.0
# 4       2014-12-31             N       2014-12-31        11097903.0
# 5       2014-12-31             N       2014-12-31        25078225.0
# 6       2014-12-31             N       2014-12-31             180.0
# 7       2014-12-31             Y       2014-12-31          175682.0
# 8       2014-12-31             N       2014-12-31               0.0
# 9       2014-12-31             N       2014-12-31               0.0
#
#   CG_Capchg-Nshrttl  ... 公司属性[交易日期] 2014-12-31[单位] 万  \
# 0     11424894787.0  ...                        公众企业
# 1     11037507242.0  ...                        公众企业
# 2        83976684.0  ...                        民营企业
# 3       914333607.0  ...                        民营企业
# 4      1349995046.0  ...                      地方国有企业
# 5       230965363.0  ...                        民营企业
# 6       303601640.0  ...                        民营企业
# 7      1505235729.0  ...                        公众企业
# 8       588069788.0  ...                        民营企业
# 9       595979092.0  ...                      地方国有企业
#
#   大股东持股比例[日期] 2014-12-31[排名] 第1名[单位] 万%  公司监事(历任)[交易日期] 2014-12-31[单位] 万  \
# 0                             50.200001         邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东
# 1                             14.910000                       周清平,解冻,廖绮云
# 2                             26.100000                        魏杰,陈少龙,何婷
# 3                             20.150000                      刘丽萍,熊金芳,汪健飞
# 4                             21.930000                       朱大华,陈强,谢向荣
# 5                             13.420000                        孙华,罗旭红,党仑
# 6                             51.480000                        杨建,祁萌,袁淦明
# 7                             12.340000                       龚明,贺国奇,马小虎
# 8                             29.990000                       孙永平,翟禹,徐文慰
# 9                             54.330002              戴先华,王秋平,王秀颜,张戈坚,张满华
#
#    净利润[报告期] 2014年报[报表类型] 合并报表[单位] 万元  年末所得税率[年度] 2014[单位] 万  \
# 0                       1.980200e+06                   25.0
# 1                       1.928752e+06                   25.0
# 2                       1.562481e+03                   25.0
# 3                       4.316394e+03                   25.0
# 4                       5.124536e+04                   25.0
# 5                      -3.338265e+03                   25.0
# 6                       7.766403e+02                   25.0
# 7                       4.725486e+04                   25.0
# 8                      -7.531835e+03                   25.0
# 9                       4.174987e+04                   25.0
#
#    经营活动产生的现金流量净额[报告期] 2014年报[报表类型] 合并报表[单位] 万元  Symbol     Enddate  \
# 0                                 2.532100e+06  000001  2014-12-31
# 1                                 4.172482e+06  000002  2014-12-31
# 2                                -5.534051e+02  000004  2014-12-31
# 3                                -9.177753e+02  000005  2014-12-31
# 4                                -1.097954e+05  000006  2014-12-31
# 5                                 1.259870e+03  000007  2014-12-31
# 6                                 6.869805e+03  000008  2014-12-31
# 7                                 4.746348e+04  000009  2014-12-31
# 8                                -1.206893e+04  000010  2014-12-31
# 9                                -1.462706e+03  000011  2014-12-31
#
#    StatisticalCaliber  UnpaidNumber
# 0                   1           5.0
# 1                   1           0.0
# 2                   1           5.0
# 3                   1           4.0
# 4                   1           3.0
# 5                   1           0.0
# 6                   1           0.0
# 7                   1           0.0
# 8                   1           0.0
# 9                   1           4.0
#
# [10 rows x 35 columns]

# %%
full_data.shape
# Out:
# (2565, 35)

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2014/full_data.xlsx')

# %% [markdown]
# ### 1：剔除金融保险类、ST、* ST类上市公司

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加[报告期] 2014年报[报表类型] 合并报表[单位] 万元',
#        '递延所得税资产减少[报告期] 2014年报[报表类型] 合并报表[单位] 万元',
#        '高管人数[交易日期] 2014-12-31[单位] 万',
#        '支付给职工以及为职工支付的现金[报告期] 2014年报[报表类型] 合并报表[单位] 万元',
#        '营业收入(同比增长率)[报告期] 2014年报[单位] 万%', '所属申万行业名称[行业级别] 一级行业[单位] 万',
#        '资产总计[报告期] 2014年报[报表类型] 合并报表[单位] 万元', '独立董事人数[交易日期] 2014-12-31[单位] 万',
#        '非独立董事人数[交易日期] 2014-12-31[单位] 万', '董事会人数[交易日期] 2014-12-31[单位] 万',
#        '管理层年度薪酬总额[年度] 2014[单位] 万元', '员工总数[交易日期] 2014-12-31[单位] 万',
#        '资产负债率[报告期] 2014年报[单位] 万%', '公司属性[交易日期] 2014-12-31[单位] 万',
#        '大股东持股比例[日期] 2014-12-31[排名] 第1名[单位] 万%',
#        '公司监事(历任)[交易日期] 2014-12-31[单位] 万', '净利润[报告期] 2014年报[报表类型] 合并报表[单位] 万元',
#        '年末所得税率[年度] 2014[单位] 万', '经营活动产生的现金流量净额[报告期] 2014年报[报表类型] 合并报表[单位] 万元',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.columns = ['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
       'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
       'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
       '证券简称', '递延所得税负债增加',
       '递延所得税资产减少', '高管人数',
       '支付给职工以及为职工支付的现金',
       '营业收入', '所属申万行业名称',
       '资产总计', '独立董事人数',
       '非独立董事人数', '董事会人数',
       '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性',
       '大股东持股比例', '公司监事',
       '净利润', '年末所得税率',
       '经营活动产生的现金流量净额', 'Symbol', 'Enddate',
       'StatisticalCaliber', 'UnpaidNumber']
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.shape
# Out:
# (2565, 35)

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '银行')]
full_data = full_data[(full_data['所属申万行业名称'] != '非银金融')]

full_data['check_ST'] = full_data['short_name'].str[0:2]
full_data['check_*ST'] = full_data['short_name'].str[0:3]
full_data = full_data[(full_data['check_ST'] != 'ST')]
full_data = full_data[(full_data['check_*ST'] != '*ST')]

# %%
full_data.shape
# Out:
# (2332, 37)

# %% [markdown]
# ### 2：剔除员工数量不足 100人的公司,这部分公司可能存在经营异常或者数据披露错误

# %%
full_data = full_data[(full_data['员工总数'] > 100)]

# %%
full_data.shape
# Out:
# (2303, 37)

# %% [markdown]
# ### 3：剔除管理层平均工资比普通员工平均工资低的公司,因为这类公司披露的高管薪酬可能仅是津贴,或者数据错误：

# %% [markdown]
# - 管理层平均工资 = 管理层年度薪酬总数/（非独立董事人数+公司监事+高管人数-UnpaidNumber）
# - 普通员工平均工资 = （支付给职工以及为职工支付的现金-管理层年度薪酬总数）/ （员工总数-（非独立董事+公司监事+高管人数））

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST'],
#       dtype='object')

# %%
full_data['人数']=full_data['公司监事'].apply(lambda x: len(x.split(',')))

# %%
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2014-12-31                A        5964839205.41
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2014-12-31             N       2014-12-31        15874479.0
#
#   CG_Capchg-Nshrttl  ...           净利润 年末所得税率  经营活动产生的现金流量净额  Symbol  \
# 1     11037507242.0  ...  1.928752e+06   25.0   4.172482e+06  000002
#
#       Enddate  StatisticalCaliber  UnpaidNumber check_ST  check_*ST  人数
# 1  2014-12-31                   1           0.0       万科        万科A   3
#
# [1 rows x 38 columns]

# %%
full_data['管理层平均工资'] = full_data['管理层年度薪酬总额'] / (
   full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数'] 
      - full_data['UnpaidNumber']
) *10000
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2014-12-31                A        5964839205.41
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2014-12-31             N       2014-12-31        15874479.0
#
#   CG_Capchg-Nshrttl  ... 年末所得税率 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11037507242.0  ...   25.0  4.172482e+06  000002  2014-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST check_*ST  人数    管理层平均工资
# 1                   1           0.0        万科       万科A   3  5439687.5
#
# [1 rows x 39 columns]

# %%
full_data['普通员工平均工资'] = (full_data ['支付给职工以及为职工支付的现金'] 
   - full_data['管理层年度薪酬总额']) / (
      full_data['员工总数'] - (
         full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数']
      )
) *10000
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2014-12-31                A        5964839205.41
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2014-12-31             N       2014-12-31        15874479.0
#
#   CG_Capchg-Nshrttl  ... 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11037507242.0  ...  4.172482e+06  000002  2014-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST  check_*ST 人数    管理层平均工资  \
# 1                   1           0.0        万科        万科A  3  5439687.5
#
#         普通员工平均工资
# 1  124180.987268
#
# [1 rows x 40 columns]

# %%
full_data = full_data[(full_data["管理层平均工资"] > full_data["普通员工平均工资"])]

# %%
full_data.shape
# Out:
# (2264, 40)

# %% [markdown]
# ### 4：剔除企业实际所得税率小于0和大于1的样本

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data = full_data[(full_data['年末所得税率'] <100) &
   (full_data['年末所得税率'] >0)]

# %%
full_data.shape
# Out:
# (2235, 40)

# %% [markdown]
# ### 5：由于2015 年新增了轻工、纺织、机械和汽车四大行业作为加速折旧政策试点,如果将这部分个业作为2014年加速折旧政策的控制组可能对结果产生偏差,为此还剔除了享受2015年加速折旧政策的公司样本

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '轻工制造')]
full_data = full_data[(full_data['所属申万行业名称'] != '纺织服装')]
full_data = full_data[(full_data['所属申万行业名称'] != '机械设备')]
full_data = full_data[(full_data['所属申万行业名称'] != '汽车')]

# %%
full_data.shape
# Out:
# (1828, 40)

# %% [markdown]
# ### 6：剔除关键变量缺失的样本

# %%
miss_data = pd.DataFrame(full_data.isnull().sum(), columns=['Missing Data Count'])
miss_data
# Out:
#                       Missing Data Count
# code                                   0
# short_name                             0
# FS_Comins-Accper                       0
# FS_Comins-Typrep                       0
# FS_Comins-B002100000                   0
# BF_EXPAY-EndDate                       0
# BF_EXPAY-Same                         22
# CG_Capchg-Reptdt                       0
# CG_Capchg-Nshrsms                      0
# CG_Capchg-Nshrttl                      0
# 证券代码                                   0
# 证券简称                                   0
# 递延所得税负债增加                            977
# 递延所得税资产减少                             63
# 高管人数                                   0
# 支付给职工以及为职工支付的现金                        0
# 营业收入                                   0
# 所属申万行业名称                               0
# 资产总计                                   0
# 独立董事人数                                 0
# 非独立董事人数                                0
# 董事会人数                                  0
# 管理层年度薪酬总额                              0
# 员工总数                                   0
# 资产负债率                                  0
# 公司属性                                   8
# 大股东持股比例                                0
# 公司监事                                   0
# 净利润                                    0
# 年末所得税率                                 0
# 经营活动产生的现金流量净额                          0
# Symbol                                 0
# Enddate                                0
# StatisticalCaliber                     0
# UnpaidNumber                           0
# check_ST                               0
# check_*ST                              0
# 人数                                     0
# 管理层平均工资                                0
# 普通员工平均工资                               0

# %%
miss_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2014/miss_data.xlsx')

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2014/full_data2.xlsx')

# %%
full_data.dropna(axis=0,inplace=True)

# %%
full_data.shape
# Out:
# (826, 40)

# %% [markdown]
# ### 8：final

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.columns = ['代码', '简称', '会计期间', '报表类型',
       '所得税费用', '截止日期', '董事长和总经理是否同一人',
       '统计截止日期', '监管层持股数', '总股数', '证券代码',
       '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
       '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
       'Symbol', 'Enddate', 'StatisticalCaliber', '未领取薪酬监管层人数', 'check_ST',
       'check_*ST', '人数', '管理层平均工资', '普通员工平均工资']
full_data.columns
# Out:
# Index(['代码', '简称', '会计期间', '报表类型', '所得税费用', '截止日期', '董事长和总经理是否同一人', '统计截止日期',
#        '监管层持股数', '总股数', '证券代码', '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数',
#        '支付给职工以及为职工支付的现金', '营业收入', '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数',
#        '董事会人数', '管理层年度薪酬总额', '员工总数', '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润',
#        '年末所得税率', '经营活动产生的现金流量净额', 'Symbol', 'Enddate', 'StatisticalCaliber',
#        '未领取薪酬监管层人数', 'check_ST', 'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2014/2014_final_1.xlsx')

# %% [markdown]
# ### .to_table

# %%
import math

def get_log(full_data):
   result_log = []
   list_log = full_data.values
   for i in list_log:
      result_log_n = math.log(i)
      result_log.append(result_log_n)
   return result_log

list_result = get_log(full_data['管理层平均工资'])
full_data['lnAMW'] = list_result

list_result = get_log(full_data['普通员工平均工资'])
full_data['lnAEW'] = list_result

full_data['收入不平等'] = full_data['管理层平均工资'] / full_data['普通员工平均工资']
list_result = get_log(full_data['收入不平等'])
full_data['lnWFI'] = list_result

full_data['净利润'] = full_data['净利润']*10000
full_data['递延所得税负债增加'] = full_data['递延所得税负债增加']*10000
full_data['递延所得税资产减少'] = full_data['递延所得税资产减少']*10000
full_data['ETR'] = full_data['所得税费用'] / (
   (
      full_data['所得税费用'] + full_data['净利润'] - (
         full_data['递延所得税负债增加'] + full_data['递延所得税资产减少']
      )/ (full_data['年末所得税率'])
   )
)


list_result = get_log(full_data['资产总计']*10000)
full_data['lnSize'] = list_result

full_data['OCF'] = full_data['经营活动产生的现金流量净额'] / full_data['资产总计']

full_data['Lev'] = full_data['资产负债率']/100

full_data['Growth'] = full_data['营业收入']/100

full_data['Top1'] = full_data['大股东持股比例']

full_data['indepent'] = (full_data['独立董事人数'] / full_data['董事会人数'])*100

full_data['MH'] = (full_data['监管层持股数'] / full_data['总股数'])*100

full_data["Dual"] = np.where(full_data["董事长和总经理是否同一人"] =='Y', "1", "0")

full_data['国有判断'] = full_data['公司属性'].str[2:4]
full_data['SOE'] = np.where(full_data['国有判断'] =='国有', "1", "0")

# %%
full_data.head(1)
# Out:
#        代码   简称        会计期间 报表类型          所得税费用        截止日期 董事长和总经理是否同一人  \
# 1  000002  万科A  2014-12-31    A  5964839205.41  2014-12-31            N
#
#        统计截止日期      监管层持股数            总股数  ...     lnSize       OCF       Lev  \
# 1  2014-12-31  15874479.0  11037507242.0  ...  26.954552  0.082069  0.772046
#
#      Growth   Top1   indepent        MH Dual  国有判断  SOE
# 1  0.081002  14.91  36.363636  0.143823    0    企业    0
#
# [1 rows x 55 columns]

# %%
full_data.shape
# Out:
# (826, 55)

# %% [markdown]
# ### 对所有连续变量在上下1%水平上进行缩尾处理

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/processed/2014_final_data.xlsx')

# %%
full_data['lnWFI'].describe()
# Out:
# count    826.000000
# mean       1.396018
# std        0.597733
# min        0.041682
# 25%        0.987787
# 50%        1.340187
# 75%        1.749211
# max        3.779737
# Name: lnWFI, dtype: float64
