# %% [markdown]
# ## 2016_Preprocessing

# %%
# import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read 2010_data

CSMAR = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2016/CSMAR.xlsx')

WIND = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2016/WIND.xlsx')

MASTER = pd.read_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2016/MASTER.xlsx')
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CSMAR.dtypes
# Out:
# code                    object
# short_name              object
# FS_Comins-Accper        object
# FS_Comins-Typrep        object
# FS_Comins-B002100000    object
# BF_EXPAY-EndDate        object
# BF_EXPAY-Same           object
# CG_Capchg-Reptdt        object
# CG_Capchg-Nshrsms       object
# CG_Capchg-Nshrttl       object
# dtype: object

# %%
WIND.dtypes
# Out:
# 证券代码                                                    object
# 证券简称                                                    object
# 递延所得税负债增加\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元          float64
# 递延所得税资产减少\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元          float64
# 高管人数\n[交易日期] 2016-12-31\n[单位] 万                        float64
# 支付给职工以及为职工支付的现金\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元    float64
# 营业收入(同比增长率)\n[报告期] 2016年报\n[单位] 万%                     float64
# 所属申万行业名称\n[行业级别] 一级行业\n[单位] 万                           object
# 资产总计\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元               float64
# 独立董事人数\n[交易日期] 2016-12-31\n[单位] 万                      float64
# 非独立董事人数\n[交易日期] 2016-12-31\n[单位] 万                     float64
# 董事会人数\n[交易日期] 2016-12-31\n[单位] 万                       float64
# 管理层年度薪酬总额\n[年度] 2016\n[单位] 万元                          float64
# 员工总数\n[交易日期] 2016-12-31\n[单位] 万                        float64
# 资产负债率\n[报告期] 2016年报\n[单位] 万%                           float64
# 公司属性\n[交易日期] 2016-12-31\n[单位] 万                         object
# 大股东持股比例\n[日期] 2016-12-31\n[排名] 第1名\n[单位] 万%            float64
# 公司监事(历任)\n[交易日期] 2016-12-31\n[单位] 万                     object
# 净利润\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元                float64
# 年末所得税率\n[年度] 2016\n[单位] 万                              float64
# 经营活动产生的现金流量净额\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元      float64
# dtype: object

# %%
MASTER.dtypes
# Out:
# Symbol                object
# Enddate               object
# StatisticalCaliber    object
# UnpaidNumber          object
# dtype: object

# %% [markdown]
# ### CSMAR_Preprocessing

# %%
CSMAR.head(5)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0      代码         简称             会计期间             报表类型                所得税费用
# 1    沒有单位       沒有单位             没有单位             没有单位                    元
# 2  000001       平安银行       2016-12-31                A         7336000000.0
# 3  000002        万科A       2016-12-31                A   10903356245.620001
# 4  000004       国华网安       2016-12-31                A           6469356.84
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0             截止日期  董事长与总经理是否同一人           统计截止日期         其中：监管层持股数
# 1             没有单位          没有单位             没有单位                 股
# 2       2016-12-31             N       2016-12-31           17587.0
# 3       2016-12-31             N       2016-12-31        15128774.0
# 4       2016-12-31             Y       2016-12-31          913500.0
#
#   CG_Capchg-Nshrttl
# 0               总股数
# 1                 股
# 2     17170411366.0
# 3     11039152001.0
# 4        83976684.0

# %%
CSMAR = CSMAR.drop([0])
CSMAR = CSMAR.drop([1])
CSMAR = CSMAR.reset_index(drop= True)
# CSMAR = CSMAR.drop(["TRD_Capchg-Shrchgdt", "TRD_Capchg-Nshrttl"], axis=1)
CSMAR.head(10)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 0  000001       平安银行       2016-12-31                A         7336000000.0
# 1  000002        万科A       2016-12-31                A   10903356245.620001
# 2  000004       国华网安       2016-12-31                A           6469356.84
# 3  000005      ST 星源       2016-12-31                A            9802169.5
# 4  000006       深振业A       2016-12-31                A         120520954.88
# 5  000007     *ST 全新       2016-12-31                A           8639407.89
# 6  000008       神州高铁       2016-12-31                A         112317329.97
# 7  000009       中国宝安       2016-12-31                A         122247073.63
# 8  000010       美丽生态       2016-12-31                A          29777171.41
# 9  000011       深物业A       2016-12-31                A         136350415.59
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 0       2016-12-31             N       2016-12-31           17587.0
# 1       2016-12-31             N       2016-12-31        15128774.0
# 2       2016-12-31             Y       2016-12-31          913500.0
# 3       2016-12-31             N       2016-12-31               0.0
# 4       2016-12-31           NaN       2016-12-31         5111150.0
# 5       2016-12-31             N       2016-12-31        25000000.0
# 6       2016-12-31             N       2016-12-31       183856393.0
# 7       2016-12-31             Y       2016-12-31         5473093.0
# 8       2016-12-31             N       2016-12-31               0.0
# 9       2016-12-31             N       2016-12-31               0.0
#
#   CG_Capchg-Nshrttl
# 0     17170411366.0
# 1     11039152001.0
# 2        83976684.0
# 3      1058536842.0
# 4      1349995046.0
# 5       230965363.0
# 6      2809078279.0
# 7      2149344971.0
# 8       819854713.0
# 9       595979092.0

# %%
CSMAR.isnull().sum()
# Out:
# code                      0
# short_name                0
# FS_Comins-Accper          0
# FS_Comins-Typrep          0
# FS_Comins-B002100000     29
# BF_EXPAY-EndDate        131
# BF_EXPAY-Same           178
# CG_Capchg-Reptdt        130
# CG_Capchg-Nshrsms       130
# CG_Capchg-Nshrttl       130
# dtype: int64

# %%
CSMAR.shape
# Out:
# (3266, 10)

# %% [markdown]
# ### WIND_Preprocessing

# %%
WIND.head(5)
# Out:
#         证券代码  证券简称  递延所得税负债增加\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0  000001.SZ  平安银行                                            NaN
# 1  000002.SZ   万科A                                   -5438.261103
# 2  000004.SZ  国华网安                                            NaN
# 3  000005.SZ  ST星源                                     -34.200000
# 4  000006.SZ  深振业A                                    -194.240773
#
#    递延所得税资产减少\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0                                 -921300.000000
# 1                                 -193879.888872
# 2                                       3.926206
# 3                                   -1191.259372
# 4                                   -3013.268300
#
#    高管人数\n[交易日期] 2016-12-31\n[单位] 万  \
# 0                             13.0
# 1                              8.0
# 2                              3.0
# 3                              6.0
# 4                              6.0
#
#    支付给职工以及为职工支付的现金\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0                                       1.376200e+06
# 1                                       6.689013e+05
# 2                                       1.719023e+03
# 3                                       6.407916e+03
# 4                                       8.776821e+03
#
#    营业收入(同比增长率)\n[报告期] 2016年报\n[单位] 万% 所属申万行业名称\n[行业级别] 一级行业\n[单位] 万  \
# 0                             12.0129                            银行
# 1                             22.9754                           房地产
# 2                            138.8206                           计算机
# 3                            472.7880                          公用事业
# 4                             -8.0859                           房地产
#
#    资产总计\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元  \
# 0                              2.953434e+08
# 1                              8.306742e+07
# 2                              2.237163e+04
# 3                              2.527235e+05
# 4                              1.317039e+06
#
#    独立董事人数\n[交易日期] 2016-12-31\n[单位] 万  ...  董事会人数\n[交易日期] 2016-12-31\n[单位] 万  \
# 0                                5.0  ...                              14.0
# 1                                4.0  ...                              11.0
# 2                                3.0  ...                               9.0
# 3                                5.0  ...                              15.0
# 4                                3.0  ...                               8.0
#
#    管理层年度薪酬总额\n[年度] 2016\n[单位] 万元  员工总数\n[交易日期] 2016-12-31\n[单位] 万  \
# 0                        4537.91                          32993.0
# 1                        6353.40                          58280.0
# 2                         136.26                            179.0
# 3                         431.81                            618.0
# 4                         766.86                            370.0
#
#    资产负债率\n[报告期] 2016年报\n[单位] 万%  公司属性\n[交易日期] 2016-12-31\n[单位] 万  \
# 0                       93.1547                             公众企业
# 1                       80.5367                             公众企业
# 2                       20.3456                             民营企业
# 3                       46.3708                             民营企业
# 4                       61.0499                           地方国有企业
#
#   大股东持股比例\n[日期] 2016-12-31\n[排名] 第1名\n[单位] 万%  \
# 0                                   49.560001
# 1                                   15.240000
# 2                                   28.420000
# 3                                   17.410000
# 4                                   21.930000
#
#    公司监事(历任)\n[交易日期] 2016-12-31\n[单位] 万  \
# 0             邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东
# 1                           周清平,解冻,廖绮云
# 2                           唐银萍,魏杰,林绮霞
# 3                  刘丽萍,熊金芳,汪健飞,刘敏儿,吕卫东
# 4                           朱大华,陈强,谢向荣
#
#   净利润\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元  年末所得税率\n[年度] 2016\n[单位] 万  \
# 0                            2.259900e+06                       25.0
# 1                            2.835026e+06                       25.0
# 2                            3.971632e+03                       25.0
# 3                            1.169624e+04                       25.0
# 4                            8.038765e+04                       25.0
#
#    经营活动产生的现金流量净额\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元
# 0                                       1.098900e+06
# 1                                       3.956613e+06
# 2                                       1.479298e+04
# 3                                      -1.858630e+04
# 4                                       1.708426e+05
#
# [5 rows x 21 columns]

# %%
WIND.columns
# Out:
# Index(['证券代码', '证券简称', '递延所得税负债增加\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元',
#        '递延所得税资产减少\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元',
#        '高管人数\n[交易日期] 2016-12-31\n[单位] 万',
#        '支付给职工以及为职工支付的现金\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元',
#        '营业收入(同比增长率)\n[报告期] 2016年报\n[单位] 万%', '所属申万行业名称\n[行业级别] 一级行业\n[单位] 万',
#        '资产总计\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元',
#        '独立董事人数\n[交易日期] 2016-12-31\n[单位] 万',
#        '非独立董事人数\n[交易日期] 2016-12-31\n[单位] 万',
#        '董事会人数\n[交易日期] 2016-12-31\n[单位] 万', '管理层年度薪酬总额\n[年度] 2016\n[单位] 万元',
#        '员工总数\n[交易日期] 2016-12-31\n[单位] 万', '资产负债率\n[报告期] 2016年报\n[单位] 万%',
#        '公司属性\n[交易日期] 2016-12-31\n[单位] 万',
#        '大股东持股比例\n[日期] 2016-12-31\n[排名] 第1名\n[单位] 万%',
#        '公司监事(历任)\n[交易日期] 2016-12-31\n[单位] 万',
#        '净利润\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元', '年末所得税率\n[年度] 2016\n[单位] 万',
#        '经营活动产生的现金流量净额\n[报告期] 2016年报\n[报表类型] 合并报表\n[单位] 万元'],
#       dtype='object')

# %%
WIND.columns = [col.replace('\n', '') for col in WIND.columns]
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2016年报[报表类型] 合并报表[单位] 万元  \
# 0     000001.SZ  平安银行                                      NaN
# 1     000002.SZ   万科A                             -5438.261103
# 2     000004.SZ  国华网安                                      NaN
# 3     000005.SZ  ST星源                               -34.200000
# 4     000006.SZ  深振业A                              -194.240773
# ...         ...   ...                                      ...
# 4769  871857.BJ  泓禧科技                                -1.580277
# 4770  871981.BJ  晶赛科技                                99.734491
# 4771  872925.BJ  锦好医疗                                      NaN
# 4772        NaN   NaN                                      NaN
# 4773  数据来源：Wind   NaN                                      NaN
#
#       递延所得税资产减少[报告期] 2016年报[报表类型] 合并报表[单位] 万元  高管人数[交易日期] 2016-12-31[单位] 万  \
# 0                              -921300.000000                         13.0
# 1                              -193879.888872                          8.0
# 2                                    3.926206                          3.0
# 3                                -1191.259372                          6.0
# 4                                -3013.268300                          6.0
# ...                                       ...                          ...
# 4769                                19.305834                          0.0
# 4770                               -49.034798                          3.0
# 4771                                 1.058994                          0.0
# 4772                                      NaN                          NaN
# 4773                                      NaN                          NaN
#
#       支付给职工以及为职工支付的现金[报告期] 2016年报[报表类型] 合并报表[单位] 万元  \
# 0                                      1.376200e+06
# 1                                      6.689013e+05
# 2                                      1.719023e+03
# 3                                      6.407916e+03
# 4                                      8.776821e+03
# ...                                             ...
# 4769                                   1.794035e+03
# 4770                                   2.191126e+03
# 4771                                   7.020482e+02
# 4772                                            NaN
# 4773                                            NaN
#
#       营业收入(同比增长率)[报告期] 2016年报[单位] 万% 所属申万行业名称[行业级别] 一级行业[单位] 万  \
# 0                            12.0129                        银行
# 1                            22.9754                       房地产
# 2                           138.8206                       计算机
# 3                           472.7880                      公用事业
# 4                            -8.0859                       房地产
# ...                              ...                       ...
# 4769                         18.5707                       NaN
# 4770                         20.1349                       NaN
# 4771                             NaN                       NaN
# 4772                             NaN                       NaN
# 4773                             NaN                       NaN
#
#       资产总计[报告期] 2016年报[报表类型] 合并报表[单位] 万元  独立董事人数[交易日期] 2016-12-31[单位] 万  ...  \
# 0                           2.953434e+08                            5.0  ...
# 1                           8.306742e+07                            4.0  ...
# 2                           2.237163e+04                            3.0  ...
# 3                           2.527235e+05                            5.0  ...
# 4                           1.317039e+06                            3.0  ...
# ...                                  ...                            ...  ...
# 4769                        1.756749e+04                            0.0  ...
# 4770                        2.293868e+04                            0.0  ...
# 4771                        3.381798e+03                            0.0  ...
# 4772                                 NaN                            NaN  ...
# 4773                                 NaN                            NaN  ...
#
#       董事会人数[交易日期] 2016-12-31[单位] 万  管理层年度薪酬总额[年度] 2016[单位] 万元  \
# 0                             14.0                    4537.91
# 1                             11.0                    6353.40
# 2                              9.0                     136.26
# 3                             15.0                     431.81
# 4                              8.0                     766.86
# ...                            ...                        ...
# 4769                           0.0                        NaN
# 4770                           5.0                        NaN
# 4771                           0.0                        NaN
# 4772                           NaN                        NaN
# 4773                           NaN                        NaN
#
#       员工总数[交易日期] 2016-12-31[单位] 万  资产负债率[报告期] 2016年报[单位] 万%  \
# 0                         32993.0                   93.1547
# 1                         58280.0                   80.5367
# 2                           179.0                   20.3456
# 3                           618.0                   46.3708
# 4                           370.0                   61.0499
# ...                           ...                       ...
# 4769                        417.0                   64.6082
# 4770                          NaN                   44.3171
# 4771                          NaN                   55.4927
# 4772                          NaN                       NaN
# 4773                          NaN                       NaN
#
#       公司属性[交易日期] 2016-12-31[单位] 万 大股东持股比例[日期] 2016-12-31[排名] 第1名[单位] 万%  \
# 0                            公众企业                             49.560001
# 1                            公众企业                             15.240000
# 2                            民营企业                             28.420000
# 3                            民营企业                             17.410000
# 4                          地方国有企业                             21.930000
# ...                           ...                                   ...
# 4769                          NaN                                   NaN
# 4770                          NaN                             98.750000
# 4771                          NaN                                   NaN
# 4772                          NaN                                   NaN
# 4773                          NaN                                   NaN
#
#       公司监事(历任)[交易日期] 2016-12-31[单位] 万 净利润[报告期] 2016年报[报表类型] 合并报表[单位] 万元  \
# 0            邱伟,车国宝,曹立新,王岚,周建国,王聪,骆向东                      2.259900e+06
# 1                          周清平,解冻,廖绮云                      2.835026e+06
# 2                          唐银萍,魏杰,林绮霞                      3.971632e+03
# 3                 刘丽萍,熊金芳,汪健飞,刘敏儿,吕卫东                      1.169624e+04
# 4                          朱大华,陈强,谢向荣                      8.038765e+04
# ...                               ...                               ...
# 4769                              NaN                      1.115970e+03
# 4770                      陈维彦,孙龙凤,王立平                      9.625220e+02
# 4771                              NaN                      8.593424e+02
# 4772                              NaN                               NaN
# 4773                              NaN                               NaN
#
#       年末所得税率[年度] 2016[单位] 万  经营活动产生的现金流量净额[报告期] 2016年报[报表类型] 合并报表[单位] 万元
# 0                      25.0                                 1.098900e+06
# 1                      25.0                                 3.956613e+06
# 2                      25.0                                 1.479298e+04
# 3                      25.0                                -1.858630e+04
# 4                      25.0                                 1.708426e+05
# ...                     ...                                          ...
# 4769                   15.0                                 1.607320e+03
# 4770                   15.0                                 8.996994e+02
# 4771                   15.0                                 5.863828e+02
# 4772                    NaN                                          NaN
# 4773                    NaN                                          NaN
#
# [4774 rows x 21 columns]

# %%
WIND = WIND.drop([4772])
WIND = WIND.drop([4773])
WIND
# Out:
#            证券代码  证券简称  递延所得税负债增加[报告期] 2016年报[报表类型] 合并报表[单位] 万元  \
# 0     000001.SZ  平安银行                                      NaN
# 1     000002.SZ   万科A                             -5438.261103
# 2     000004.SZ  国华网安                                      NaN
# 3     000005.SZ  ST星源                               -34.200000
# 4     000006.SZ  深振业A                              -194.240773
# ...         ...   ...                                      ...
# 4767  871553.BJ  凯腾精工                                      NaN
# 4768  871642.BJ  通易航天                                      NaN
# 4769  871857.BJ  泓禧科技                                -1.580277
# 4770  871981.BJ  晶赛科技                                99.734491
# 4771  872925.BJ  锦好医疗                                      NaN
#
#       递延所得税资产减少[报告期] 2016年报[报表类型] 合并报表[单位] 万元  高管人数[交易日期] 2016-12-31[单位] 万  \
# 0                              -921300.000000                         13.0
# 1                              -193879.888872                          8.0
# 2                                    3.926206                          3.0
# 3                                -1191.259372                          6.0
# 4                                -3013.268300                          6.0
# ...                                       ...                          ...
# 4767                                11.236237                          6.0
# 4768                               128.734637                          6.0
# 4769                                19.305834                          0.0
# 4770                               -49.034798                          3.0
# 4771                                 1.058994                          0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2016年报[报表类型] 合并报表[单位] 万元  \
# 0                                      1.376200e+06
# 1                                      6.689013e+05
# 2                                      1.719023e+03
# 3                                      6.407916e+03
# 4                                      8.776821e+03
# ...                                             ...
# 4767                                   9.885092e+03
# 4768                                   6.955866e+02
# 4769                                   1.794035e+03
# 4770                                   2.191126e+03
# 4771                                   7.020482e+02
#
#       营业收入(同比增长率)[报告期] 2016年报[单位] 万% 所属申万行业名称[行业级别] 一级行业[单位] 万  \
# 0                            12.0129                        银行
# 1                            22.9754                       房地产
# 2                           138.8206                       计算机
# 3                           472.7880                      公用事业
# 4                            -8.0859                       房地产
# ...                              ...                       ...
# 4767                          9.8202                       NaN
# 4768                         83.9517                       NaN
# 4769                         18.5707                       NaN
# 4770                         20.1349                       NaN
# 4771                             NaN                       NaN
#
#       资产总计[报告期] 2016年报[报表类型] 合并报表[单位] 万元  独立董事人数[交易日期] 2016-12-31[单位] 万  ...  \
# 0                           2.953434e+08                            5.0  ...
# 1                           8.306742e+07                            4.0  ...
# 2                           2.237163e+04                            3.0  ...
# 3                           2.527235e+05                            5.0  ...
# 4                           1.317039e+06                            3.0  ...
# ...                                  ...                            ...  ...
# 4767                        3.016867e+04                            0.0  ...
# 4768                        8.675999e+03                            0.0  ...
# 4769                        1.756749e+04                            0.0  ...
# 4770                        2.293868e+04                            0.0  ...
# 4771                        3.381798e+03                            0.0  ...
#
#       董事会人数[交易日期] 2016-12-31[单位] 万  管理层年度薪酬总额[年度] 2016[单位] 万元  \
# 0                             14.0                    4537.91
# 1                             11.0                    6353.40
# 2                              9.0                     136.26
# 3                             15.0                     431.81
# 4                              8.0                     766.86
# ...                            ...                        ...
# 4767                           5.0                        NaN
# 4768                           5.0                        NaN
# 4769                           0.0                        NaN
# 4770                           5.0                        NaN
# 1                              -193879.888872                          8.0
# 2                                    3.926206                          3.0
# 3                                -1191.259372                          6.0
# 4                                -3013.268300                          6.0
# ...                                       ...                          ...
# 4767                                11.236237                          6.0
# 4768                               128.734637                          6.0
# 4769                                19.305834                          0.0
# 4770                               -49.034798                          3.0
# 4771                                 1.058994                          0.0
#
#       支付给职工以及为职工支付的现金[报告期] 2016年报[报表类型] 合并报表[单位] 万元  \
# 0                                      1.376200e+06
# 1                                      6.689013e+05
# 2                                      1.719023e+03
# 3                                      6.407916e+03
# 4                                      8.776821e+03
# ...                                             ...
# 4767                                   9.885092e+03
# 4768                                   6.955866e+02
# 4769                                   1.794035e+03
# 4770                                   2.191126e+03
# 4771                                   7.020482e+02
#
#       营业收入(同比增长率)[报告期] 2016年报[单位] 万% 所属申万行业名称[行业级别] 一级行业[单位] 万  \
# 0                            12.0129                        银行
# 1                            22.9754                       房地产
# 2                           138.8206                       计算机
# 3                           472.7880                      公用事业
# 4                            -8.0859                       房地产
# ...                              ...                       ...
# 4767                          9.8202                       NaN
# 4768                         83.9517                       NaN
# 4769                         18.5707                       NaN
# 4770                         20.1349                       NaN
# 4771                             NaN                       NaN
#
#       资产总计[报告期] 2016年报[报表类型] 合并报表[单位] 万元  独立董事人数[交易日期] 2016-12-31[单位] 万  ...  \
# 0                           2.953434e+08                            5.0  ...
# 1                           8.306742e+07                            4.0  ...
# 2                           2.237163e+04                            3.0  ...
# 3                           2.527235e+05                            5.0  ...
# 4                           1.317039e+06                            3.0  ...
# ...                                  ...                            ...  ...
# 4767                        3.016867e+04                            0.0  ...
# 4768                        8.675999e+03                            0.0  ...
# 4769                        1.756749e+04                            0.0  ...
# 4770                        2.293868e+04                            0.0  ...
# 4771                        3.381798e+03                            0.0  ...
#
#       董事会人数[交易日期] 2016-12-31[单位] 万  管理层年度薪酬总额[年度] 2016[单位] 万元  \
# 0                             14.0                    4537.91
# 1                             11.0                    6353.40
# 2                              9.0                     136.26
# 3                             15.0                     431.81
# 4                              8.0                     766.86
# ...                            ...                        ...
# 4767                           5.0                        NaN
# 4768                           5.0                        NaN
# 4769                           0.0                        NaN
# 4770                           5.0                        NaN
# 4771                           0.0                        NaN
#
#       员工总数[交易日期] 2016-12-31[单位] 万  资产负债率[报告期] 2016年报[单位] 万%  \
# 0                         32993.0                   93.1547
# 1                         58280.0                   80.5367
# 2                           179.0                   20.3456
# 3                           618.0                   46.3708
# 4                           370.0                   61.0499
# ...                           ...                       ...
# 4767                          NaN                   37.8149
# 4768                        100.0                   46.7358
# 4769                        417.0                   64.6082
# 4770                          NaN                   44.3171
# 4771                          NaN                   55.4927
#
#       公司属性[交易日期] 2016-12-31[单位] 万 大股东持股比例[日期] 2016-12-31[排名] 第1名[单位] 万%  \
# 0                            公众企业                             49.560001
# 1                            公众企业                             15.240000
# 2                            民营企业                             28.420000
# 3                            民营企业                             17.410000
# 4                          地方国有企业                             21.930000
# ...                           ...                                   ...
# 4767                          NaN                                   NaN
# 4768                          NaN                                   NaN
# 4769                          NaN                                   NaN
_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2016/full_data.xlsx')

# %% [markdown]
# ### 1：剔除金融保险类、ST、* ST类上市公司

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加[报告期] 2016年报[报表类型] 合并报表[单位] 万元',
#        '递延所得税资产减少[报告期] 2016年报[报表类型] 合并报表[单位] 万元',
#        '高管人数[交易日期] 2016-12-31[单位] 万',
#        '支付给职工以及为职工支付的现金[报告期] 2016年报[报表类型] 合并报表[单位] 万元',
#        '营业收入(同比增长率)[报告期] 2016年报[单位] 万%', '所属申万行业名称[行业级别] 一级行业[单位] 万',
#        '资产总计[报告期] 2016年报[报表类型] 合并报表[单位] 万元', '独立董事人数[交易日期] 2016-12-31[单位] 万',
#        '非独立董事人数[交易日期] 2016-12-31[单位] 万', '董事会人数[交易日期] 2016-12-31[单位] 万',
#        '管理层年度薪酬总额[年度] 2016[单位] 万元', '员工总数[交易日期] 2016-12-31[单位] 万',
#        '资产负债率[报告期] 2016年报[单位] 万%', '公司属性[交易日期] 2016-12-31[单位] 万',
#        '大股东持股比例[日期] 2016-12-31[排名] 第1名[单位] 万%',
#        '公司监事(历任)[交易日期] 2016-12-31[单位] 万', '净利润[报告期] 2016年报[报表类型] 合并报表[单位] 万元',
#        '年末所得税率[年度] 2016[单位] 万', '经营活动产生的现金流量净额[报告期] 2016年报[报表类型] 合并报表[单位] 万元',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.columns = ['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
       'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
       'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
       '证券简称', '递延所得税负债增加',
       '递延所得税资产减少', '高管人数',
       '支付给职工以及为职工支付的现金',
       '营业收入', '所属申万行业名称',
       '资产总计', '独立董事人数',
       '非独立董事人数', '董事会人数',
       '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性',
       '大股东持股比例', '公司监事',
       '净利润', '年末所得税率',
       '经营活动产生的现金流量净额', 'Symbol', 'Enddate',
       'StatisticalCaliber', 'UnpaidNumber']
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber'],
#       dtype='object')

# %%
full_data.shape
# Out:
# (3059, 35)

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '银行')]
full_data = full_data[(full_data['所属申万行业名称'] != '非银金融')]

full_data['check_ST'] = full_data['short_name'].str[0:2]
full_data['check_*ST'] = full_data['short_name'].str[0:3]
full_data = full_data[(full_data['check_ST'] != 'ST')]
full_data = full_data[(full_data['check_*ST'] != '*ST')]

# %%
full_data.shape
# Out:
# (2798, 37)

# %% [markdown]
# ### 2：剔除员工数量不足 100人的公司,这部分公司可能存在经营异常或者数据披露错误

# %%
full_data = full_data[(full_data['员工总数'] > 100)]

# %%
full_data.shape
# Out:
# (2774, 37)

# %% [markdown]
# ### 3：剔除管理层平均工资比普通员工平均工资低的公司,因为这类公司披露的高管薪酬可能仅是津贴,或者数据错误：

# %% [markdown]
# - 管理层平均工资 = 管理层年度薪酬总数/（非独立董事人数+公司监事+高管人数-UnpaidNumber）
# - 普通员工平均工资 = （支付给职工以及为职工支付的现金-管理层年度薪酬总数）/ （员工总数-（非独立董事+公司监事+高管人数））

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST'],
#       dtype='object')

# %%
full_data['人数']=full_data['公司监事'].apply(lambda x: len(x.split(',')))

# %%
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2016-12-31                A   10903356245.620001
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2016-12-31             N       2016-12-31        15128774.0
#
#   CG_Capchg-Nshrttl  ...           净利润 年末所得税率  经营活动产生的现金流量净额  Symbol  \
# 1     11039152001.0  ...  2.835026e+06   25.0   3.956613e+06  000002
#
#       Enddate  StatisticalCaliber  UnpaidNumber check_ST  check_*ST  人数
# 1  2016-12-31                   1           0.0       万科        万科A   3
#
# [1 rows x 38 columns]

# %%
full_data['管理层平均工资'] = full_data['管理层年度薪酬总额'] / (
   full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数'] 
      - full_data['UnpaidNumber']
) *10000
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2016-12-31                A   10903356245.620001
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2016-12-31             N       2016-12-31        15128774.0
#
#   CG_Capchg-Nshrttl  ... 年末所得税率 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11039152001.0  ...   25.0  3.956613e+06  000002  2016-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST check_*ST  人数         管理层平均工资
# 1                   1           0.0        万科       万科A   3  3529666.666667
#
# [1 rows x 39 columns]

# %%
full_data['普通员工平均工资'] = (full_data ['支付给职工以及为职工支付的现金'] 
   - full_data['管理层年度薪酬总额']) / (
      full_data['员工总数'] - (
         full_data['非独立董事人数'] + full_data['人数'] + full_data['高管人数']
      )
) *10000
full_data.head(1)
# Out:
#      code short_name FS_Comins-Accper FS_Comins-Typrep FS_Comins-B002100000  \
# 1  000002        万科A       2016-12-31                A   10903356245.620001
#
#   BF_EXPAY-EndDate BF_EXPAY-Same CG_Capchg-Reptdt CG_Capchg-Nshrsms  \
# 1       2016-12-31             N       2016-12-31        15128774.0
#
#   CG_Capchg-Nshrttl  ... 经营活动产生的现金流量净额  Symbol     Enddate  \
# 1     11039152001.0  ...  3.956613e+06  000002  2016-12-31
#
#    StatisticalCaliber  UnpaidNumber  check_ST  check_*ST 人数         管理层平均工资  \
# 1                   1           0.0        万科        万科A  3  3529666.666667
#
#         普通员工平均工资
# 1  113718.709722
#
# [1 rows x 40 columns]

# %%
full_data = full_data[(full_data["管理层平均工资"] > full_data["普通员工平均工资"])]

# %%
full_data.shape
# Out:
# (2727, 40)

# %% [markdown]
# ### 4：剔除企业实际所得税率小于0和大于1的样本

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data = full_data[(full_data['年末所得税率'] <100) &
   (full_data['年末所得税率'] >0)]

# %%
full_data.shape
# Out:
# (2688, 40)

# %% [markdown]
# ### 5：由于2015 年新增了轻工、纺织、机械和汽车四大行业作为加速折旧政策试点,如果将这部分个业作为2014年加速折旧政策的控制组可能对结果产生偏差,为此还剔除了享受2015年加速折旧政策的公司样本

# %%
full_data = full_data[(full_data['所属申万行业名称'] != '轻工制造')]
full_data = full_data[(full_data['所属申万行业名称'] != '纺织服装')]
full_data = full_data[(full_data['所属申万行业名称'] != '机械设备')]
full_data = full_data[(full_data['所属申万行业名称'] != '汽车')]

# %%
full_data.shape
# Out:
# (2156, 40)

# %% [markdown]
# ### 6：剔除关键变量缺失的样本

# %%
miss_data = pd.DataFrame(full_data.isnull().sum(), columns=['Missing Data Count'])
miss_data
# Out:
#                       Missing Data Count
# code                                   0
# short_name                             0
# FS_Comins-Accper                       0
# FS_Comins-Typrep                       0
# FS_Comins-B002100000                   9
# BF_EXPAY-EndDate                       0
# BF_EXPAY-Same                         31
# CG_Capchg-Reptdt                       0
# CG_Capchg-Nshrsms                      0
# CG_Capchg-Nshrttl                      0
# 证券代码                                   0
# 证券简称                                   0
# 递延所得税负债增加                            974
# 递延所得税资产减少                             52
# 高管人数                                   0
# 支付给职工以及为职工支付的现金                        0
# 营业收入                                   0
# 所属申万行业名称                               0
# 资产总计                                   0
# 独立董事人数                                 0
# 非独立董事人数                                0
# 董事会人数                                  0
# 管理层年度薪酬总额                              0
# 员工总数                                   0
# 资产负债率                                  0
# 公司属性                                  14
# 大股东持股比例                                0
# 公司监事                                   0
# 净利润                                    0
# 年末所得税率                                 0
# 经营活动产生的现金流量净额                          0
# Symbol                                 0
# Enddate                                0
# StatisticalCaliber                     0
# UnpaidNumber                           0
# check_ST                               0
# check_*ST                              0
# 人数                                     0
# 管理层平均工资                                0
# 普通员工平均工资                               0

# %%
miss_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2016/miss_data.xlsx')

# %%
full_data.to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2016/full_data2.xlsx')

# %%
full_data.dropna(axis=0,inplace=True)

# %%
full_data.shape
# Out:
# (1155, 40)

# %% [markdown]
# ### 8：final

# %%
full_data.columns
# Out:
# Index(['code', 'short_name', 'FS_Comins-Accper', 'FS_Comins-Typrep',
#        'FS_Comins-B002100000', 'BF_EXPAY-EndDate', 'BF_EXPAY-Same',
#        'CG_Capchg-Reptdt', 'CG_Capchg-Nshrsms', 'CG_Capchg-Nshrttl', '证券代码',
#        '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
#        '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
#        '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
#        'Symbol', 'Enddate', 'StatisticalCaliber', 'UnpaidNumber', 'check_ST',
#        'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.columns = ['代码', '简称', '会计期间', '报表类型',
       '所得税费用', '截止日期', '董事长和总经理是否同一人',
       '统计截止日期', '监管层持股数', '总股数', '证券代码',
       '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数', '支付给职工以及为职工支付的现金', '营业收入',
       '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数', '董事会人数', '管理层年度薪酬总额', '员工总数',
       '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润', '年末所得税率', '经营活动产生的现金流量净额',
       'Symbol', 'Enddate', 'StatisticalCaliber', '未领取薪酬监管层人数', 'check_ST',
       'check_*ST', '人数', '管理层平均工资', '普通员工平均工资']
full_data.columns
# Out:
# Index(['代码', '简称', '会计期间', '报表类型', '所得税费用', '截止日期', '董事长和总经理是否同一人', '统计截止日期',
#        '监管层持股数', '总股数', '证券代码', '证券简称', '递延所得税负债增加', '递延所得税资产减少', '高管人数',
#        '支付给职工以及为职工支付的现金', '营业收入', '所属申万行业名称', '资产总计', '独立董事人数', '非独立董事人数',
#        '董事会人数', '管理层年度薪酬总额', '员工总数', '资产负债率', '公司属性', '大股东持股比例', '公司监事', '净利润',
#        '年末所得税率', '经营活动产生的现金流量净额', 'Symbol', 'Enddate', 'StatisticalCaliber',
#        '未领取薪酬监管层人数', 'check_ST', 'check_*ST', '人数', '管理层平均工资', '普通员工平均工资'],
#       dtype='object')

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/raw/2016/2016_final_1.xlsx')

# %% [markdown]
# ### .to_table

# %%
import math

def get_log(full_data):
   result_log = []
   list_log = full_data.values
   for i in list_log:
      result_log_n = math.log(i)
      result_log.append(result_log_n)
   return result_log

list_result = get_log(full_data['管理层平均工资'])
full_data['lnAMW'] = list_result

list_result = get_log(full_data['普通员工平均工资'])
full_data['lnAEW'] = list_result

full_data['收入不平等'] = full_data['管理层平均工资'] / full_data['普通员工平均工资']
list_result = get_log(full_data['收入不平等'])
full_data['lnWFI'] = list_result

full_data['净利润'] = full_data['净利润']*10000
full_data['递延所得税负债增加'] = full_data['递延所得税负债增加']*10000
full_data['递延所得税资产减少'] = full_data['递延所得税资产减少']*10000
full_data['ETR'] = full_data['所得税费用'] / (
   (
      full_data['所得税费用'] + full_data['净利润'] - (
         full_data['递延所得税负债增加'] + full_data['递延所得税资产减少']
      )/ (full_data['年末所得税率'])
   )
)

list_result = get_log(full_data['资产总计']*10000)
full_data['lnSize'] = list_result

full_data['OCF'] = full_data['经营活动产生的现金流量净额'] / full_data['资产总计']

full_data['Lev'] = full_data['资产负债率']/100

full_data['Growth'] = full_data['营业收入']/100

full_data['Top1'] = full_data['大股东持股比例']

full_data['indepent'] = (full_data['独立董事人数'] / full_data['董事会人数'])*100

full_data['MH'] = (full_data['监管层持股数'] / full_data['总股数'])*100

full_data["Dual"] = np.where(full_data["董事长和总经理是否同一人"] =='Y', "1", "0")

full_data['国有判断'] = full_data['公司属性'].str[2:4]
full_data['SOE'] = np.where(full_data['国有判断'] =='国有', "1", "0")

# %%
full_data.head(1)
# Out:
#        代码   简称        会计期间 报表类型               所得税费用        截止日期 董事长和总经理是否同一人  \
# 1  000002  万科A  2016-12-31    A  10903356245.620001  2016-12-31            N
#
#        统计截止日期      监管层持股数            总股数  ...     lnSize       OCF       Lev  \
# 1  2016-12-31  15128774.0  11039152001.0  ...  27.445504  0.047631  0.805367
#
#      Growth   Top1   indepent        MH Dual  国有判断  SOE
# 1  0.229754  15.24  36.363636  0.137047    0    企业    0
#
# [1 rows x 55 columns]

# %%
full_data.shape
# Out:
# (1155, 55)

# %% [markdown]
# ### 对所有连续变量在上下1%水平上进行缩尾处理

# %%
full_data.reset_index().to_excel('/Users/quzihanwu/Desktop/Preprocessing_copy_by_Martin/data/processed/2016_final_data.xlsx')

# %%
full_data['lnAMW'].describe()
# Out:
# count    1155.000000
# mean       12.950545
# std         0.611704
# min        11.330804
# 25%        12.524254
# 50%        12.911790
# 75%        13.309247
# max        15.277583
# Name: lnAMW, dtype: float64

# %%
full_data['lnWFI'].describe()
# Out:
# count    1155.000000
# mean        1.389954
# std         0.606173
# min         0.004597
# 25%         0.972681
# 50%         1.335066
# 75%         1.746340
# max         3.526885
# Name: lnWFI, dtype: float64
